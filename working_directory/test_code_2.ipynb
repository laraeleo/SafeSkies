# %%
# Install dependencies
# %pip install ultralytics
# %pip install opencv-python
# %pip install simple_pid
# %pip install numpy
# %pip install pyserial
# %pip install cv2-enumerate-cameras
# %pip install scikit-learn
# %pip install nolds
# %pip install folium
# %pip install html2image
# %pip install google-api-python-client
# %pip install google-auth-httplib2
# %pip install google-auth-oauthlib
# Out:
# Requirement already satisfied: ultralytics in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (8.3.186)
# Requirement already satisfied: numpy>=1.23.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (2.3.1)
# Requirement already satisfied: matplotlib>=3.3.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (3.10.3)
# Requirement already satisfied: opencv-python>=4.6.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (1.16.0)
# Requirement already satisfied: torch>=1.8.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (2.7.1)
# Requirement already satisfied: torchvision>=0.9.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (0.22.1)
# Requirement already satisfied: psutil in /Users/Leonardo/Library/Python/3.13/lib/python/site-packages (from ultralytics) (7.0.0)
# Requirement already satisfied: py-cpuinfo in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (2.3.0)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/Leonardo/Library/Python/3.13/lib/python/site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/Leonardo/Library/Python/3.13/lib/python/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/Leonardo/Library/Python/3.13/lib/python/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (2026.1.4)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (3.20.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (4.14.0)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (2025.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: opencv-python in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from opencv-python) (2.3.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: simple_pid in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (2.0.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (2.3.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pyserial in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (3.5)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: cv2-enumerate-cameras in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (1.3.0)
# Requirement already satisfied: pyobjc-framework-AVFoundation in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from cv2-enumerate-cameras) (11.1)
# Requirement already satisfied: pyobjc-core>=11.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pyobjc-framework-AVFoundation->cv2-enumerate-cameras) (11.1)
# Requirement already satisfied: pyobjc-framework-CoreMedia>=11.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pyobjc-framework-AVFoundation->cv2-enumerate-cameras) (11.1)
# Requirement already satisfied: pyobjc-framework-CoreAudio>=11.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pyobjc-framework-AVFoundation->cv2-enumerate-cameras) (11.1)
# Requirement already satisfied: pyobjc-framework-Cocoa>=11.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pyobjc-framework-AVFoundation->cv2-enumerate-cameras) (11.1)
# Requirement already satisfied: pyobjc-framework-Quartz>=11.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pyobjc-framework-AVFoundation->cv2-enumerate-cameras) (11.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from scikit-learn) (2.3.1)
# Requirement already satisfied: scipy>=1.8.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from scikit-learn) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: nolds in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (0.6.2)
# Requirement already satisfied: numpy<3.0,>1.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from nolds) (2.3.1)
# Requirement already satisfied: future in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from nolds) (1.0.0)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from nolds) (80.9.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: folium in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (0.20.0)
# Requirement already satisfied: branca>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from folium) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from folium) (2.3.1)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from folium) (2.32.4)
# Requirement already satisfied: xyzservices in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from folium) (2025.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests->folium) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests->folium) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests->folium) (2026.1.4)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: html2image in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (2.0.7)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from html2image) (2.32.4)
# Requirement already satisfied: websocket-client~=1.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from html2image) (1.8.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests->html2image) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests->html2image) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests->html2image) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests->html2image) (2026.1.4)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: google-api-python-client in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (2.192.0)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-python-client) (0.31.2)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-python-client) (2.49.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-python-client) (0.3.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-python-client) (2.30.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-python-client) (4.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (1.73.0)
# Requirement already satisfied: protobuf<7.0.0,>=4.25.8 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (6.33.5)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (1.27.1)
# Requirement already satisfied: requests<3.0.0,>=2.20.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.32.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (46.0.5)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (4.9.1)
# Requirement already satisfied: pyparsing<4,>=3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client) (3.2.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests<3.0.0,>=2.20.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests<3.0.0,>=2.20.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests<3.0.0,>=2.20.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests<3.0.0,>=2.20.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2026.1.4)
# Requirement already satisfied: pyasn1>=0.1.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from rsa<5,>=3.1.4->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (0.6.2)
# Requirement already satisfied: cffi>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from cryptography>=38.0.3->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (2.0.0)
# Requirement already satisfied: pycparser in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (3.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: google-auth-httplib2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (0.3.0)
# Requirement already satisfied: google-auth<3.0.0,>=1.32.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth-httplib2) (2.49.0)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth-httplib2) (0.31.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth<3.0.0,>=1.32.0->google-auth-httplib2) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth<3.0.0,>=1.32.0->google-auth-httplib2) (46.0.5)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth<3.0.0,>=1.32.0->google-auth-httplib2) (4.9.1)
# Requirement already satisfied: pyparsing<4,>=3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httplib2<1.0.0,>=0.19.0->google-auth-httplib2) (3.2.3)
# Requirement already satisfied: pyasn1>=0.1.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=1.32.0->google-auth-httplib2) (0.6.2)
# Requirement already satisfied: cffi>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=1.32.0->google-auth-httplib2) (2.0.0)
# Requirement already satisfied: pycparser in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=1.32.0->google-auth-httplib2) (3.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: google-auth-oauthlib in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (1.3.0)
# Requirement already satisfied: google-auth!=2.43.0,!=2.44.0,!=2.45.0,<3.0.0,>=2.15.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth-oauthlib) (2.49.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth-oauthlib) (2.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth!=2.43.0,!=2.44.0,!=2.45.0,<3.0.0,>=2.15.0->google-auth-oauthlib) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth!=2.43.0,!=2.44.0,!=2.45.0,<3.0.0,>=2.15.0->google-auth-oauthlib) (46.0.5)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth!=2.43.0,!=2.44.0,!=2.45.0,<3.0.0,>=2.15.0->google-auth-oauthlib) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from rsa<5,>=3.1.4->google-auth!=2.43.0,!=2.44.0,!=2.45.0,<3.0.0,>=2.15.0->google-auth-oauthlib) (0.6.2)
# Requirement already satisfied: cffi>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from cryptography>=38.0.3->google-auth!=2.43.0,!=2.44.0,!=2.45.0,<3.0.0,>=2.15.0->google-auth-oauthlib) (2.0.0)
# Requirement already satisfied: pycparser in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth!=2.43.0,!=2.44.0,!=2.45.0,<3.0.0,>=2.15.0->google-auth-oauthlib) (3.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.3.1)
# Requirement already satisfied: requests>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2026.1.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Configurations
import cv2
import os
import io
import math
import serial
import time
import requests
import nolds
import pickle
import folium
import webbrowser
import numpy as np
import matplotlib.pyplot as plt
from ultralytics import YOLO
from simple_pid import PID
from cv2_enumerate_cameras import enumerate_cameras
from collections import deque
from sklearn.decomposition import PCA
from html2image import Html2Image
from googleapiclient.discovery import build
from googleapiclient.http import MediaIoBaseUpload
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request

# Camera configuration
CAMERA_INDEX_1 = 1200                  # Index of the camera  to be used (custom value; check with enumerate_cameras)
CAMERA_INDEX_2 = 1201                  # Index of the camera to be used (custom value; check with enumerate_cameras)
VERBOSE = True                         # Set to True to enable detailed logging for debugging purposes

# Movement vector filtering
VECTOR_MIN_LENGTH = 20                 # Minimum length of movement vector to consider (in pixels)
VECTOR_MAX_LENGTH = 200                # Maximum length of movement vector to consider (in pixels)
PIXELS_PER_UNIT = 20000.0              # Conversion factor from pixels to real-world units (e.g., cm)
VECTOR_HISTORY_SIZE = 10               # Number of previous positions to store for movement vector calculation

# Geometry setup
CAMERA_DISTANCE = 0.43                 # Distance between two cameras (used for triangulation)
DISTANCE_UNIT = "m"                    # Unit of measurement for camera distance
PROTOTYPE_ANGLE = 10                   # Angle of the prototype setup (in degrees)
R = 6371000                            # Radius of the Earth in DISTANCE_UNITs

# YOLO model setup
MODEL = YOLO('yolov10m.pt')            # Load YOLOv8 nano model for object detection
CLASS_NAMES = MODEL.names              # List of all class labels in the model
DESIRED_CLASSES = ["sports ball"]      # Classes we want to detect (only track sports balls)

# PID control parameters
PID_KP = 0.015                         # PID Proportional gain
PID_KI = 0.003                         # PID Integral gain
PID_KD = 0.09                          # PID Derivative gain
PID_OUTPUT_LIMITS = (-3, 3)            # Output limits for PID correction to smooth servo movement
ALPHA = 0.2                            # Smoothing factor for servo movement (0 < ALPHA < 1)

# Servo configuration
SERVO_MIN = 0                          # Minimum angle a servo can rotate to
SERVO_MAX = 180                        # Maximum angle a servo can rotate to
SERVO_MIN_STEP = 1                     # Minimum step size in angles for servo movement
SERVO_SCAN_STEP = 5                    # Step size in angles for servo scanning movements
SERVO_DOUBLE_SCAN_INTERVAL = 300       # Seconds between servo scan movements when no cameras found an object
SERVO_SINGLE_SCAN_INTERVAL = 10        # Seconds between servo scan movements when only one camera found the object
DELAY_BETWEEN_SERVO_MOVEMENTS = 1      # Delay in seconds between servo movements to allow physical movement
SERVO_INIT = {                         # Initial servo positions (centered)
    'x1': 65, 
    'y1': 90, 
    'x2': 115, 
    'y2': 90
}

# Arduino serial communication
ARDUINO_PORT = '/dev/cu.usbmodem11301'  # Serial port where Arduino is connected
ARDUINO_BAUDRATE = 9600                 # Communication speed between Python and Arduino

# Weather API configuration
LAT_INIT = -23.451642                         # Latitude of camera 1
LON_INIT = -46.774476                         # Longitude of camera 1
API_KEY = '860d2355fa0fe182dce220585a819603'  # OpenWeatherMap API key
PREDICTION_INTERVAL = 60                      # Seconds between flight predictions
FIRST_PREDICTION_INTERVAL = 10                # Seconds until first flight prediction

# Telegram bot configuration
TOKEN = "8750939695:AAHakcI-1T_IC6WkK2CvcPSsSsAT5hnzCrI" # Change to your bot token
CHAT_ID = "-4856182101"                  # Change to your chat ID
ALERT_COOLDOWN = 30                      # Seconds between alerts

# Google Drive configuration
SCOPES = ['https://www.googleapis.com/auth/drive.file'] # Scope for uploading files to Google Drive
POSITIVE_IMAGE_UPLOAD_INTERVAL = 30               # Seconds between positive image uploads to Google Drive
NEGATIVE_IMAGE_UPLOAD_INTERVAL = 60               # Seconds between negative image uploads to Google Drive
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/nolds/datasets.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
# CV2 and camera settings

# Initialize camera
def init_camera(index, verbose=VERBOSE):
    cap = cv2.VideoCapture(index)
    if not cap.isOpened():
        raise RuntimeError(f"Error: Could not open webcam {index}.")
    if verbose:
        print(f"Camera {index} opened successfully.")
    return cap


# Read current frame
def read_frame(cap):
    ret, frame = cap.read()
    if not ret:
        raise RuntimeError("Failed to capture image from webcam.")
    return frame


# Calculate frame center
def calculate_center(frame):
    height, width = frame.shape[:2]
    x_center, y_center = width / 2, height / 2
    return x_center, y_center


# Check if class is in desired classes
def valid_class(box, class_names=CLASS_NAMES, desired_classes=DESIRED_CLASSES):
    return class_names[int(box.cls)] in desired_classes


# Draw bounding box
def draw_bounding_box(frame, box, class_names=CLASS_NAMES, verbose=VERBOSE):
    x1, y1, x2, y2 = map(int, box.xyxy[0])
    cv2.rectangle(frame, (x1, y1), (x2, y2), (255, 0, 255), 3)
    
    cls = int(box.cls[0])
    confidence = math.ceil((box.conf[0] * 100)) / 100
    
    org = [x1, y1]
    font = cv2.FONT_HERSHEY_SIMPLEX
    font_scale = 1
    color = (255, 0, 0)
    thickness = 2
    cv2.putText(frame, class_names[cls], org, font, font_scale, color, thickness)
    
    height, width = abs(y2 - y1), abs(x2 - x1)
    area = height * width
    
    if verbose:
        print(f"Class: {class_names[cls]}, Confidence: {confidence}")
    
    return height, width, area


# Draw movement vector
def draw_movement_vector(frame, box, balloon_position, vector_history, avg_dt, prev_position=None, verbose=VERBOSE):
    x1, y1, x2, y2 = map(int, box.xyxy[0])
    cx_pixel, cy_pixel = int((x1 + x2) / 2), int((y1 + y2) / 2)
    x, y, z = float(balloon_position[0]), float(balloon_position[1]), float(balloon_position[2])

    if len(vector_history) == 0:
        base_px, base_py, base_pz = prev_position if prev_position is not None else (x, y, z)
    else:
        base_px = sum(p[0] for p in vector_history) / len(vector_history)
        base_py = sum(p[1] for p in vector_history) / len(vector_history)
        base_pz = sum(p[2] for p in vector_history) / len(vector_history)

    dx_w, dy_w, dz_w = x - base_px, y - base_py, z - base_pz
    mag_w = math.sqrt(dx_w**2 + dy_w**2 + dz_w**2)
    vel_w = mag_w / avg_dt

    if mag_w > 1e-9:
        ux, uy = dx_w / mag_w, dz_w / mag_w
        length_px = mag_w * PIXELS_PER_UNIT
        length_px = max(VECTOR_MIN_LENGTH, min(length_px, VECTOR_MAX_LENGTH))
        
        end_x = int(cx_pixel - ux * length_px)
        end_y = int(cy_pixel - uy * length_px)
        cv2.arrowedLine(frame, (cx_pixel, cy_pixel), (end_x, end_y), (0, 0, 255), 3, tipLength=0.3)

    vector_history.append((x, y, z))
    new_prev_position = (x, y, z)

    if verbose:
        print(f"3D displacement: ({dx_w:.3f}, {dy_w:.3f}, {dz_w:.3f})")
        print(f"Velocity: {vel_w:.3f} {DISTANCE_UNIT}/s")

    return new_prev_position

# %%
# Calculations

# Calculate balloon coordinates
def triangulation(angles: dict, d=CAMERA_DISTANCE, verbose=VERBOSE):
    alpha = np.radians(angles['x1'])
    beta = np.radians(angles['x2']-90)
    gamma = np.radians(90-angles['y1'])
    delta = np.radians(90-angles['y2'])
    
    if (np.sin(alpha + beta)) == 0:
        raise ValueError("Invalid angles for triangulation.")
    
    n = d * np.sin(beta) / np.sin(alpha + beta)
    m = d * np.sin(alpha) / np.sin(alpha + beta)

    x1 = n * np.cos(alpha)
    y1 = n * np.sin(alpha)
    z1 = n * np.tan(gamma)
    
    x2 = d - (m * np.cos(beta))
    y2 = m * np.sin(beta)
    z2 = m * np.tan(delta)

    x = (x1 + x2) / 2
    y = (y1 + y2) / 2
    z = (z1 + z2) / 2
    
    if verbose:
        print(f"Balloon position: ({x:.2f}, {y:.2f}, {z:.2f})")
    
    return np.array([x, y, z])


# Calculate distance to camera
def get_distance(camera, balloon_position, d=CAMERA_DISTANCE, verbose=VERBOSE):
    if camera == 'C1':
        camera_position = np.array([0, 0, 0])
    elif camera == 'C2':
        camera_position = np.array([d, 0, 0])
    else:
        raise ValueError("Invalid camera ID. Use 'C1' or 'C2'.")
    
    distance = np.linalg.norm(balloon_position - camera_position)
    
    if verbose:
        print(f"{camera} Distance: {distance:.2f} {DISTANCE_UNIT}")
    
    return distance


# Compute Lyapunov exponent
def compute_lyapunov_exponent(positions, dt, method="pca", emb_dim=6, tau=1, min_tsep=10, trajectory_len=20, debug_plot=True):
    positions = np.array(positions)
    if positions.shape[1] != 3:
        raise ValueError("Positions must be of shape (N,3).")

    if method.lower() == "pca":
        pca = PCA(n_components=1)
        scalar_series = pca.fit_transform(positions).flatten()
    elif method.lower() == "norm":
        scalar_series = np.linalg.norm(positions, axis=1)
    elif method.lower() in ["x", "y", "z"]:
        idx = {"x":0, "y":1, "z":2}[method.lower()]
        scalar_series = positions[:, idx]
    else:
        raise ValueError("Invalid method. Choose 'pca', 'norm', 'x', 'y', or 'z'.")

    scalar_series = (scalar_series - np.mean(scalar_series)) / (np.std(scalar_series) + 1e-12)

    lyap_raw = nolds.lyap_r(
        scalar_series,
        emb_dim=emb_dim,
        tau=tau,
        min_tsep=min_tsep,
        trajectory_len=trajectory_len,
        debug_plot=debug_plot
    )
    lyap_exp = lyap_raw / dt
    lyap_time = 1 / lyap_exp if lyap_exp > 0 else float('inf')

    return lyap_exp, lyap_time

# %%
# PID controller

# Initialize PID controller
def init_pid(x_center, y_center, verbose=VERBOSE):
    pid_pan = PID(Kp=PID_KP, Ki=PID_KI, Kd=PID_KD, setpoint=x_center)
    pid_pan.output_limits = PID_OUTPUT_LIMITS
    pid_tilt = PID(Kp=PID_KP, Ki=PID_KI, Kd=PID_KD, setpoint=y_center)
    pid_tilt.output_limits = PID_OUTPUT_LIMITS
    if verbose:
        print("PID controller initialized.")
    return pid_pan, pid_tilt


# Calculate corrections using PID controller
def calculate_corrections(box, pid_pan, pid_tilt, prev_pan, prev_tilt, verbose=VERBOSE):
    x1, y1, x2, y2 = box.xyxy[0]
    x_box = float((x1 + x2) / 2)
    y_box = float((y1 + y2) / 2)
    
    pan_raw = pid_pan(x_box)
    tilt_raw = pid_tilt(y_box)
    pan = ALPHA * pan_raw + (1 - ALPHA) * prev_pan
    tilt = ALPHA * tilt_raw + (1 - ALPHA) * prev_tilt
    
    if verbose:
        print(f"Box: ({x_box}, {y_box})")
        print(f"Pan: {pan}, Tilt: {tilt}")
    return pan, tilt


# Update servo angle
def update_angle(servo_angle, correction):
    if correction > 10:
        correction = 10
    elif correction < -10:
        correction = -10
    elif abs(correction) < SERVO_MIN_STEP:
        correction = 0
    return max(SERVO_MIN, min(SERVO_MAX, math.ceil(servo_angle + correction)))

# %%
# Arduino

# Initialize serial connection to arduino
def init_arduino(*, port=ARDUINO_PORT, baudrate=ARDUINO_BAUDRATE, initial_angles=SERVO_INIT, verbose=VERBOSE):
    try:
        arduino = serial.Serial(port, baudrate)
        time.sleep(2)
        if verbose:
            print(f"Connected to Arduino on {port} at {baudrate} baud.")
        move_servos(arduino, initial_angles)
        return arduino
    except serial.SerialException as e:
        raise RuntimeError(f"Could not connect to Arduino on {port}: {e}")


# Move servos
def move_servos(arduino, angles: dict, verbose=VERBOSE):
    try:
        command = f"{angles['x1']},{angles['y1']},{angles['x2']},{angles['y2']}\n"
        arduino.write(command.encode())
        arduino.flush()
        if verbose:
            print(f"C1 → X: {angles['x1']:.1f}°, Y: {angles['y1']:.1f}°")
            print(f"C2 → X: {angles['x2']:.1f}°, Y: {angles['y2']:.1f}°")
    except serial.SerialException as e:
        print(f"Serial communication error: {e}")


# Rotate servos to scan environment
def rotate_servos(arduino, angles: dict, pos, c1=True, c2=True, step=SERVO_SCAN_STEP, delay=DELAY_BETWEEN_SERVO_MOVEMENTS, verbose=VERBOSE):
    try:
        if verbose:
            print(f"Scanning environment...")
        if c1:
            angles['x1'] = (step * pos) % SERVO_MAX
            if (step * pos) > (2 * SERVO_MAX):
                angles['y1'] = 40
            elif (5 * pos) > SERVO_MAX:
                angles['y1'] = 65
            else:
                angles['y1'] = 90
            if verbose:
                print(f"Rotating C1 to x={angles['x1']}, y={angles['y1']}")
        if c2:
            angles['x2'] = (step * pos) % SERVO_MAX
            if (step * pos) > (2 * SERVO_MAX):
                angles['y2'] = 40
            elif (5 * pos) > SERVO_MAX:
                angles['y2'] = 65
            else:
                angles['y2'] = 90
            if verbose:
                print(f"Rotating C2 to x={angles['x2']}, y={angles['y2']}")
        command = f"{angles['x1']},{angles['y1']},{angles['x2']},{angles['y2']}\n"
        arduino.write(command.encode())
        arduino.flush()
        time.sleep(DELAY_BETWEEN_SERVO_MOVEMENTS)
    except serial.SerialException as e:
        print(f"Serial communication error: {e}")

# %%
# Flight prediction

# Calculate latitude and longitude
def calculate_lat_lon(x, y, lat0=LAT_INIT, lon0=LON_INIT, theta_deg=0):
    theta_rad = np.radians(theta_deg)
    
    x_geo = x * np.cos(theta_rad) - y * np.sin(theta_rad)
    y_geo = x * np.sin(theta_rad) + y * np.cos(theta_rad)
    
    delta_lat = (y_geo / R) * (180 / np.pi)
    
    lat0_rad = np.radians(lat0)
    delta_lon = (x_geo / (R * np.cos(lat0_rad))) * (180 / np.pi)
    
    lat1 = lat0 + delta_lat
    lon1 = lon0 + delta_lon
    
    return lat1, lon1


# Convert latitude and longitude to x, y coordinates
def lat_lon_to_xy(lat1, lon1, lat0=LAT_INIT, lon0=LON_INIT, theta_degrees=0):
    
    theta_rad = np.radians(theta_degrees)
    
    y_aligned = (lat1 - lat0) * (np.pi / 180) * R
    lat0_rad = np.radians(lat0)
    x_aligned = (lon1 - lon0) * (np.pi / 180) * R * np.cos(lat0_rad)
    
    x = x_aligned * np.cos(theta_rad) + y_aligned * np.sin(theta_rad)
    y = -x_aligned * np.sin(theta_rad) + y_aligned * np.cos(theta_rad)
    
    return x, y


# Get wind data from OpenWeatherMap API
def get_wind_data(lat, lon, api_key=API_KEY, hour=0):
    url = f"https://api.openweathermap.org/data/3.0/onecall?lat={lat}&lon={lon}&appid={api_key}"
    
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()
        
        if hour == 0:
            wind_speed = data['current']['wind_speed']
            wind_deg = data['current']['wind_deg']
        else:
            wind_speed = data['hourly'][hour - 1]['wind_speed']
            wind_deg = data['hourly'][hour - 1]['wind_deg']
        
        return wind_speed, wind_deg
    
    except (requests.exceptions.RequestException, KeyError, IndexError) as error:
        print(f"Error retrieving wind data: {error}")
        return None, None


# Move balloon one hour based on wind data
def move_balloon_one_hour(lat0, lon0, wind_speed, wind_deg):        
    displacement_m = wind_speed * 3600
    
    wind_rad = np.radians(wind_deg)
    
    displacement_ew = displacement_m * np.sin(wind_rad)
    displacement_ns = displacement_m * np.cos(wind_rad)
    
    delta_lat = (displacement_ns / R) * (180 / np.pi)
    
    lat0_rad = np.radians(lat0)
    delta_lon = (displacement_ew / (R * np.cos(lat0_rad))) * (180 / np.pi)
    
    lat_final = lat0 + delta_lat
    lon_final = lon0 + delta_lon
    
    return lat_final, lon_final


# Predict balloon flight over 48 hours
def predict_balloon_flight(lat_init, lon_init, api_key=API_KEY, verbose=VERBOSE):    
    positions = []
    lat_current = lat_init
    lon_current = lon_init
    if verbose:
        print(f"Starting prediction at lat: {lat_current}, lon: {lon_current}")
    
    for hour in range(49):
        wind_speed, wind_deg = get_wind_data(lat_current, lon_current, api_key, hour)
        
        if verbose and (wind_speed is None or wind_deg is None):
            print(f"Skipping hour {hour} due to missing wind data.")
            continue
        
        lat_current, lon_current = move_balloon_one_hour(lat_current, lon_current, wind_speed, wind_deg)
        positions.append((lat_current, lon_current))
        
        if verbose:
            print(f"Hour {hour}: {positions[hour]} --> (Speed = {wind_speed} m/s, Deg = {wind_deg}°)")
    return positions


# Plot trajectory on graphs
def plot_graph_trajectory(data):
    lats = [p[0] for p in data]
    lons = [p[1] for p in data]
    hours = list(range(len(data)))
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 7))
    
    ax1.plot(lons, lats, 'b-', linewidth=2, label='Trajetória do balão')
    ax1.scatter(lons[0], lats[0], color='green', s=200, zorder=5, label='Início (hora 0)', marker='o')
    ax1.scatter(lons[-1], lats[-1], color='red', s=200, zorder=5, label='Fim (hora 48)', marker='X')
    
    for i in range(0, len(data), 6):
        ax1.annotate(f'{i}h', (lons[i], lats[i]), fontsize=8, ha='center')
    
    ax1.set_xlabel('Longitude (°)', fontsize=12)
    ax1.set_ylabel('Latitude (°)', fontsize=12)
    ax1.set_title('Trajetória do Balão - 48 Horas', fontsize=14, fontweight='bold')
    ax1.grid(True, alpha=0.3)
    ax1.legend(fontsize=10)
    ax1.invert_yaxis()
    
    ax2_lat = ax2
    ax2_lon = ax2.twinx()
    
    line1 = ax2_lat.plot(hours, lats, 'b-', linewidth=2, label='Latitude')
    ax2_lat.set_xlabel('Tempo (horas)', fontsize=12)
    ax2_lat.set_ylabel('Latitude (°)', fontsize=12, color='b')
    ax2_lat.tick_params(axis='y', labelcolor='b')
    ax2_lat.grid(True, alpha=0.3)
    
    line2 = ax2_lon.plot(hours, lons, 'r-', linewidth=2, label='Longitude')
    ax2_lon.set_ylabel('Longitude (°)', fontsize=12, color='r')
    ax2_lon.tick_params(axis='y', labelcolor='r')
    
    ax2.set_title('Evolução de Latitude e Longitude', fontsize=14, fontweight='bold')
    
    lines = line1 + line2
    labels = [l.get_label() for l in lines]
    ax2_lat.legend(lines, labels, loc='upper left', fontsize=10)
    
    plt.tight_layout()
    plt.show()


# Plot map trajectory
def plot_map_trajectory(data):
    centro_lat = (data[0][0] + data[-1][0]) / 2
    centro_lon = (data[0][1] + data[-1][1]) / 2
    
    mapa = folium.Map(
        location=[centro_lat, centro_lon],
        zoom_start=8,
        tiles='OpenStreetMap'
    )
    
    folium.PolyLine(
        data,
        color='blue',
        weight=3,
        opacity=0.8,
        popup='Trajetória do balão'
    ).add_to(mapa)
    
    folium.Marker(
        location=data[0],
        popup='<b>Início</b><br>Hora 0<br>São Paulo',
        icon=folium.Icon(color='green', icon='play'),
        tooltip='Início (hora 0)'
    ).add_to(mapa)
    
    folium.Marker(
        location=data[-1],
        popup='<b>Fim</b><br>Hora 48<br>SC/PR',
        icon=folium.Icon(color='red', icon='stop'),
        tooltip='Fim (hora 48)'
    ).add_to(mapa)
    
    for i in range(6, len(data), 6):
        folium.CircleMarker(
            location=data[i],
            radius=5,
            popup=f'<b>Hora {i}</b><br>Lat: {data[i][0]:.4f}<br>Lon: {data[i][1]:.4f}',
            color='blue',
            fill=True,
            fillOpacity=0.7,
            tooltip=f'Hora {i}'
        ).add_to(mapa)
    
    for i in range(0, len(data), 6):
        folium.Marker(
            location=data[i],
            icon=folium.DivIcon(html=f'''
                <div style="font-size: 12pt; color: black; font-weight: bold; 
                            background-color: white; border-radius: 50%; 
                            width: 25px; height: 25px; text-align: center; line-height: 25px;">
                    {i}h
                </div>'''),
            popup=f'Hora {i}'
        ).add_to(mapa)
    
    mapa.save('trajetoria_balao.html')
    webbrowser.open('file://' + os.path.realpath('trajetoria_balao.html'))
    
    hti = Html2Image()
    hti.screenshot(
        html_file='trajetoria_balao.html',
        save_as='trajetoria_balao.png',
        size=(1200, 800)
    )

# %%
# Drive upload

# Authenticate and create Google Drive service
def authenticate_drive():
    creds = None

    if os.path.exists("token.pickle"):
        with open("token.pickle", "rb") as f:
            creds = pickle.load(f)

    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file("credentials.json", SCOPES)
            creds = flow.run_local_server(port=0)

        with open("token.pickle", "wb") as f:
            pickle.dump(creds, f)

    return build("drive", "v3", credentials=creds)


# Create folder to store frames in Google Drive
def create_folder(service, name):
    folder_metadata = {
        "name": name,
        "mimeType": "application/vnd.google-apps.folder"
    }

    folder = service.files().create(
        body=folder_metadata,
        fields="id"
    ).execute()

    return folder["id"]


# Upload frame to Google Drive
def upload_frame(service, frame, folder_id, code):
    global last_positive_c1_upload_time, last_positive_c2_upload_time, last_negative_c1_upload_time, last_negative_c2_upload_time, frame_count
    now = time.time()
    
    y1 = code == 'Y1' and now - last_positive_c1_upload_time >= POSITIVE_IMAGE_UPLOAD_INTERVAL
    y2 = code == 'Y2' and now - last_positive_c2_upload_time >= POSITIVE_IMAGE_UPLOAD_INTERVAL
    n1 = code == 'N1' and now - last_negative_c1_upload_time >= NEGATIVE_IMAGE_UPLOAD_INTERVAL
    n2 = code == 'N2' and now - last_negative_c2_upload_time >= NEGATIVE_IMAGE_UPLOAD_INTERVAL

    if y1 or y2 or n1 or n2:
        _, buffer = cv2.imencode(".jpg", frame)
        file_bytes = io.BytesIO(buffer)

        media = MediaIoBaseUpload(file_bytes, mimetype="image/jpeg")
        
        filename = f"{code}_{frame_count}"

        file_metadata = {
            "name": filename,
            "parents": [folder_id]
        }

        service.files().create(
            body=file_metadata,
            media_body=media
        ).execute()
        
        if n1:
            last_negative_c1_upload_time = now
        elif n2:
            last_negative_c2_upload_time = now
        elif y1:
            last_positive_c1_upload_time = now
        elif y2:
            last_positive_c2_upload_time = now
        n1, n2, y1, y2 = False, False, False, False

# %%
# Telegram alert

# Check if enough time has passed since last alert
def valid_time(current_time, last_time, interval):
    return (current_time - last_time) >= interval


# Send Telegram alert with balloon coordinates
def send_telegram_alert(position, lat, lon, dist_c1, dist_c2, height=None, width=None, area=None, map=True):
    x, y, z = position
    message = f"🎈 Balão detectado!\n" \
            f"📍 Coordenadas: x={x:.2f}, y={y:.2f}, z={z:.2f}\n"
    
    if lat is not None and lon is not None:
        message += f"📡 Localização aproximada: lat={lat:.4f}, lon={lon:.4f}\n"
    if dist_c1 is not None:
        message += f"📏 Distância C1: {dist_c1:.2f} cm\n"
    if dist_c2 is not None:
        message += f"📏 Distância C2: {dist_c2:.2f} cm\n"
    if height is not None and width is not None and area is not None:
        message += f"📐 Tamanho do objeto: {height:.1f}x{width:.1f} pixels (Área: {area:.1f} px²)\n"

    url = f"https://api.telegram.org/bot{TOKEN}/sendMessage"
    data = {"chat_id": CHAT_ID, "text": message}
    response = requests.post(url, data=data)
    
    if response.status_code == 200:
        print("📩 Coordenadas enviadas com sucesso!")
    else:
        print("⚠️ Erro ao enviar coordenadas:", response.text)
    
    if map:
        try:
            with open("trajetoria_balao.html", "rb") as f:
                requests.post(
                    f"https://api.telegram.org/bot{TOKEN}/sendDocument",
                    data={"chat_id": CHAT_ID},
                    files={"document": f}
                )
            with open("trajetoria_balao.png", "rb") as f:
                requests.post(
                    f"https://api.telegram.org/bot{TOKEN}/sendPhoto",
                    data={"chat_id": CHAT_ID},
                    files={"photo": f}
                )
        except Exception as e:
            print("⚠️ Erro ao enviar mapa:", e)

# %%
# Print functions

# Print divider
def print_div(text):
    print("\n" + f" {text} ".center(100, '-') + "\n")


# Print available cameras
def print_cameras():
    for camera_info in enumerate_cameras():
        print(f'{camera_info.index}: {camera_info.name}')


# Print final information
def final_prints(frame_count, x1_center, y1_center, x2_center, y2_center, frame_delay, balloon_position, dist_c1, dist_c2, servo_angles, lyap_exp, lyap_time):
    x, y, z = balloon_position
    print(f"Total frames: {frame_count}, Total time: {frame_delay*frame_count:.2f} seconds")
    print(f"Detected classes: {DESIRED_CLASSES}")
    print(f"Frame centers: ({x1_center}, {y1_center}), ({x2_center}, {y2_center})")
    print(f"FPS: {(1/frame_delay):.2f}")
    print(f"Final balloon position: ({x:.2f}, {y:.2f}, {z:.2f})")
    print(f"Final C1 distance: {dist_c1:.2f} {DISTANCE_UNIT}")
    print(f"Final C2 distance: {dist_c2:.2f} {DISTANCE_UNIT}")
    print(f"Servo angles: {servo_angles}")
    print(f"Lyapunov exponent: {lyap_exp:.4f} per second")
    if lyap_time != float('inf'):
        print(f"Predictability horizon: {lyap_time:.2f} seconds\n")
    else:
        print("Predictability horizon: Infinite (non-chaotic behavior)\n")

# %%
# Main program
print_div("Available cameras")
print_cameras()

print_div("Initial settings")
frame_count, total_time, last_alert_time= 0, 0, 0
last_positive_c1_upload_time, last_positive_c2_upload_time = 0, 0
last_negative_c1_upload_time, last_negative_c2_upload_time = 0, 0
last_prediction_time, first_time, second_time = 0, True, False
last_double_scan_time, last_single_scan_time, times_scanned = 0, 0, 0
prev_time = time.time()
lost_c1, lost_c2 = 51, 51

SERVO_INIT = {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
servo_angles = SERVO_INIT
vector_history = deque(maxlen=VECTOR_HISTORY_SIZE)
prev_position = None
balloon_position = triangulation(servo_angles)
balloon_positions_history = []
rotate_angles = {'x1': 0, 'y1': 0, 'x2': 0, 'y2': 0}

arduino = init_arduino(initial_angles=servo_angles)
service = authenticate_drive()
folder_id = create_folder(service, "frames")

cap1 = init_camera(CAMERA_INDEX_1)
cap2 = init_camera(CAMERA_INDEX_2)
frame1 = read_frame(cap1)
frame2 = read_frame(cap2)

x1_center, y1_center = calculate_center(frame1)
x2_center, y2_center = calculate_center(frame2)
height1, width1, area1 = 0, 0, 0
height2, width2, area2 = 0, 0, 0

pid_pan1, pid_tilt1 = init_pid(x1_center, y1_center)
pid_pan2, pid_tilt2 = init_pid(x2_center, y2_center)
prev_pan1, prev_tilt1 = 0, 0
prev_pan2, prev_tilt2 = 0, 0

print_div("Program started")
try:
    while True:
        print(f"Frame number: {frame_count}")
        current_time = time.time()
        frame_delay = current_time - prev_time
        total_time += frame_delay
        avg_frame_delay = total_time / frame_count if frame_count > 0 else frame_delay
        prev_time = current_time
        
        x1_correction, y1_correction = 0, 0
        detected_c1 = False
        frame1 = read_frame(cap1)
        results1 = MODEL(frame1, stream=True)
        for r1 in results1:
            if not r1.boxes:
                continue
            for box1 in r1.boxes:
                if valid_class(box1):
                    detected_c1 = True
                    upload_frame(service, frame1, folder_id, 'Y1')
                    height1, width1, area1 = draw_bounding_box(frame1, box1)
                    prev_position = draw_movement_vector(frame1, box1, balloon_position, vector_history, avg_frame_delay, prev_position)
                    x1_correction, y1_correction = calculate_corrections(box1, pid_pan1, pid_tilt1, prev_pan1, prev_tilt1)
                    prev_pan1, prev_tilt1 = x1_correction, y1_correction
        
        x2_correction, y2_correction = 0, 0
        detected_c2 = False
        frame2 = read_frame(cap2)
        results2 = MODEL(frame2, stream=True)
        for r2 in results2:
            if not r2.boxes:
                continue
            for box2 in r2.boxes:
                if valid_class(box2):
                    detected_c2 = True
                    upload_frame(service, frame2, folder_id, 'Y2')
                    height2, width2, area2 = draw_bounding_box(frame2, box2)
                    prev_position = draw_movement_vector(frame2, box2, balloon_position, vector_history, avg_frame_delay, prev_position)
                    x2_correction, y2_correction = calculate_corrections(box2, pid_pan2, pid_tilt2, prev_pan2, prev_tilt2)
                    prev_pan2, prev_tilt2 = x2_correction, y2_correction
        
        c1_change = x1_correction != 0 or y1_correction != 0
        c2_change = x2_correction != 0 or y2_correction != 0
        lost_c1 = 0 if detected_c1 else (lost_c1 + 1)
        lost_c2 = 0 if detected_c2 else (lost_c2 + 1)
        
        if detected_c1 == False:
            upload_frame(service, frame1, folder_id, 'N1')
        if detected_c2 == False:
            upload_frame(service, frame2, folder_id, 'N2')
        
        if c1_change and c2_change:
            balloon_position = triangulation(servo_angles)
            balloon_positions_history.append(balloon_position.copy())
            dist_c1 = get_distance('C1', balloon_position)
            dist_c2 = get_distance('C2', balloon_position)
            print(f"Servo angles: {servo_angles}")
            
            if first_time:
                last_prediction_time = current_time
                first_time, second_time = False, True
                
            elif valid_time(current_time, last_prediction_time, PREDICTION_INTERVAL) or (second_time and valid_time(current_time, last_prediction_time, FIRST_PREDICTION_INTERVAL)):
                lat, lon = calculate_lat_lon(balloon_position[0], balloon_position[1])
                #predictions = predict_balloon_flight(lat, lon)
                #plot_graph_trajectory(predictions)
                #plot_map_trajectory(predictions)
                #lyap_exp, lyap_time = compute_lyapunov_exponent(balloon_positions_history, avg_frame_delay)
                #send_telegram_alert(balloon_position, lat, lon, dist_c1, dist_c2, height=max(height1, height2), width=max(width1, width2), area=max(area1, area2))
                last_prediction_time, second_time = current_time, False
        
        if c1_change:
            y1_correction *= -1 # type: ignore
            servo_angles['x1'] = update_angle(servo_angles['x1'], x1_correction)
            servo_angles['y1'] = update_angle(servo_angles['y1'], y1_correction)
        
        if c2_change:
            y2_correction *= -1 # type: ignore
            servo_angles['x2'] = update_angle(servo_angles['x2'], x2_correction)
            servo_angles['y2'] = update_angle(servo_angles['y2'], y2_correction)
        
        if c1_change or c2_change:
            move_servos(arduino, servo_angles)
            last_double_scan_time, last_single_scan_time = current_time, current_time
        
        valid_double_scan_time = valid_time(current_time, last_double_scan_time, SERVO_DOUBLE_SCAN_INTERVAL)
        valid_single_scan_time = valid_time(current_time, last_single_scan_time, SERVO_SINGLE_SCAN_INTERVAL)
        
        if not detected_c1 and not detected_c2:
            if ((times_scanned < (3 * SERVO_MAX / SERVO_SCAN_STEP)) or valid_double_scan_time) and (lost_c1 > 50 and lost_c2 > 50):
                if times_scanned >= (3 * SERVO_MAX / SERVO_SCAN_STEP):
                    times_scanned = 0
                rotate_angles = rotate_servos(arduino, servo_angles, times_scanned)
                last_double_scan_time = current_time
                times_scanned += 1
                
        elif not detected_c1:
            if ((times_scanned < (3 * SERVO_MAX / SERVO_SCAN_STEP)) or valid_single_scan_time) and lost_c1 > 50:
                if times_scanned >= (3 * SERVO_MAX / SERVO_SCAN_STEP):
                    times_scanned = 0
                rotate_angles = rotate_servos(arduino, servo_angles, times_scanned, c2=False)
                last_single_scan_time = current_time
                times_scanned += 1
                
        elif not detected_c2:
            if ((times_scanned < (3 * SERVO_MAX / SERVO_SCAN_STEP)) or valid_single_scan_time) and lost_c2 > 50:
                if times_scanned >= (3 * SERVO_MAX / SERVO_SCAN_STEP):
                    times_scanned = 0
                rotate_angles = rotate_servos(arduino, servo_angles, times_scanned, c1=False)
                last_single_scan_time = current_time
                times_scanned += 1
        
        frame_count += 1
        cv2.imshow("Image1", frame1)
        cv2.imshow("Image2", frame2)
        if cv2.waitKey(1) == ord('q'):
            break
finally:
    print_div("Program finished")
    #final_prints(frame_count, x1_center, y1_center, x2_center, y2_center, avg_frame_delay, 
                 #balloon_position, dist_c1, dist_c2, servo_angles, lyap_exp, lyap_time)
    cap1.release()
    cap2.release()
    cv2.destroyAllWindows()
    arduino.close()
# Out:
# ---------------------------------------- Available cameras -----------------------------------------
#
# 1200: USB Camera VID:1133 PID:2085
# 1201: C270 HD WEBCAM
# 1202: iPhone Leo Camera
# 1203: MacBook Air Camera
#
# ----------------------------------------- Initial settings -----------------------------------------
#
# Balloon position: (0.08, 0.16, 0.00)
# Connected to Arduino on /dev/cu.usbmodem11301 at 9600 baud.
# C1 → X: 65.0°, Y: 90.0°
# C2 → X: 115.0°, Y: 90.0°
# Camera 1200 opened successfully.
# Camera 1201 opened successfully.
# PID controller initialized.
# PID controller initialized.
#
# ----------------------------------------- Program started ------------------------------------------
#
# Frame number: 0
#
# 0: 480x640 1 person, 1 bed, 169.4ms
# Speed: 1.7ms preprocess, 169.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 147.8ms
# Speed: 1.1ms preprocess, 147.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Scanning environment...
# Rotating C1 to x=0, y=90
# Rotating C2 to x=0, y=90
# Frame number: 1
#
# 0: 480x640 1 person, 2 chairs, 2 tvs, 1 laptop, 190.0ms
# Speed: 8.7ms preprocess, 190.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 2 chairs, 1 tv, 121.8ms
# Speed: 0.9ms preprocess, 121.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Scanning environment...
# Rotating C1 to x=5, y=90
# Rotating C2 to x=5, y=90
# Frame number: 2
#
# 0: 480x640 1 person, 3 chairs, 1 laptop, 123.7ms
# Speed: 1.4ms preprocess, 123.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 119.8ms
# Speed: 0.9ms preprocess, 119.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Scanning environment...
# Rotating C1 to x=10, y=90
# Rotating C2 to x=10, y=90
# Frame number: 3
#
# 0: 480x640 1 person, 1 chair, 1 tv, 123.1ms
# Speed: 2.8ms preprocess, 123.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 119.8ms
# Speed: 0.9ms preprocess, 119.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Scanning environment...
# Rotating C1 to x=15, y=90
# Rotating C2 to x=15, y=90
# Frame number: 4
#
# 0: 480x640 1 person, 122.2ms
# Speed: 2.0ms preprocess, 122.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.5ms
# Speed: 0.9ms preprocess, 119.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Scanning environment...
# Rotating C1 to x=20, y=90
# Rotating C2 to x=20, y=90
# Frame number: 5
#
# 0: 480x640 1 person, 2 chairs, 124.7ms
# Speed: 2.4ms preprocess, 124.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.9ms
# Speed: 0.9ms preprocess, 117.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Scanning environment...
# Rotating C1 to x=25, y=90
# Rotating C2 to x=25, y=90
# Frame number: 6
#
# 0: 480x640 1 person, 1 motorcycle, 129.2ms
# Speed: 2.4ms preprocess, 129.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.1ms
# Speed: 0.9ms preprocess, 118.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Scanning environment...
# Rotating C1 to x=30, y=90
# Rotating C2 to x=30, y=90
# Frame number: 7
#
# 0: 480x640 1 person, 124.2ms
# Speed: 2.1ms preprocess, 124.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 117.9ms
# Speed: 0.9ms preprocess, 117.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Scanning environment...
# Rotating C1 to x=35, y=90
# Rotating C2 to x=35, y=90
# Frame number: 8
#
# 0: 480x640 1 person, 124.5ms
# Speed: 2.1ms preprocess, 124.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 116.2ms
# Speed: 0.9ms preprocess, 116.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Scanning environment...
# Rotating C1 to x=40, y=90
# Rotating C2 to x=40, y=90
# Frame number: 9
#
# 0: 480x640 1 person, 1 sports ball, 127.6ms
# Class: sports ball, Confidence: 0.63
# 3D displacement: (0.000, 0.000, 0.000)
# Velocity: 0.000 m/s
# Box: (491.69677734375, 431.6923828125)
# Pan: 0.6000000000000001, Tilt: 0.6000000000000001
# Speed: 2.9ms preprocess, 127.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 128.4ms
# Speed: 3.2ms preprocess, 128.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 40.0°, Y: 90.0°
# C2 → X: 40.0°, Y: 90.0°
# Scanning environment...
# Rotating C2 to x=45, y=90
# Frame number: 10
#
# 0: 480x640 1 person, 1 sports ball, 122.1ms
# Class: sports ball, Confidence: 0.29
# 3D displacement: (0.000, 0.000, 0.000)
# Velocity: 0.000 m/s
# Box: (175.70111083984375, 396.54132080078125)
# Pan: 1.08, Tilt: 1.08
# Speed: 1.9ms preprocess, 122.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 116.9ms
# Speed: 0.9ms preprocess, 116.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 42.0°, Y: 89.0°
# C2 → X: 45.0°, Y: 90.0°
# Scanning environment...
# Rotating C2 to x=50, y=90
# Frame number: 11
#
# 0: 480x640 1 person, 124.7ms
# Speed: 2.5ms preprocess, 124.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 116.5ms
# Speed: 0.9ms preprocess, 116.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 12
#
# 0: 480x640 1 person, 116.6ms
# Speed: 0.9ms preprocess, 116.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 117.1ms
# Speed: 0.9ms preprocess, 117.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 13
#
# 0: 480x640 1 person, 117.3ms
# Speed: 0.9ms preprocess, 117.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 117.3ms
# Speed: 1.0ms preprocess, 117.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 14
#
# 0: 480x640 1 person, 1 apple, 116.6ms
# Speed: 0.9ms preprocess, 116.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 117.8ms
# Speed: 0.9ms preprocess, 117.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 15
#
# 0: 480x640 1 person, 1 apple, 116.1ms
# Speed: 0.9ms preprocess, 116.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 113.7ms
# Speed: 0.9ms preprocess, 113.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 16
#
# 0: 480x640 1 person, 1 apple, 116.8ms
# Speed: 0.9ms preprocess, 116.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 117.3ms
# Speed: 0.9ms preprocess, 117.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 17
#
# 0: 480x640 1 person, 1 apple, 116.8ms
# Speed: 0.9ms preprocess, 116.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 118.0ms
# Speed: 0.9ms preprocess, 118.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 18
#
# 0: 480x640 1 person, 1 apple, 116.2ms
# Speed: 0.9ms preprocess, 116.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 118.6ms
# Speed: 0.9ms preprocess, 118.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 19
#
# 0: 480x640 1 person, 117.3ms
# Speed: 0.9ms preprocess, 117.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 117.8ms
# Speed: 0.9ms preprocess, 117.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 20
#
# 0: 480x640 1 person, 1 apple, 115.9ms
# Speed: 0.9ms preprocess, 115.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 118.1ms
# Speed: 0.9ms preprocess, 118.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 21
#
# 0: 480x640 1 person, 116.6ms
# Speed: 0.9ms preprocess, 116.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 118.1ms
# Speed: 0.9ms preprocess, 118.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 22
#
# 0: 480x640 1 person, 1 frisbee, 117.4ms
# Speed: 1.1ms preprocess, 117.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 118.0ms
# Speed: 0.9ms preprocess, 118.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 23
#
# 0: 480x640 1 person, 116.5ms
# Speed: 0.9ms preprocess, 116.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 117.6ms
# Speed: 0.9ms preprocess, 117.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 24
#
# 0: 480x640 1 person, 1 sports ball, 116.8ms
# Class: sports ball, Confidence: 0.87
# 3D displacement: (0.000, 0.000, 0.000)
# Velocity: 0.000 m/s
# Box: (359.17010498046875, 413.3876953125)
# Pan: 1.4640000000000002, Tilt: 1.4640000000000002
# Speed: 0.9ms preprocess, 116.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 117.8ms
# Speed: 0.9ms preprocess, 117.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 44.0°, Y: 88.0°
# C2 → X: 50.0°, Y: 90.0°
# Scanning environment...
# Rotating C2 to x=55, y=90
# Frame number: 25
#
# 0: 480x640 1 person, 1 apple, 128.5ms
# Speed: 2.7ms preprocess, 128.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 118.7ms
# Speed: 0.9ms preprocess, 118.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 26
#
# 0: 480x640 1 person, 1 sports ball, 1 apple, 117.0ms
# Class: sports ball, Confidence: 0.66
# 3D displacement: (0.000, 0.000, 0.000)
# Velocity: 0.000 m/s
# Box: (442.9419250488281, 415.9853820800781)
# Pan: 1.4432295975397231, Tilt: 1.7712000000000003
# Speed: 0.9ms preprocess, 117.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 115.9ms
# Speed: 0.9ms preprocess, 115.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 46.0°, Y: 87.0°
# C2 → X: 55.0°, Y: 90.0°
# Scanning environment...
# Rotating C2 to x=60, y=90
# Frame number: 27
#
# 0: 480x640 1 person, 1 sports ball, 1 apple, 123.4ms
# Class: sports ball, Confidence: 0.58
# 3D displacement: (0.000, 0.000, 0.000)
# Velocity: 0.000 m/s
# Box: (515.278564453125, 433.32708740234375)
# Pan: 1.1459382166128331, Tilt: 1.9213636625317971
# Speed: 2.5ms preprocess, 123.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 117.3ms
# Speed: 0.9ms preprocess, 117.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 48.0°, Y: 86.0°
# C2 → X: 60.0°, Y: 90.0°
# Scanning environment...
# Rotating C2 to x=65, y=90
# Frame number: 28
#
# 0: 480x640 1 person, 1 sports ball, 1 apple, 128.2ms
# Class: sports ball, Confidence: 0.26
# 3D displacement: (0.000, 0.000, 0.000)
# Velocity: 0.000 m/s
# Box: (543.2588500976562, 461.166015625)
# Pan: 1.428092606119121, Tilt: 1.8166257069598484
# Speed: 2.7ms preprocess, 128.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 116.9ms
# Speed: 0.9ms preprocess, 116.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 50.0°, Y: 85.0°
# C2 → X: 65.0°, Y: 90.0°
# Scanning environment...
# Rotating C2 to x=70, y=90
# Frame number: 29
#
# 0: 480x640 1 person, 1 apple, 129.2ms
# Speed: 2.6ms preprocess, 129.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 116.6ms
# Speed: 0.9ms preprocess, 116.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 30
#
# 0: 480x640 1 person, 1 apple, 116.0ms
# Speed: 0.9ms preprocess, 116.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 116.7ms
# Speed: 0.9ms preprocess, 116.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 31
#
# 0: 480x640 1 person, 1 apple, 116.2ms
# Speed: 0.9ms preprocess, 116.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.7ms
# Speed: 0.9ms preprocess, 117.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 32
#
# 0: 480x640 1 person, 1 apple, 116.0ms
# Speed: 0.9ms preprocess, 116.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 117.8ms
# Speed: 0.9ms preprocess, 117.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 33
#
# 0: 480x640 1 person, 1 apple, 117.3ms
# Speed: 0.9ms preprocess, 117.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.5ms
# Speed: 0.9ms preprocess, 118.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 34
#
# 0: 480x640 1 person, 1 apple, 115.9ms
# Speed: 0.9ms preprocess, 115.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 118.3ms
# Speed: 0.9ms preprocess, 118.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 35
#
# 0: 480x640 1 person, 1 apple, 116.7ms
# Speed: 0.9ms preprocess, 116.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 118.8ms
# Speed: 0.9ms preprocess, 118.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 36
#
# 0: 480x640 1 person, 1 sports ball, 116.9ms
# Class: sports ball, Confidence: 0.48
# 3D displacement: (0.000, 0.000, 0.000)
# Velocity: 0.000 m/s
# Box: (556.7275390625, 468.1132507324219)
# Pan: 1.7424740848952969, Tilt: 2.053300565567879
# Speed: 0.9ms preprocess, 116.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 117.9ms
# Speed: 0.9ms preprocess, 117.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 52.0°, Y: 83.0°
# C2 → X: 70.0°, Y: 90.0°
# Scanning environment...
# Rotating C2 to x=75, y=90
# Frame number: 37
#
# 0: 480x640 1 person, 1 sports ball, 125.7ms
# Class: sports ball, Confidence: 0.94
# 3D displacement: (0.000, 0.000, 0.000)
# Velocity: 0.000 m/s
# Box: (593.9346923828125, 502.18359375)
# Pan: 1.629119525657447, Tilt: 1.6977246245493027
# Speed: 2.4ms preprocess, 125.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.4ms
# Speed: 0.9ms preprocess, 117.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 54.0°, Y: 82.0°
# C2 → X: 75.0°, Y: 90.0°
# Scanning environment...
# Rotating C2 to x=80, y=90
# Frame number: 38
#
# 0: 480x640 1 person, 1 sports ball, 126.0ms
# Class: sports ball, Confidence: 0.49
# 3D displacement: (0.000, 0.000, 0.000)
# Velocity: 0.000 m/s
# Box: (486.3011779785156, 479.0517578125)
# Pan: 1.903295620525958, Tilt: 1.9581796996394423
# Speed: 2.7ms preprocess, 126.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.1ms
# Speed: 0.9ms preprocess, 117.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 56.0°, Y: 81.0°
# C2 → X: 80.0°, Y: 90.0°
# Scanning environment...
# Rotating C2 to x=85, y=90
# Frame number: 39
#
# 0: 480x640 1 person, 1 sports ball, 128.4ms
# Class: sports ball, Confidence: 0.68
# 3D displacement: (0.000, 0.000, 0.000)
# Velocity: 0.000 m/s
# Box: (420.2862548828125, 528.9949951171875)
# Pan: 2.1226364964207667, Tilt: 1.284140035899643
# Speed: 2.5ms preprocess, 128.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.3ms
# Speed: 0.9ms preprocess, 117.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 59.0°, Y: 80.0°
# C2 → X: 85.0°, Y: 90.0°
# Scanning environment...
# Rotating C2 to x=90, y=90
# Frame number: 40
#
# 0: 480x640 1 person, 1 sports ball, 127.5ms
# Class: sports ball, Confidence: 0.95
# 3D displacement: (0.000, 0.000, 0.000)
# Velocity: 0.000 m/s
# Box: (519.751953125, 621.701171875)
# Pan: 1.3013645963039935, Tilt: 0.4273120287197145
# Speed: 2.7ms preprocess, 127.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 sports ball, 116.6ms
# Class: sports ball, Confidence: 0.9
# 3D displacement: (0.000, 0.000, 0.000)
# Velocity: 0.000 m/s
# Box: (78.33857727050781, 417.8090515136719)
# Pan: 0.6000000000000001, Tilt: 0.6000000000000001
# Speed: 0.9ms preprocess, 116.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Balloon position: (0.00, 0.00, 0.00)
# C1 Distance: 0.00 m
# C2 Distance: 0.43 m
# Servo angles: {'x1': 59, 'y1': 80, 'x2': 90, 'y2': 90}
# C1 → X: 61.0°, Y: 80.0°
# C2 → X: 90.0°, Y: 90.0°
# Frame number: 41
#
# 0: 480x640 1 person, 1 sports ball, 123.1ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (-0.077, -0.165, 0.000)
# Velocity: 0.155 m/s
# Box: (561.59814453125, 613.9312744140625)
# Pan: 1.6068111600223205, Tilt: 0.19749451973049528
# Speed: 2.1ms preprocess, 123.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 sports ball, 117.2ms
# Class: sports ball, Confidence: 0.97
# 3D displacement: (-0.069, -0.148, 0.000)
# Velocity: 0.140 m/s
# Box: (173.50025939941406, 426.0506896972656)
# Pan: -0.12, Tilt: 0.8115033738257977
# Speed: 0.9ms preprocess, 117.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Balloon position: (0.00, 0.00, 0.00)
# C1 Distance: 0.00 m
# C2 Distance: 0.43 m
# Servo angles: {'x1': 61, 'y1': 80, 'x2': 90, 'y2': 90}
# C1 → X: 63.0°, Y: 80.0°
# C2 → X: 90.0°, Y: 90.0°
# Frame number: 42
#
# 0: 480x640 1 person, 1 sports ball, 116.4ms
# Class: sports ball, Confidence: 0.97
# 3D displacement: (-0.061, -0.132, 0.000)
# Velocity: 0.127 m/s
# Box: (598.2117919921875, 614.648681640625)
# Pan: 0.6854489280178564, Tilt: -0.10528222912115964
# Speed: 0.9ms preprocess, 116.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 sports ball, 117.2ms
# Class: sports ball, Confidence: 0.97
# 3D displacement: (-0.054, -0.115, 0.000)
# Velocity: 0.111 m/s
# Box: (167.9385223388672, 419.8054504394531)
# Pan: 0.5040000000000001, Tilt: 1.2492026990606382
# Speed: 0.9ms preprocess, 117.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Balloon position: (0.00, 0.00, 0.00)
# C1 Distance: 0.00 m
# C2 Distance: 0.43 m
# Servo angles: {'x1': 63, 'y1': 80, 'x2': 90, 'y2': 90}
# C1 → X: 63.0°, Y: 80.0°
# C2 → X: 90.0°, Y: 89.0°
# Frame number: 43
#
# 0: 480x640 1 person, 1 sports ball, 115.9ms
# Class: sports ball, Confidence: 0.97
# 3D displacement: (-0.046, -0.099, 0.000)
# Velocity: 0.097 m/s
# Box: (650.3812255859375, 614.6223754882812)
# Pan: -0.051640857585714905, Tilt: -0.3301063196723664
# Speed: 0.9ms preprocess, 115.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 sports ball, 118.1ms
# Class: sports ball, Confidence: 0.97
# 3D displacement: (-0.038, -0.082, 0.000)
# Velocity: 0.080 m/s
# Box: (167.23294067382812, 440.1060791015625)
# Pan: 1.0032, Tilt: 0.5798354702180075
# Speed: 0.9ms preprocess, 118.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Balloon position: (0.00, 0.00, 0.00)
# C1 Distance: 0.00 m
# C2 Distance: 0.43 m
# Servo angles: {'x1': 63, 'y1': 80, 'x2': 90, 'y2': 89}
# C1 → X: 63.0°, Y: 80.0°
# C2 → X: 92.0°, Y: 89.0°
# Frame number: 44
#
# 0: 480x640 1 person, 1 sports ball, 117.7ms
# Class: sports ball, Confidence: 0.97
# 3D displacement: (-0.031, -0.066, 0.004)
# Velocity: 0.065 m/s
# Box: (648.0570068359375, 615.6517333984375)
# Pan: 0.5586873139314281, Tilt: -0.5984790283726982
# Speed: 0.9ms preprocess, 117.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 sports ball, 118.4ms
# Class: sports ball, Confidence: 0.97
# 3D displacement: (-0.023, -0.049, 0.003)
# Velocity: 0.049 m/s
# Box: (203.49417114257812, 449.12664794921875)
# Pan: 0.6754252547415498, Tilt: 0.6498389674511695
# Speed: 0.9ms preprocess, 118.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Balloon position: (0.01, 0.01, 0.01)
# C1 Distance: 0.02 m
# C2 Distance: 0.42 m
# Servo angles: {'x1': 63, 'y1': 80, 'x2': 92, 'y2': 89}
# C1 → X: 63.0°, Y: 80.0°
# C2 → X: 92.0°, Y: 89.0°
# Frame number: 45
#
# 0: 480x640 1 person, 1 sports ball, 116.9ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (-0.008, -0.018, 0.004)
# Velocity: 0.019 m/s
# Box: (657.5943603515625, 627.83154296875)
# Pan: 0.4533782214106661, Tilt: -1.0787832226981586
# Speed: 0.9ms preprocess, 116.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 sports ball, 118.4ms
# Class: sports ball, Confidence: 0.97
# 3D displacement: (-0.001, -0.003, 0.004)
# Velocity: 0.005 m/s
# Box: (251.02442932128906, 451.9490966796875)
# Pan: -0.05965979620676021, Tilt: 1.0452465472307182
# Speed: 0.9ms preprocess, 118.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Balloon position: (0.01, 0.01, 0.01)
# C1 Distance: 0.02 m
# C2 Distance: 0.42 m
# Servo angles: {'x1': 63, 'y1': 80, 'x2': 92, 'y2': 89}
# C1 → X: 63.0°, Y: 82.0°
# C2 → X: 92.0°, Y: 88.0°
# Frame number: 46
#
# 0: 480x640 1 person, 1 sports ball, 116.5ms
# Class: sports ball, Confidence: 0.95
# 3D displacement: (0.006, 0.012, 0.003)
# Velocity: 0.013 m/s
# Box: (664.5481567382812, 627.8446655273438)
# Pan: 0.48505546315703096, Tilt: -1.2336565743643597
# Speed: 0.9ms preprocess, 116.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 sports ball, 118.0ms
# Class: sports ball, Confidence: 0.97
# 3D displacement: (0.005, 0.010, 0.003)
# Velocity: 0.011 m/s
# Box: (259.93890380859375, 459.66766357421875)
# Pan: 0.5522721630345919, Tilt: 1.062373250082524
# Speed: 0.9ms preprocess, 118.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Balloon position: (0.01, 0.01, 0.01)
# C1 Distance: 0.02 m
# C2 Distance: 0.42 m
# Servo angles: {'x1': 63, 'y1': 82, 'x2': 92, 'y2': 88}
# C1 → X: 63.0°, Y: 84.0°
# C2 → X: 92.0°, Y: 87.0°
# Frame number: 47
#
# 0: 480x640 1 person, 1 sports ball, 116.0ms
# Class: sports ball, Confidence: 0.97
# 3D displacement: (0.005, 0.009, 0.006)
# Velocity: 0.011 m/s
# Box: (663.413330078125, 593.1744384765625)
# Pan: 0.9654393053506105, Tilt: -0.3869252594914877
# Speed: 0.9ms preprocess, 116.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 sports ball, 117.6ms
# Class: sports ball, Confidence: 0.98
# 3D displacement: (0.004, 0.007, 0.005)
# Velocity: 0.009 m/s
# Box: (260.6861267089844, 461.82708740234375)
# Pan: 1.0418177304276737, Tilt: 1.3828379355138702
# Speed: 0.9ms preprocess, 117.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Balloon position: (0.01, 0.01, 0.01)
# C1 Distance: 0.02 m
# C2 Distance: 0.42 m
# Servo angles: {'x1': 63, 'y1': 84, 'x2': 92, 'y2': 87}
# C1 → X: 63.0°, Y: 84.0°
# C2 → X: 94.0°, Y: 86.0°
# Frame number: 48
#
# 0: 480x640 1 person, 1 sports ball, 117.0ms
# Class: sports ball, Confidence: 0.97
# 3D displacement: (0.003, 0.006, 0.007)
# Velocity: 0.010 m/s
# Box: (668.1077270507812, 548.0612182617188)
# Pan: 1.0008527141667338, Tilt: 0.2904597924068099
# Speed: 0.9ms preprocess, 117.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 sports ball, 116.6ms
# Class: sports ball, Confidence: 0.97
# 3D displacement: (0.002, 0.004, 0.006)
# Velocity: 0.008 m/s
# Box: (266.9383850097656, 455.14947509765625)
# Pan: 1.4334541843421391, Tilt: 1.7062703484110964
# Speed: 0.9ms preprocess, 116.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Balloon position: (0.01, 0.03, 0.02)
# C1 Distance: 0.04 m
# C2 Distance: 0.42 m
# Servo angles: {'x1': 63, 'y1': 84, 'x2': 94, 'y2': 86}
# C1 → X: 65.0°, Y: 84.0°
# C2 → X: 96.0°, Y: 85.0°
# Frame number: 49
#
# 0: 480x640 1 person, 1 sports ball, 118.0ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (0.009, 0.017, 0.009)
# Velocity: 0.021 m/s
# Box: (666.686767578125, 529.9393920898438)
# Pan: 1.3736264577795887, Tilt: 0.832367833925448
# Speed: 0.9ms preprocess, 118.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 sports ball, 117.7ms
# Class: sports ball, Confidence: 0.97
# 3D displacement: (0.007, 0.014, 0.008)
# Velocity: 0.017 m/s
# Box: (293.10498046875, 458.69488525390625)
# Pan: 1.3201377304529633, Tilt: 1.83012073835786
# Speed: 0.9ms preprocess, 117.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Balloon position: (0.02, 0.04, 0.02)
# C1 Distance: 0.05 m
# C2 Distance: 0.41 m
# Servo angles: {'x1': 65, 'y1': 84, 'x2': 96, 'y2': 85}
# C1 → X: 67.0°, Y: 84.0°
# C2 → X: 98.0°, Y: 84.0°
# Frame number: 50
#
# 0: 480x640 1 person, 1 sports ball, 115.5ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (0.011, 0.025, 0.011)
# Velocity: 0.029 m/s
# Box: (699.5191650390625, 507.05316162109375)
# Pan: 0.49890116622367087, Tilt: 1.2658942671403586
# Speed: 0.9ms preprocess, 115.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 sports ball, 118.2ms
# Class: sports ball, Confidence: 0.97
# 3D displacement: (0.010, 0.023, 0.010)
# Velocity: 0.026 m/s
# Box: (316.9608154296875, 452.29241943359375)
# Pan: 1.289211144065196, Tilt: 2.064096590686288
# Speed: 0.9ms preprocess, 118.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Balloon position: (0.02, 0.06, 0.02)
# C1 Distance: 0.07 m
# C2 Distance: 0.41 m
# Servo angles: {'x1': 67, 'y1': 84, 'x2': 98, 'y2': 84}
# C1 → X: 67.0°, Y: 83.0°
# C2 → X: 100.0°, Y: 82.0°
# Frame number: 51
#
# 0: 480x640 1 person, 1 sports ball, 116.1ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (0.013, 0.034, 0.012)
# Velocity: 0.038 m/s
# Box: (752.529052734375, 494.216064453125)
# Pan: -0.2008790670210634, Tilt: 1.612715413712287
# Speed: 0.9ms preprocess, 116.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 sports ball, 118.3ms
# Class: sports ball, Confidence: 0.97
# 3D displacement: (0.011, 0.030, 0.010)
# Velocity: 0.033 m/s
# Box: (367.0478820800781, 490.85223388671875)
# Pan: 0.4313689152521569, Tilt: 1.0512772725490305
# Speed: 0.9ms preprocess, 118.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Balloon position: (0.03, 0.07, 0.03)
# C1 Distance: 0.08 m
# C2 Distance: 0.41 m
# Servo angles: {'x1': 67, 'y1': 83, 'x2': 100, 'y2': 82}
# C1 → X: 67.0°, Y: 82.0°
# C2 → X: 100.0°, Y: 81.0°
# Frame number: 52
#
# 0: 480x640 1 person, 1 sports ball, 116.3ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (0.015, 0.039, 0.017)
# Velocity: 0.045 m/s
# Box: (754.9532470703125, 482.827392578125)
# Pan: -0.12329859480015554, Tilt: 1.8901723309698297
# Speed: 0.9ms preprocess, 116.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 sports balls, 116.5ms
# Class: sports ball, Confidence: 0.89
# 3D displacement: (0.013, 0.033, 0.014)
# Velocity: 0.039 m/s
# Box: (435.59014892578125, 506.0464172363281)
# Pan: -0.25490486779827454, Tilt: 0.4968043723538953
# Class: sports ball, Confidence: 0.32
# 3D displacement: (0.011, 0.028, 0.012)
# Velocity: 0.032 m/s
# Box: (435.6106262207031, 505.892578125)
# Pan: -0.8039238942386198, Tilt: 0.0532260521977872
# Speed: 0.9ms preprocess, 116.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Balloon position: (0.03, 0.07, 0.04)
# C1 Distance: 0.09 m
# C2 Distance: 0.41 m
# Servo angles: {'x1': 67, 'y1': 82, 'x2': 100, 'y2': 81}
# C1 → X: 67.0°, Y: 81.0°
# C2 → X: 100.0°, Y: 81.0°
# Frame number: 53
#
# 0: 480x640 1 person, 1 sports ball, 116.4ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (0.008, 0.022, 0.014)
# Velocity: 0.028 m/s
# Box: (753.25634765625, 483.9591064453125)
# Pan: -0.09698796731223491, Tilt: 1.5071350721597603
# Speed: 0.9ms preprocess, 116.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 sports ball, 124.4ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (0.006, 0.016, 0.012)
# Velocity: 0.022 m/s
# Box: (413.8074645996094, 570.986572265625)
# Pan: -0.043139115390895766, Tilt: -0.21052929374417387
# Speed: 2.4ms preprocess, 124.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Balloon position: (0.03, 0.07, 0.04)
# C1 Distance: 0.09 m
# C2 Distance: 0.41 m
# Servo angles: {'x1': 67, 'y1': 81, 'x2': 100, 'y2': 81}
# C1 → X: 67.0°, Y: 80.0°
# C2 → X: 100.0°, Y: 81.0°
# Frame number: 54
#
# 0: 480x640 1 person, 1 sports ball, 115.9ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (0.005, 0.012, 0.010)
# Velocity: 0.016 m/s
# Box: (721.1400146484375, 562.15087890625)
# Pan: 0.5224096261502121, Tilt: 0.6057080577278082
# Speed: 0.9ms preprocess, 115.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 sports ball, 116.8ms
# Class: sports ball, Confidence: 0.97
# 3D displacement: (0.003, 0.008, 0.008)
# Velocity: 0.012 m/s
# Box: (409.5860595703125, 581.3452758789062)
# Pan: 0.5654887076872834, Tilt: -0.6536249686234854
# Speed: 0.9ms preprocess, 116.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Balloon position: (0.03, 0.07, 0.04)
# C1 Distance: 0.09 m
# C2 Distance: 0.41 m
# Servo angles: {'x1': 67, 'y1': 80, 'x2': 100, 'y2': 81}
# C1 → X: 67.0°, Y: 80.0°
# C2 → X: 100.0°, Y: 81.0°
# Frame number: 55
#
# 0: 480x640 1 person, 1 sports ball, 116.6ms
# Class: sports ball, Confidence: 0.97
# 3D displacement: (0.002, 0.005, 0.007)
# Velocity: 0.009 m/s
# Box: (714.0804443359375, 580.5840454101562)
# Pan: 0.8911791668215453, Tilt: -0.1154335538177535
# Speed: 0.9ms preprocess, 116.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 sports ball, 116.9ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (0.001, 0.003, 0.005)
# Velocity: 0.006 m/s
# Box: (404.4201354980469, 596.91259765625)
# Pan: 1.0523909661498267, Tilt: -1.1228999748987885
# Speed: 0.9ms preprocess, 116.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Balloon position: (0.03, 0.07, 0.04)
# C1 Distance: 0.09 m
# C2 Distance: 0.41 m
# Servo angles: {'x1': 67, 'y1': 80, 'x2': 100, 'y2': 81}
# C1 → X: 67.0°, Y: 80.0°
# C2 → X: 102.0°, Y: 83.0°
# Frame number: 56
#
# 0: 480x640 1 person, 1 sports ball, 117.1ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (0.001, 0.001, 0.004)
# Velocity: 0.004 m/s
# Box: (708.3377685546875, 597.47216796875)
# Pan: 1.1229288477250827, Tilt: -0.6923468430542029
# Speed: 0.9ms preprocess, 117.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 sports ball, 116.8ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (0.000, 0.000, 0.002)
# Velocity: 0.002 m/s
# Box: (411.81610107421875, 587.5301513671875)
# Pan: 1.4419127729198615, Tilt: -0.31289324030516086
# Speed: 0.9ms preprocess, 116.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Balloon position: (0.04, 0.08, 0.03)
# C1 Distance: 0.10 m
# C2 Distance: 0.40 m
# Servo angles: {'x1': 67, 'y1': 80, 'x2': 102, 'y2': 83}
# C1 → X: 69.0°, Y: 80.0°
# C2 → X: 104.0°, Y: 83.0°
# Frame number: 57
#
# 0: 480x640 1 person, 1 sports ball, 117.7ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (0.006, 0.013, -0.005)
# Velocity: 0.016 m/s
# Box: (702.5140380859375, 610.4573974609375)
# Pan: 1.3114138756514668, Tilt: -1.1538774744433624
# Speed: 0.9ms preprocess, 117.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 sports ball, 117.7ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (0.005, 0.012, -0.005)
# Velocity: 0.014 m/s
# Box: (481.89862060546875, 599.3056640625)
# Pan: 0.5535302183358892, Tilt: -0.8503145922441289
# Speed: 0.9ms preprocess, 117.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Balloon position: (0.04, 0.10, 0.03)
# C1 Distance: 0.11 m
# C2 Distance: 0.41 m
# Servo angles: {'x1': 69, 'y1': 80, 'x2': 104, 'y2': 83}
# C1 → X: 71.0°, Y: 82.0°
# C2 → X: 104.0°, Y: 83.0°
# Frame number: 58
#
# 0: 480x640 1 person, 1 sports ball, 116.5ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (0.006, 0.025, -0.003)
# Velocity: 0.027 m/s
# Box: (734.90576171875, 625.956298828125)
# Pan: 0.44913110052117333, Tilt: -1.52310197955469
# Speed: 0.9ms preprocess, 116.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 sports ball, 117.4ms
# Class: sports ball, Confidence: 0.97
# 3D displacement: (0.006, 0.022, -0.003)
# Velocity: 0.024 m/s
# Box: (491.9113464355469, 613.9228515625)
# Pan: 0.923819594487602, Tilt: -1.2802516737953034
# Speed: 0.9ms preprocess, 117.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Balloon position: (0.03, 0.10, 0.03)
# C1 Distance: 0.11 m
# C2 Distance: 0.41 m
# Servo angles: {'x1': 71, 'y1': 82, 'x2': 104, 'y2': 83}
# C1 → X: 71.0°, Y: 84.0°
# C2 → X: 104.0°, Y: 85.0°
# Frame number: 59
#
# 0: 480x640 1 person, 1 sports ball, 116.8ms
# Class: sports ball, Confidence: 0.95
# 3D displacement: (0.001, 0.020, -0.004)
# Velocity: 0.022 m/s
# Box: (765.624267578125, 630.3685302734375)
# Pan: -0.2406951195830614, Tilt: -1.8184815836437522
# Speed: 0.9ms preprocess, 116.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 sports ball, 117.9ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (0.001, 0.017, -0.004)
# Velocity: 0.019 m/s
# Box: (492.6531066894531, 602.2293090820312)
# Pan: 1.3390556755900818, Tilt: -0.42620051355827426
# Speed: 0.9ms preprocess, 117.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Balloon position: (0.03, 0.10, 0.02)
# C1 Distance: 0.11 m
# C2 Distance: 0.41 m
# Servo angles: {'x1': 71, 'y1': 84, 'x2': 104, 'y2': 85}
# C1 → X: 71.0°, Y: 86.0°
# C2 → X: 106.0°, Y: 85.0°
# Frame number: 60
#
# 0: 480x640 1 person, 1 sports ball, 116.2ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (0.001, 0.014, -0.012)
# Velocity: 0.020 m/s
# Box: (764.082763671875, 616.0097045898438)
# Pan: -0.26858161079136067, Tilt: -1.206196840802875
# Speed: 0.9ms preprocess, 116.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 sports ball, 117.1ms
# Class: sports ball, Confidence: 0.97
# 3D displacement: (0.000, 0.012, -0.011)
# Velocity: 0.017 m/s
# Box: (518.0888671875, 613.1533203125)
# Pan: 0.6032756410001097, Tilt: -0.9409604108466195
# Speed: 0.9ms preprocess, 117.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Balloon position: (0.04, 0.11, 0.02)
# C1 Distance: 0.12 m
# C2 Distance: 0.41 m
# Servo angles: {'x1': 71, 'y1': 86, 'x2': 106, 'y2': 85}
# C1 → X: 71.0°, Y: 88.0°
# C2 → X: 106.0°, Y: 85.0°
# Frame number: 61
#
# 0: 480x640 1 person, 1 sports ball, 115.6ms
# Class: sports ball, Confidence: 0.95
# 3D displacement: (0.004, 0.022, -0.010)
# Velocity: 0.027 m/s
# Box: (763.8695068359375, 588.964599609375)
# Pan: -0.38862445523499933, Tilt: -0.36495747264229994
# Speed: 0.9ms preprocess, 115.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 sports ball, 117.3ms
# Class: sports ball, Confidence: 0.97
# 3D displacement: (0.004, 0.018, -0.009)
# Velocity: 0.022 m/s
# Box: (537.4730834960938, 618.7810668945312)
# Pan: 0.2997037743483967, Tilt: -1.2302494781228481
# Speed: 0.9ms preprocess, 117.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Balloon position: (0.04, 0.11, 0.02)
# C1 Distance: 0.12 m
# C2 Distance: 0.41 m
# Servo angles: {'x1': 71, 'y1': 88, 'x2': 106, 'y2': 85}
# C1 → X: 71.0°, Y: 88.0°
# C2 → X: 106.0°, Y: 87.0°
# Frame number: 62
#
# 0: 480x640 1 person, 1 sports ball, 116.9ms
# Class: sports ball, Confidence: 0.95
# 3D displacement: (0.003, 0.014, -0.009)
# Velocity: 0.018 m/s
# Box: (759.9068603515625, 534.2037353515625)
# Pan: -0.28539506978487916, Tilt: 0.30803402188616014
# Speed: 0.9ms preprocess, 116.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 sports ball, 118.1ms
# Class: sports ball, Confidence: 0.97
# 3D displacement: (0.002, 0.011, -0.008)
# Velocity: 0.015 m/s
# Box: (531.1536865234375, 575.4949951171875)
# Pan: 0.8397630194787175, Tilt: -0.38419958249827846
# Speed: 0.9ms preprocess, 118.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Balloon position: (0.04, 0.11, 0.01)
# C1 Distance: 0.12 m
# C2 Distance: 0.41 m
# Servo angles: {'x1': 71, 'y1': 88, 'x2': 106, 'y2': 87}
# C1 → X: 71.0°, Y: 88.0°
# C2 → X: 106.0°, Y: 87.0°
# Frame number: 63
#
# 0: 480x640 1 person, 2 sports balls, 116.3ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (0.002, 0.008, -0.014)
# Velocity: 0.018 m/s
# Box: (758.7047119140625, 525.002197265625)
# Pan: -0.3771264492212055, Tilt: 0.43627239962127184
# Class: sports ball, Confidence: 0.27
# 3D displacement: (0.002, 0.007, -0.011)
# Velocity: 0.015 m/s
# Box: (657.5323486328125, 521.117431640625)
# Pan: -0.45051155277026655, Tilt: 0.5388631018093613
# Speed: 0.9ms preprocess, 116.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 sports ball, 117.0ms
# Class: sports ball, Confidence: 0.97
# 3D displacement: (0.002, 0.005, -0.009)
# Velocity: 0.012 m/s
# Box: (534.2150268554688, 549.1685180664062)
# Pan: 1.2718104155829741, Tilt: 0.2926403340013773
# Speed: 0.9ms preprocess, 117.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Balloon position: (0.04, 0.11, 0.01)
# C1 Distance: 0.12 m
# C2 Distance: 0.41 m
# Servo angles: {'x1': 71, 'y1': 88, 'x2': 106, 'y2': 87}
# C1 → X: 71.0°, Y: 88.0°
# C2 → X: 108.0°, Y: 87.0°
# Frame number: 64
#
# 0: 480x640 1 person, 1 sports ball, 116.4ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (0.001, 0.004, -0.007)
# Velocity: 0.009 m/s
# Box: (771.3703002929688, 512.6434936523438)
# Pan: -0.9604092422162134, Tilt: 0.8311774708269928
# Speed: 0.9ms preprocess, 116.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 sports ball, 118.6ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (0.001, 0.003, -0.005)
# Velocity: 0.007 m/s
# Box: (571.8074340820312, 534.7315063476562)
# Pan: 0.41744833246637936, Tilt: 0.8341122672011019
# Speed: 0.9ms preprocess, 118.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Balloon position: (0.04, 0.13, 0.01)
# C1 Distance: 0.13 m
# C2 Distance: 0.41 m
# Servo angles: {'x1': 71, 'y1': 88, 'x2': 108, 'y2': 87}
# C1 → X: 71.0°, Y: 88.0°
# C2 → X: 108.0°, Y: 87.0°
# Frame number: 65
#
# 0: 480x640 1 person, 1 sports ball, 116.0ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (0.005, 0.015, -0.004)
# Velocity: 0.018 m/s
# Box: (786.6137084960938, 507.01837158203125)
# Pan: -1.368327393772971, Tilt: 0.6981626743156906
# Speed: 0.9ms preprocess, 116.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 sports ball, 116.3ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (0.004, 0.012, -0.003)
# Velocity: 0.015 m/s
# Box: (606.9317626953125, 526.80712890625)
# Pan: -0.26604133402689656, Tilt: 1.180248827564993
# Speed: 0.9ms preprocess, 116.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Balloon position: (0.04, 0.13, 0.01)
# C1 Distance: 0.13 m
# C2 Distance: 0.41 m
# Servo angles: {'x1': 71, 'y1': 88, 'x2': 108, 'y2': 87}
# C1 → X: 70.0°, Y: 88.0°
# C2 → X: 108.0°, Y: 86.0°
# Frame number: 66
#
# 0: 480x640 1 person, 2 sports balls, 116.6ms
# Class: sports ball, Confidence: 0.86
# 3D displacement: (0.004, 0.011, -0.002)
# Velocity: 0.013 m/s
# Box: (800.6901245117188, 505.4060974121094)
# Pan: -1.6946619150183768, Tilt: 0.3664563353762626
# Class: sports ball, Confidence: 0.27
# 3D displacement: (0.003, 0.009, -0.001)
# Velocity: 0.011 m/s
# Box: (800.7880859375, 505.0897521972656)
# Pan: -1.9557295320147017, Tilt: 0.1010912642247202
# Speed: 0.9ms preprocess, 116.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 sports ball, 117.0ms
# Class: sports ball, Confidence: 0.97
# 3D displacement: (0.003, 0.008, -0.001)
# Velocity: 0.010 m/s
# Box: (621.553466796875, 530.63818359375)
# Pan: -0.37960860685821296, Tilt: 0.7714930618495189
# Speed: 0.9ms preprocess, 117.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Balloon position: (0.05, 0.12, 0.02)
# C1 Distance: 0.13 m
# C2 Distance: 0.40 m
# Servo angles: {'x1': 70, 'y1': 88, 'x2': 108, 'y2': 86}
# C1 → X: 69.0°, Y: 88.0°
# C2 → X: 108.0°, Y: 86.0°
# Frame number: 67
#
# 0: 480x640 1 person, 1 sports ball, 117.5ms
# Class: sports ball, Confidence: 0.97
# 3D displacement: (0.005, 0.006, 0.004)
# Velocity: 0.010 m/s
# Box: (807.482666015625, 508.001708984375)
# Pan: -2.1645836256117614, Tilt: -0.36092206711354213
# Speed: 0.9ms preprocess, 117.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 sports ball, 118.0ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (0.004, 0.005, 0.003)
# Velocity: 0.008 m/s
# Box: (633.190185546875, 533.109130859375)
# Pan: -0.33488503332582814, Tilt: 0.5038698294112937
# Speed: 0.9ms preprocess, 118.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Balloon position: (0.05, 0.12, 0.02)
# C1 Distance: 0.13 m
# C2 Distance: 0.40 m
# Servo angles: {'x1': 69, 'y1': 88, 'x2': 108, 'y2': 86}
# C1 → X: 67.0°, Y: 88.0°
# C2 → X: 108.0°, Y: 86.0°
# Frame number: 68
#
# 0: 480x640 1 person, 1 sports ball, 115.8ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (0.005, 0.003, 0.003)
# Velocity: 0.008 m/s
# Box: (816.0458984375, 509.6180725097656)
# Pan: -2.3316669004894095, Tilt: -0.6869557725306124
# Speed: 0.9ms preprocess, 115.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 sports ball, 117.2ms
# Class: sports ball, Confidence: 0.97
# 3D displacement: (0.004, 0.002, 0.002)
# Velocity: 0.006 m/s
# Box: (647.74560546875, 533.1690673828125)
# Pan: -0.5137653365249617, Tilt: 0.41439818610495055
# Speed: 0.9ms preprocess, 117.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Balloon position: (0.05, 0.12, 0.02)
# C1 Distance: 0.13 m
# C2 Distance: 0.40 m
# Servo angles: {'x1': 67, 'y1': 88, 'x2': 108, 'y2': 86}
# C1 → X: 65.0°, Y: 88.0°
# C2 → X: 108.0°, Y: 86.0°
# Frame number: 69
#
# 0: 480x640 1 person, 1 sports ball, 116.6ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (0.008, -0.001, 0.002)
# Velocity: 0.010 m/s
# Box: (822.491455078125, 510.79644775390625)
# Pan: -2.465333520391528, Tilt: -0.9327368063584911
# Speed: 0.9ms preprocess, 116.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 sports ball, 118.1ms
# Class: sports ball, Confidence: 0.97
# 3D displacement: (0.007, -0.002, 0.002)
# Velocity: 0.008 m/s
# Box: (661.076171875, 531.7494506835938)
# Pan: -0.6266163764523143, Tilt: 0.4200170959076428
# Speed: 0.9ms preprocess, 118.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Balloon position: (0.06, 0.12, 0.02)
# C1 Distance: 0.13 m
# C2 Distance: 0.39 m
# Servo angles: {'x1': 65, 'y1': 88, 'x2': 108, 'y2': 86}
# C1 → X: 63.0°, Y: 88.0°
# C2 → X: 108.0°, Y: 86.0°
# Frame number: 70
#
# 0: 480x640 1 person, 1 sports ball, 116.4ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (0.010, -0.003, 0.001)
# Velocity: 0.013 m/s
# Box: (833.4444580078125, 510.232421875)
# Pan: -2.5722668163132223, Tilt: -1.0355809149287443
# Speed: 0.9ms preprocess, 116.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 sports ball, 120.6ms
# Class: sports ball, Confidence: 0.97
# 3D displacement: (0.009, -0.003, 0.001)
# Velocity: 0.011 m/s
# Box: (676.2761840820312, 529.6950073242188)
# Pan: -0.8717957712232547, Tilt: 0.45630313314288723
# Speed: 0.9ms preprocess, 120.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Balloon position: (0.06, 0.12, 0.02)
# C1 Distance: 0.14 m
# C2 Distance: 0.39 m
# Servo angles: {'x1': 63, 'y1': 88, 'x2': 108, 'y2': 86}
# C1 → X: 61.0°, Y: 90.0°
# C2 → X: 108.0°, Y: 86.0°
# Frame number: 71
#
# 0: 480x640 1 person, 1 sports ball, 115.2ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (0.012, -0.004, 0.000)
# Velocity: 0.015 m/s
# Box: (816.6181640625, 511.17352294921875)
# Pan: -1.7375642381458951, Tilt: -1.2122098808477364
# Speed: 0.9ms preprocess, 115.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 sports ball, 112.8ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (0.010, -0.003, -0.000)
# Velocity: 0.013 m/s
# Box: (687.65966796875, 536.8369750976562)
# Pan: -1.0153449766316562, Tilt: -0.13355943044364138
# Speed: 0.9ms preprocess, 112.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Balloon position: (0.07, 0.12, 0.01)
# C1 Distance: 0.14 m
# C2 Distance: 0.38 m
# Servo angles: {'x1': 61, 'y1': 90, 'x2': 108, 'y2': 86}
# C1 → X: 60.0°, Y: 92.0°
# C2 → X: 107.0°, Y: 86.0°
# Frame number: 72
#
# 0: 480x640 1 person, 1 sports ball, 116.2ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (0.013, -0.004, -0.003)
# Velocity: 0.017 m/s
# Box: (780.1644287109375, 476.5970764160156)
# Pan: -0.7900513905167161, Tilt: -0.3697679046781891
# Speed: 0.9ms preprocess, 116.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 sports ball, 116.7ms
# Class: sports ball, Confidence: 0.97
# 3D displacement: (0.011, -0.004, -0.003)
# Velocity: 0.014 m/s
# Box: (706.6905517578125, 528.8768310546875)
# Pan: -1.4122759813053252, Tilt: 0.3235795359657142
# Speed: 0.9ms preprocess, 116.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Balloon position: (0.06, 0.11, 0.01)
# C1 Distance: 0.13 m
# C2 Distance: 0.38 m
# Servo angles: {'x1': 60, 'y1': 92, 'x2': 107, 'y2': 86}
# C1 → X: 60.0°, Y: 92.0°
# C2 → X: 106.0°, Y: 86.0°
# Frame number: 73
#
# 0: 480x640 1 person, 1 sports ball, 115.7ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (0.008, -0.010, -0.004)
# Velocity: 0.016 m/s
# Box: (778.9959716796875, 426.4619140625)
# Pan: -1.1486169345609005, Tilt: 0.3041856762574488
# Speed: 0.9ms preprocess, 115.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 sports ball, 115.5ms
# Class: sports ball, Confidence: 0.97
# 3D displacement: (0.006, -0.008, -0.004)
# Velocity: 0.013 m/s
# Box: (724.5799560546875, 525.0706787109375)
# Pan: -1.7298207850442602, Tilt: 0.49958428690466405
# Speed: 0.9ms preprocess, 115.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Balloon position: (0.06, 0.11, 0.01)
# C1 Distance: 0.12 m
# C2 Distance: 0.38 m
# Servo angles: {'x1': 60, 'y1': 92, 'x2': 106, 'y2': 86}
# C1 → X: 59.0°, Y: 92.0°
# C2 → X: 105.0°, Y: 86.0°
# Frame number: 74
#
# 0: 480x640 1 person, 1 sports ball, 115.4ms
# Class: sports ball, Confidence: 0.95
# 3D displacement: (0.001, -0.013, -0.003)
# Velocity: 0.016 m/s
# Box: (791.951416015625, 429.9176330566406)
# Pan: -1.5188935476487204, Tilt: -0.04278932252922557
# Speed: 0.9ms preprocess, 115.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 sports ball, 115.5ms
# Class: sports ball, Confidence: 0.97
# 3D displacement: (0.000, -0.011, -0.003)
# Velocity: 0.014 m/s
# Box: (746.6246337890625, 537.33984375)
# Pan: -1.9838566280354084, Tilt: -0.20033257047626885
# Speed: 0.9ms preprocess, 115.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Balloon position: (0.06, 0.10, 0.01)
# C1 Distance: 0.12 m
# C2 Distance: 0.38 m
# Servo angles: {'x1': 59, 'y1': 92, 'x2': 105, 'y2': 86}
# C1 → X: 58.0°, Y: 92.0°
# C2 → X: 104.0°, Y: 86.0°
# Frame number: 75
#
# 0: 480x640 1 person, 1 sports ball, 1 chair, 115.1ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (-0.002, -0.016, -0.002)
# Velocity: 0.020 m/s
# Box: (780.869384765625, 433.4380187988281)
# Pan: -1.2319668665626184, Tilt: -0.3010484555639806
# Speed: 0.9ms preprocess, 115.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 sports ball, 116.5ms
# Class: sports ball, Confidence: 0.97
# 3D displacement: (-0.002, -0.014, -0.002)
# Velocity: 0.018 m/s
# Box: (766.235107421875, 537.75830078125)
# Pan: -2.187085302428327, Tilt: -0.2508730797575378
# Speed: 0.9ms preprocess, 116.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Balloon position: (0.06, 0.09, 0.01)
# C1 Distance: 0.11 m
# C2 Distance: 0.38 m
# Servo angles: {'x1': 58, 'y1': 92, 'x2': 104, 'y2': 86}
# C1 → X: 57.0°, Y: 92.0°
# C2 → X: 102.0°, Y: 86.0°
# Frame number: 76
#
# 0: 480x640 1 person, 1 sports ball, 116.9ms
# Class: sports ball, Confidence: 0.95
# 3D displacement: (-0.004, -0.018, -0.001)
# Velocity: 0.023 m/s
# Box: (795.7669677734375, 436.3780212402344)
# Pan: -1.585573493250095, Tilt: -0.4750975658141453
# Speed: 0.9ms preprocess, 116.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 sports ball, 117.4ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (-0.004, -0.016, -0.001)
# Velocity: 0.020 m/s
# Box: (788.5732421875, 537.438232421875)
# ...
# Box: (508.14825439453125, 457.5841064453125)
# Pan: 1.1245800073466738, Tilt: 0.5421559782092831
# Speed: 0.9ms preprocess, 117.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 sports ball, 117.7ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (0.007, 0.023, 0.001)
# Velocity: 0.035 m/s
# Box: (633.1126708984375, 477.76885986328125)
# Pan: 0.8991975291138937, Tilt: -0.23535877911472836
# Speed: 0.9ms preprocess, 117.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Balloon position: (0.07, 0.19, -0.01)
# C1 Distance: 0.20 m
# C2 Distance: 0.41 m
# Servo angles: {'x1': 71, 'y1': 89, 'x2': 118, 'y2': 92}
# C1 → X: 73.0°, Y: 89.0°
# C2 → X: 118.0°, Y: 92.0°
# Frame number: 104
#
# 0: 480x640 1 person, 1 sports ball, 114.9ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (-0.000, 0.022, -0.007)
# Velocity: 0.034 m/s
# Box: (544.209716796875, 468.13983154296875)
# Pan: 0.299664005877339, Tilt: 0.06282782986799657
# Speed: 0.9ms preprocess, 114.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 sports ball, 116.6ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (-0.001, 0.018, -0.006)
# Velocity: 0.028 m/s
# Box: (616.09033203125, 479.8694763183594)
# Pan: 1.319358023291115, Tilt: -0.45432531084724687
# Speed: 0.9ms preprocess, 116.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Balloon position: (0.06, 0.20, -0.01)
# C1 Distance: 0.21 m
# C2 Distance: 0.42 m
# Servo angles: {'x1': 73, 'y1': 89, 'x2': 118, 'y2': 92}
# C1 → X: 73.0°, Y: 89.0°
# C2 → X: 120.0°, Y: 92.0°
# Frame number: 105
#
# 0: 480x640 1 person, 1 sports ball, 1 dining table, 115.8ms
# Class: sports ball, Confidence: 0.95
# 3D displacement: (-0.007, 0.017, -0.006)
# Velocity: 0.028 m/s
# Box: (595.1339111328125, 472.7870178222656)
# Pan: -0.3602687952981289, Tilt: -0.0005915433699462472
# Speed: 0.9ms preprocess, 115.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 sports ball, 116.7ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (-0.007, 0.013, -0.005)
# Velocity: 0.024 m/s
# Box: (618.081787109375, 483.9075927734375)
# Pan: 1.3714388171744207, Tilt: -0.7503247409803162
# Speed: 0.9ms preprocess, 116.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Balloon position: (0.06, 0.21, -0.01)
# C1 Distance: 0.22 m
# C2 Distance: 0.42 m
# Servo angles: {'x1': 73, 'y1': 89, 'x2': 120, 'y2': 92}
# C1 → X: 73.0°, Y: 89.0°
# C2 → X: 122.0°, Y: 92.0°
# Frame number: 106
#
# 0: 480x640 1 person, 1 sports ball, 115.2ms
# Class: sports ball, Confidence: 0.95
# 3D displacement: (-0.003, 0.024, -0.004)
# Velocity: 0.037 m/s
# Box: (562.2592163085938, 462.3538818359375)
# Pan: 0.31178496376149695, Tilt: 0.5995267653040431
# Speed: 0.9ms preprocess, 115.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 sports ball, 116.4ms
# Class: sports ball, Confidence: 0.95
# 3D displacement: (-0.002, 0.021, -0.004)
# Velocity: 0.032 m/s
# Box: (579.6444091796875, 460.46636962890625)
# Pan: 1.6971510537395367, Tilt: -0.0002597927842529213
# Speed: 0.9ms preprocess, 116.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Balloon position: (0.07, 0.23, -0.01)
# C1 Distance: 0.24 m
# C2 Distance: 0.43 m
# Servo angles: {'x1': 73, 'y1': 89, 'x2': 122, 'y2': 92}
# C1 → X: 73.0°, Y: 89.0°
# C2 → X: 124.0°, Y: 92.0°
# Frame number: 107
#
# 0: 480x640 1 person, 1 sports ball, 114.9ms
# Class: sports ball, Confidence: 0.91
# 3D displacement: (0.003, 0.032, -0.003)
# Velocity: 0.048 m/s
# Box: (396.7488708496094, 350.35711669921875)
# Pan: 0.8494279710091976, Tilt: 1.0796214122432346
# Speed: 0.9ms preprocess, 114.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 sports ball, 116.1ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (0.002, 0.027, -0.002)
# Velocity: 0.041 m/s
# Box: (396.7286376953125, 343.86236572265625)
# Pan: 1.9577208429916295, Tilt: 0.5997921657725978
# Speed: 0.9ms preprocess, 116.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Balloon position: (0.07, 0.24, -0.01)
# C1 Distance: 0.25 m
# C2 Distance: 0.43 m
# Servo angles: {'x1': 73, 'y1': 89, 'x2': 124, 'y2': 92}
# C1 → X: 73.0°, Y: 88.0°
# C2 → X: 126.0°, Y: 92.0°
# Frame number: 108
#
# 0: 480x640 1 person, 1 dining table, 115.0ms
# Speed: 0.9ms preprocess, 115.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 sports ball, 116.9ms
# Class: sports ball, Confidence: 0.86
# 3D displacement: (0.007, 0.037, -0.001)
# Velocity: 0.057 m/s
# Box: (67.14544677734375, 194.57760620117188)
# Pan: 2.166176674393304, Tilt: 1.0798337326180782
# Speed: 0.9ms preprocess, 116.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 73.0°, Y: 88.0°
# C2 → X: 129.0°, Y: 91.0°
# Frame number: 109
#
# 0: 480x640 (no detections), 125.7ms
# Speed: 1.7ms preprocess, 125.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.0ms
# Speed: 0.9ms preprocess, 119.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 110
#
# 0: 480x640 1 person, 133.4ms
# Speed: 3.0ms preprocess, 133.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 121.1ms
# Speed: 0.9ms preprocess, 121.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 111
#
# 0: 480x640 1 person, 122.7ms
# Speed: 0.9ms preprocess, 122.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.4ms
# Speed: 0.9ms preprocess, 119.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 112
#
# 0: 480x640 (no detections), 122.4ms
# Speed: 0.9ms preprocess, 122.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.7ms
# Speed: 0.9ms preprocess, 118.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 113
#
# 0: 480x640 1 person, 120.9ms
# Speed: 1.0ms preprocess, 120.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.6ms
# Speed: 0.9ms preprocess, 119.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 114
#
# 0: 480x640 1 person, 119.6ms
# Speed: 0.9ms preprocess, 119.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.4ms
# Speed: 0.9ms preprocess, 119.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 115
#
# 0: 480x640 (no detections), 119.5ms
# Speed: 0.9ms preprocess, 119.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.4ms
# Speed: 0.9ms preprocess, 119.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 116
#
# 0: 480x640 1 person, 119.0ms
# Speed: 0.9ms preprocess, 119.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.4ms
# Speed: 0.9ms preprocess, 123.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 117
#
# 0: 480x640 1 person, 118.7ms
# Speed: 0.9ms preprocess, 118.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 126.1ms
# Speed: 0.9ms preprocess, 126.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 118
#
# 0: 480x640 1 person, 119.5ms
# Speed: 0.9ms preprocess, 119.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.3ms
# Speed: 0.9ms preprocess, 119.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 119
#
# 0: 480x640 1 person, 117.5ms
# Speed: 0.9ms preprocess, 117.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 121.1ms
# Speed: 0.9ms preprocess, 121.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 120
#
# 0: 480x640 1 person, 1 bed, 118.9ms
# Speed: 0.9ms preprocess, 118.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 121.2ms
# Speed: 0.9ms preprocess, 121.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 121
#
# 0: 480x640 1 person, 116.2ms
# Speed: 1.0ms preprocess, 116.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.1ms
# Speed: 0.8ms preprocess, 123.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 122
#
# 0: 480x640 1 person, 119.5ms
# Speed: 0.9ms preprocess, 119.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.9ms
# Speed: 0.9ms preprocess, 118.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 123
#
# 0: 480x640 1 person, 122.1ms
# Speed: 0.9ms preprocess, 122.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.3ms
# Speed: 1.0ms preprocess, 119.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 124
#
# 0: 480x640 1 person, 119.9ms
# Speed: 0.9ms preprocess, 119.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 167.6ms
# Speed: 0.9ms preprocess, 167.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 125
#
# 0: 480x640 1 person, 118.5ms
# Speed: 1.0ms preprocess, 118.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.8ms
# Speed: 0.9ms preprocess, 119.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 126
#
# 0: 480x640 1 bed, 119.3ms
# Speed: 0.9ms preprocess, 119.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.1ms
# Speed: 0.9ms preprocess, 118.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 127
#
# 0: 480x640 1 bed, 118.6ms
# Speed: 0.9ms preprocess, 118.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.7ms
# Speed: 0.9ms preprocess, 118.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 128
#
# 0: 480x640 (no detections), 118.1ms
# Speed: 0.9ms preprocess, 118.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.6ms
# Speed: 0.9ms preprocess, 117.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 129
#
# 0: 480x640 1 bed, 117.7ms
# Speed: 0.9ms preprocess, 117.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.2ms
# Speed: 0.9ms preprocess, 118.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 130
#
# 0: 480x640 (no detections), 117.6ms
# Speed: 0.9ms preprocess, 117.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 116.7ms
# Speed: 0.9ms preprocess, 116.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 131
#
# 0: 480x640 1 bed, 116.8ms
# Speed: 0.9ms preprocess, 116.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.6ms
# Speed: 0.9ms preprocess, 117.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 132
#
# 0: 480x640 1 bed, 118.1ms
# Speed: 0.9ms preprocess, 118.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.0ms
# Speed: 0.9ms preprocess, 117.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 133
#
# 0: 480x640 (no detections), 117.3ms
# Speed: 0.9ms preprocess, 117.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.8ms
# Speed: 0.9ms preprocess, 117.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 134
#
# 0: 480x640 (no detections), 118.8ms
# Speed: 0.9ms preprocess, 118.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.2ms
# Speed: 0.9ms preprocess, 120.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 135
#
# 0: 480x640 (no detections), 115.3ms
# Speed: 0.9ms preprocess, 115.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.0ms
# Speed: 0.9ms preprocess, 117.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 136
#
# 0: 480x640 (no detections), 116.3ms
# Speed: 0.9ms preprocess, 116.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.3ms
# Speed: 0.9ms preprocess, 117.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 137
#
# 0: 480x640 (no detections), 115.9ms
# Speed: 0.9ms preprocess, 115.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 116.5ms
# Speed: 0.9ms preprocess, 116.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 138
#
# 0: 480x640 1 person, 116.9ms
# Speed: 0.9ms preprocess, 116.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 116.5ms
# Speed: 0.9ms preprocess, 116.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 139
#
# 0: 480x640 2 persons, 117.4ms
# Speed: 0.9ms preprocess, 117.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.7ms
# Speed: 0.9ms preprocess, 117.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 140
#
# 0: 480x640 1 person, 1 bed, 116.3ms
# Speed: 0.9ms preprocess, 116.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 116.2ms
# Speed: 0.9ms preprocess, 116.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 141
#
# 0: 480x640 1 person, 1 bed, 117.6ms
# Speed: 0.9ms preprocess, 117.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.9ms
# Speed: 0.9ms preprocess, 117.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 142
#
# 0: 480x640 1 person, 116.1ms
# Speed: 0.9ms preprocess, 116.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 116.2ms
# Speed: 0.9ms preprocess, 116.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 143
#
# 0: 480x640 1 person, 118.5ms
# Speed: 0.9ms preprocess, 118.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 113.8ms
# Speed: 0.9ms preprocess, 113.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 144
#
# 0: 480x640 (no detections), 121.0ms
# Speed: 0.9ms preprocess, 121.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.2ms
# Speed: 0.9ms preprocess, 117.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 145
#
# 0: 480x640 (no detections), 116.7ms
# Speed: 1.1ms preprocess, 116.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 116.8ms
# Speed: 0.9ms preprocess, 116.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 146
#
# 0: 480x640 (no detections), 119.2ms
# Speed: 1.0ms preprocess, 119.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.1ms
# Speed: 0.9ms preprocess, 117.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 147
#
# 0: 480x640 1 person, 116.2ms
# Speed: 0.9ms preprocess, 116.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.1ms
# Speed: 0.9ms preprocess, 117.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# ----------------------------------------- Program finished -----------------------------------------
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
enumerate_cameras()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 enumerate_cameras()
#
# NameError: name 'enumerate_cameras' is not defined
