# %%
# Install dependencies
# %pip install ultralytics
# %pip install opencv-python
# %pip install simple_pid
# %pip install numpy
# %pip install pyserial
# %pip install cv2-enumerate-cameras
# %pip install scikit-learn
# %pip install nolds
# %pip install google-api-python-client
# %pip install google-auth-httplib2
# %pip install google-auth-oauthlib
# Out:
# Requirement already satisfied: ultralytics in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (8.3.186)
# Requirement already satisfied: numpy>=1.23.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (2.3.1)
# Requirement already satisfied: matplotlib>=3.3.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (3.10.3)
# Requirement already satisfied: opencv-python>=4.6.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (1.16.0)
# Requirement already satisfied: torch>=1.8.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (2.7.1)
# Requirement already satisfied: torchvision>=0.9.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (0.22.1)
# Requirement already satisfied: psutil in /Users/Leonardo/Library/Python/3.13/lib/python/site-packages (from ultralytics) (7.0.0)
# Requirement already satisfied: py-cpuinfo in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (2.3.0)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/Leonardo/Library/Python/3.13/lib/python/site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/Leonardo/Library/Python/3.13/lib/python/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/Leonardo/Library/Python/3.13/lib/python/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (2026.1.4)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (3.20.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (4.14.0)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (2025.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: opencv-python in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from opencv-python) (2.3.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: simple_pid in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (2.0.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (2.3.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pyserial in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (3.5)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: cv2-enumerate-cameras in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (1.3.0)
# Requirement already satisfied: pyobjc-framework-AVFoundation in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from cv2-enumerate-cameras) (11.1)
# Requirement already satisfied: pyobjc-core>=11.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pyobjc-framework-AVFoundation->cv2-enumerate-cameras) (11.1)
# Requirement already satisfied: pyobjc-framework-CoreMedia>=11.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pyobjc-framework-AVFoundation->cv2-enumerate-cameras) (11.1)
# Requirement already satisfied: pyobjc-framework-CoreAudio>=11.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pyobjc-framework-AVFoundation->cv2-enumerate-cameras) (11.1)
# Requirement already satisfied: pyobjc-framework-Cocoa>=11.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pyobjc-framework-AVFoundation->cv2-enumerate-cameras) (11.1)
# Requirement already satisfied: pyobjc-framework-Quartz>=11.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pyobjc-framework-AVFoundation->cv2-enumerate-cameras) (11.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from scikit-learn) (2.3.1)
# Requirement already satisfied: scipy>=1.8.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from scikit-learn) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: nolds in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (0.6.2)
# Requirement already satisfied: numpy<3.0,>1.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from nolds) (2.3.1)
# Requirement already satisfied: future in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from nolds) (1.0.0)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from nolds) (80.9.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: google-api-python-client in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (2.192.0)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-python-client) (0.31.2)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-python-client) (2.49.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-python-client) (0.3.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-python-client) (2.30.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-python-client) (4.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (1.73.0)
# Requirement already satisfied: protobuf<7.0.0,>=4.25.8 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (6.33.5)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (1.27.1)
# Requirement already satisfied: requests<3.0.0,>=2.20.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.32.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (46.0.5)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (4.9.1)
# Requirement already satisfied: pyparsing<4,>=3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client) (3.2.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests<3.0.0,>=2.20.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests<3.0.0,>=2.20.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests<3.0.0,>=2.20.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests<3.0.0,>=2.20.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2026.1.4)
# Requirement already satisfied: pyasn1>=0.1.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from rsa<5,>=3.1.4->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (0.6.2)
# Requirement already satisfied: cffi>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from cryptography>=38.0.3->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (2.0.0)
# Requirement already satisfied: pycparser in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (3.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: google-auth-httplib2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (0.3.0)
# Requirement already satisfied: google-auth<3.0.0,>=1.32.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth-httplib2) (2.49.0)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth-httplib2) (0.31.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth<3.0.0,>=1.32.0->google-auth-httplib2) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth<3.0.0,>=1.32.0->google-auth-httplib2) (46.0.5)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth<3.0.0,>=1.32.0->google-auth-httplib2) (4.9.1)
# Requirement already satisfied: pyparsing<4,>=3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httplib2<1.0.0,>=0.19.0->google-auth-httplib2) (3.2.3)
# Requirement already satisfied: pyasn1>=0.1.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=1.32.0->google-auth-httplib2) (0.6.2)
# Requirement already satisfied: cffi>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=1.32.0->google-auth-httplib2) (2.0.0)
# Requirement already satisfied: pycparser in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=1.32.0->google-auth-httplib2) (3.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: google-auth-oauthlib in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (1.3.0)
# Requirement already satisfied: google-auth!=2.43.0,!=2.44.0,!=2.45.0,<3.0.0,>=2.15.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth-oauthlib) (2.49.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth-oauthlib) (2.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth!=2.43.0,!=2.44.0,!=2.45.0,<3.0.0,>=2.15.0->google-auth-oauthlib) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth!=2.43.0,!=2.44.0,!=2.45.0,<3.0.0,>=2.15.0->google-auth-oauthlib) (46.0.5)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth!=2.43.0,!=2.44.0,!=2.45.0,<3.0.0,>=2.15.0->google-auth-oauthlib) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from rsa<5,>=3.1.4->google-auth!=2.43.0,!=2.44.0,!=2.45.0,<3.0.0,>=2.15.0->google-auth-oauthlib) (0.6.2)
# Requirement already satisfied: cffi>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from cryptography>=38.0.3->google-auth!=2.43.0,!=2.44.0,!=2.45.0,<3.0.0,>=2.15.0->google-auth-oauthlib) (2.0.0)
# Requirement already satisfied: pycparser in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth!=2.43.0,!=2.44.0,!=2.45.0,<3.0.0,>=2.15.0->google-auth-oauthlib) (3.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.3.1)
# Requirement already satisfied: requests>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2026.1.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Configurations
import cv2
import os
import io
import math
import serial
import time
import numpy as np
import nolds
import requests
import pickle
from ultralytics import YOLO
from simple_pid import PID
from cv2_enumerate_cameras import enumerate_cameras
from collections import deque
from sklearn.decomposition import PCA
from googleapiclient.discovery import build
from googleapiclient.http import MediaIoBaseUpload
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request

# Camera configuration
CAMERA_INDEX_1 = 1200                  # Index of the camera  to be used (custom value; check with enumerate_cameras)
CAMERA_INDEX_2 = 1201                  # Index of the camera to be used (custom value; check with enumerate_cameras)

# Movement vector filtering
VECTOR_MIN_LENGTH = 20                 # Minimum length of movement vector to consider (in pixels)
VECTOR_MAX_LENGTH = 200                # Maximum length of movement vector to consider (in pixels)
PIXELS_PER_UNIT = 200.0                # Conversion factor from pixels to real-world units (e.g., cm)
VECTOR_HISTORY_SIZE = 6                # Number of previous positions to store for movement vector calculation

# Geometry setup
CAMERA_DISTANCE = 43                   # Distance between two cameras (used for triangulation)
DISTANCE_UNIT = "cm"                   # Unit of measurement for camera distance

# YOLO model setup
MODEL = YOLO('yolov10m.pt')            # Load YOLOv8 nano model for object detection
CLASS_NAMES = MODEL.names              # List of all class labels in the model
DESIRED_CLASSES = ["sports ball"]      # Classes we want to detect (only track sports balls)

# PID control parameters
PID_KP = 0.015                         # PID Proportional gain
PID_KI = 0.003                         # PID Integral gain
PID_KD = 0.09                          # PID Derivative gain
PID_OUTPUT_LIMITS = (-3, 3)            # Output limits for PID correction to smooth servo movement
ALPHA = 0.2                            # Smoothing factor for servo movement (0 < ALPHA < 1)

# Servo configuration
SERVO_MIN = 0                          # Minimum angle a servo can rotate to
SERVO_MAX = 180                        # Maximum angle a servo can rotate to
SERVO_INIT = {                         # Initial servo positions (centered)
    'x1': 65, 
    'y1': 90, 
    'x2': 115, 
    'y2': 90
}

# Arduino serial communication
ARDUINO_PORT = '/dev/cu.usbmodem11301'  # Serial port where Arduino is connected
ARDUINO_BAUDRATE = 9600                 # Communication speed between Python and Arduino


# Telegram bot configuration
TOKEN = "8750939695:AAHakcI-1T_IC6WkK2CvcPSsSsAT5hnzCrI" # Change to your bot token
CHAT_ID = "-4856182101"                  # Change to your chat ID
ALERT_COOLDOWN = 30                      # Seconds between alerts

# Google Drive configuration
SCOPES = ['https://www.googleapis.com/auth/drive.file'] # Scope for uploading files to Google Drive
POSITIVE_IMAGE_UPLOAD_INTERVAL = 30      # Seconds between positive image uploads to Google Drive
NEGATIVE_IMAGE_UPLOAD_INTERVAL = 60      # Seconds between negative image uploads to Google Drive
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/nolds/datasets.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
# CV2 and camera settings

# Initialize camera
def init_camera(index, verbose=True):
    cap = cv2.VideoCapture(index)
    if not cap.isOpened():
        raise RuntimeError(f"Error: Could not open webcam {index}.")
    if verbose:
        print(f"Camera {index} opened successfully.")
    return cap


# Read current frame
def read_frame(cap):
    ret, frame = cap.read()
    if not ret:
        raise RuntimeError("Failed to capture image from webcam.")
    return frame


# Calculate frame center
def calculate_center(frame):
    height, width = frame.shape[:2]
    x_center, y_center = width / 2, height / 2
    return x_center, y_center


# Check if class is in desired classes
def valid_class(box, class_names=CLASS_NAMES, desired_classes=DESIRED_CLASSES):
    return class_names[int(box.cls)] in desired_classes


# Draw bounding box
def draw_bounding_box(frame, box, class_names=CLASS_NAMES, verbose=True):
    x1, y1, x2, y2 = map(int, box.xyxy[0])
    cv2.rectangle(frame, (x1, y1), (x2, y2), (255, 0, 255), 3)
    
    cls = int(box.cls[0])
    confidence = math.ceil((box.conf[0] * 100)) / 100
    
    org = [x1, y1]
    font = cv2.FONT_HERSHEY_SIMPLEX
    font_scale = 1
    color = (255, 0, 0)
    thickness = 2
    cv2.putText(frame, class_names[cls], org, font, font_scale, color, thickness)
    
    if verbose:
        print(f"Class: {class_names[cls]}, Confidence: {confidence}")


# Draw movement vector
def draw_movement_vector(frame, box, balloon_position, vector_history, avg_dt, prev_position=None, verbose=True):
    x1, y1, x2, y2 = map(int, box.xyxy[0])
    cx_pixel, cy_pixel = int((x1 + x2) / 2), int((y1 + y2) / 2)
    x, y, z = float(balloon_position[0]), float(balloon_position[1]), float(balloon_position[2])

    if len(vector_history) == 0:
        base_px, base_py, base_pz = prev_position if prev_position is not None else (x, y, z)
    else:
        base_px = sum(p[0] for p in vector_history) / len(vector_history)
        base_py = sum(p[1] for p in vector_history) / len(vector_history)
        base_pz = sum(p[2] for p in vector_history) / len(vector_history)

    dx_w, dy_w, dz_w = x - base_px, y - base_py, z - base_pz
    mag_w = math.sqrt(dx_w**2 + dy_w**2 + dz_w**2)
    vel_w = mag_w / avg_dt

    if mag_w > 1e-9:
        ux, uy = dx_w / mag_w, dz_w / mag_w
        length_px = mag_w * PIXELS_PER_UNIT
        length_px = max(VECTOR_MIN_LENGTH, min(length_px, VECTOR_MAX_LENGTH))
        
        end_x = int(cx_pixel + ux * length_px)
        end_y = int(cy_pixel - uy * length_px)
        cv2.arrowedLine(frame, (cx_pixel, cy_pixel), (end_x, end_y), (0, 0, 255), 3, tipLength=0.3)

    vector_history.append((x, y, z))
    new_prev_position = (x, y, z)

    if verbose:
        print(f"3D displacement: ({dx_w:.3f}, {dy_w:.3f}, {dz_w:.3f})")
        print(f"Velocity: {vel_w:.3f} {DISTANCE_UNIT}/s")

    return new_prev_position

# %%
# Calculations

# Calculate balloon coordinates
def triangulation(angles: dict, d=CAMERA_DISTANCE, verbose=True):
    alpha = np.radians(angles['x1'])
    beta = np.radians(angles['x2']-90)
    gamma = np.radians(90-angles['y1'])
    delta = np.radians(90-angles['y2'])
    
    if (np.sin(alpha + beta)) == 0:
        raise ValueError("Invalid angles for triangulation.")
    
    n = d * np.sin(beta) / np.sin(alpha + beta)
    m = d * np.sin(alpha) / np.sin(alpha + beta)

    x1 = n * np.cos(alpha)
    y1 = n * np.sin(alpha)
    z1 = n * np.tan(gamma)
    
    x2 = d - (m * np.cos(beta))
    y2 = m * np.sin(beta)
    z2 = m * np.tan(delta)

    x = (x1 + x2) / 2
    y = (y1 + y2) / 2
    z = (z1 + z2) / 2
    
    if verbose:
        print(f"Balloon position: ({x:.2f}, {y:.2f}, {z:.2f})")
    
    return np.array([x, y, z])


# Calculate distance to camera
def get_distance(camera, balloon_position, d=CAMERA_DISTANCE, verbose=True):
    if camera == 'C1':
        camera_position = np.array([0, 0, 0])
    elif camera == 'C2':
        camera_position = np.array([d, 0, 0])
    else:
        raise ValueError("Invalid camera ID. Use 'C1' or 'C2'.")
    
    distance = np.linalg.norm(balloon_position - camera_position)
    
    if verbose:
        print(f"{camera} Distance: {distance:.2f} {DISTANCE_UNIT}")
    
    return distance

# %%
# Lyapunov exponent

def compute_lyapunov_exponent(positions, dt, method="pca", emb_dim=6, tau=1, min_tsep=10, trajectory_len=20, debug_plot=True):
    positions = np.array(positions)
    if positions.shape[1] != 3:
        raise ValueError("Positions must be of shape (N,3).")

    if method.lower() == "pca":
        pca = PCA(n_components=1)
        scalar_series = pca.fit_transform(positions).flatten()
    elif method.lower() == "norm":
        scalar_series = np.linalg.norm(positions, axis=1)
    elif method.lower() in ["x", "y", "z"]:
        idx = {"x":0, "y":1, "z":2}[method.lower()]
        scalar_series = positions[:, idx]
    else:
        raise ValueError("Invalid method. Choose 'pca', 'norm', 'x', 'y', or 'z'.")

    scalar_series = (scalar_series - np.mean(scalar_series)) / (np.std(scalar_series) + 1e-12)

    lyap_raw = nolds.lyap_r(
        scalar_series,
        emb_dim=emb_dim,
        tau=tau,
        min_tsep=min_tsep,
        trajectory_len=trajectory_len,
        debug_plot=debug_plot
    )
    lyap_exp = lyap_raw / dt
    lyap_time = 1 / lyap_exp if lyap_exp > 0 else float('inf')

    return lyap_exp, lyap_time

# %%
# PID controller

# Initialize PID controller
def init_pid(x_center, y_center, verbose=True):
    global prev_pan, prev_tilt
    prev_pan, prev_tilt = 0, 0
    pid_pan = PID(Kp=PID_KP, Ki=PID_KI, Kd=PID_KD, setpoint=x_center)
    pid_pan.output_limits = PID_OUTPUT_LIMITS
    pid_tilt = PID(Kp=PID_KP, Ki=PID_KI, Kd=PID_KD, setpoint=y_center)
    pid_tilt.output_limits = PID_OUTPUT_LIMITS
    if verbose:
        print("PID controller initialized.")
    return pid_pan, pid_tilt


# Calculate corrections using PID controller
def calculate_corrections(box, pid_pan, pid_tilt, verbose=True):
    global prev_pan, prev_tilt
    x1, y1, x2, y2 = box.xyxy[0]
    x_box = float((x1 + x2) / 2)
    y_box = float((y1 + y2) / 2)
    
    pan_raw = pid_pan(x_box)
    tilt_raw = pid_tilt(y_box)
    pan = ALPHA * pan_raw + (1 - ALPHA) * prev_pan
    tilt = ALPHA * tilt_raw + (1 - ALPHA) * prev_tilt
    prev_pan, prev_tilt = pan, tilt
    
    if verbose:
        print(f"Box: ({x_box}, {y_box})")
        print(f"Pan: {pan}, Tilt: {tilt}")
    return pan, tilt


# Update servo angle
def update_angle(servo_angle, correction):
    if correction > 10:
        correction = 10
    elif correction < -10:
        correction = -10
    return max(SERVO_MIN, min(SERVO_MAX, math.ceil(servo_angle + correction)))

# %%
# Arduino

# Initialize serial connection to arduino
def init_arduino(*, port=ARDUINO_PORT, baudrate=ARDUINO_BAUDRATE, initial_angles=SERVO_INIT, verbose=True):
    try:
        arduino = serial.Serial(port, baudrate)
        time.sleep(2)
        if verbose:
            print(f"Connected to Arduino on {port} at {baudrate} baud.")
        move_servos(arduino, initial_angles)
        return arduino
    except serial.SerialException as e:
        raise RuntimeError(f"Could not connect to Arduino on {port}: {e}")


# Move servos
def move_servos(arduino, angles: dict, verbose=True):
    try:
        command = f"{angles['x1']},{angles['y1']},{angles['x2']},{angles['y2']}\n"
        arduino.write(command.encode())
        arduino.flush()
        if verbose:
            print(f"C1 → X: {angles['x1']:.1f}°, Y: {angles['y1']:.1f}°")
            print(f"C2 → X: {angles['x2']:.1f}°, Y: {angles['y2']:.1f}°")
            
    except serial.SerialException as e:
        print(f"Serial communication error: {e}")

# %%
# Telegram alert

def send_telegram_alert(position, dist_c1, dist_c2, message="🎈 Balão detectado!"):
    global last_alert_time
    now = time.time()
    
    if now - last_alert_time >= ALERT_COOLDOWN:
        x, y, z = position
        message = f"🎈 Balão detectado!\n" \
                f"📍 Coordenadas: x={x:.2f}, y={y:.2f}, z={z:.2f}\n"
        
        if dist_c1 is not None:
            message += f"📏 Distância C1: {dist_c1:.2f} cm\n"
        if dist_c2 is not None:
            message += f"📏 Distância C2: {dist_c2:.2f} cm\n"

        url = f"https://api.telegram.org/bot{TOKEN}/sendMessage"
        data = {"chat_id": CHAT_ID, "text": message}
        response = requests.post(url, data=data)
        
        if response.status_code == 200:
            print("📩 Coordenadas enviadas com sucesso!")
        else:
            print("⚠️ Erro ao enviar coordenadas:", response.text)
        
        last_alert_time = now

# %%
# Drive upload

# Authenticate and create Google Drive service
def authenticate_drive():
    creds = None

    if os.path.exists("token.pickle"):
        with open("token.pickle", "rb") as f:
            creds = pickle.load(f)

    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file("credentials.json", SCOPES)
            creds = flow.run_local_server(port=0)

        with open("token.pickle", "wb") as f:
            pickle.dump(creds, f)

    return build("drive", "v3", credentials=creds)


# Create folder to store frames in Google Drive
def create_folder(service, name):
    folder_metadata = {
        "name": name,
        "mimeType": "application/vnd.google-apps.folder"
    }

    folder = service.files().create(
        body=folder_metadata,
        fields="id"
    ).execute()

    return folder["id"]


# Upload frame to Google Drive
def upload_frame(service, frame, folder_id, code):
    global last_positive_c1_upload_time, last_positive_c2_upload_time, last_negative_c1_upload_time, last_negative_c2_upload_time, frame_count
    now = time.time()
    
    y1 = code == 'Y1' and now - last_positive_c1_upload_time >= POSITIVE_IMAGE_UPLOAD_INTERVAL
    y2 = code == 'Y2' and now - last_positive_c2_upload_time >= POSITIVE_IMAGE_UPLOAD_INTERVAL
    n1 = code == 'N1' and now - last_negative_c1_upload_time >= NEGATIVE_IMAGE_UPLOAD_INTERVAL
    n2 = code == 'N2' and now - last_negative_c2_upload_time >= NEGATIVE_IMAGE_UPLOAD_INTERVAL

    if y1 or y2 or n1 or n2:
        _, buffer = cv2.imencode(".jpg", frame)
        file_bytes = io.BytesIO(buffer)

        media = MediaIoBaseUpload(file_bytes, mimetype="image/jpeg")
        
        filename = f"{code}_{frame_count}"

        file_metadata = {
            "name": filename,
            "parents": [folder_id]
        }

        service.files().create(
            body=file_metadata,
            media_body=media
        ).execute()
        
        if n1:
            last_negative_c1_upload_time = now
        elif n2:
            last_negative_c2_upload_time = now
        elif y1:
            last_positive_c1_upload_time = now
        elif y2:
            last_positive_c2_upload_time = now
        n1, n2, y1, y2 = False, False, False, False

# %%
# Print functions

# Print divider
def print_div(text):
    print("\n" + f" {text} ".center(100, '-') + "\n")


# Print available cameras
def print_cameras():
    for camera_info in enumerate_cameras():
        print(f'{camera_info.index}: {camera_info.name}')


# Print final information
def final_prints(frame_count, x1_center, y1_center, x2_center, y2_center, frame_delay, balloon_position, dist_c1, dist_c2, servo_angles, lyap_exp, lyap_time):
    x, y, z = balloon_position
    print(f"Total frames: {frame_count}, Total time: {frame_delay*frame_count:.2f} seconds")
    print(f"Detected classes: {DESIRED_CLASSES}")
    print(f"Frame centers: ({x1_center}, {y1_center}), ({x2_center}, {y2_center})")
    print(f"FPS: {(1/frame_delay):.2f}")
    print(f"Final balloon position: ({x:.2f}, {y:.2f}, {z:.2f})")
    print(f"Final C1 distance: {dist_c1:.2f} {DISTANCE_UNIT}")
    print(f"Final C2 distance: {dist_c2:.2f} {DISTANCE_UNIT}")
    print(f"Servo angles: {servo_angles}")
    print(f"Lyapunov exponent: {lyap_exp:.4f} per second")
    if lyap_time != float('inf'):
        print(f"Predictability horizon: {lyap_time:.2f} seconds\n")
    else:
        print("Predictability horizon: Infinite (non-chaotic behavior)\n")

# %%
# Main program
print_div("Available cameras")
print_cameras()

print_div("Initial settings")
frame_count, total_time, last_alert_time = 0, 0, 0
last_positive_c1_upload_time, last_positive_c2_upload_time = 0, 0
last_negative_c1_upload_time, last_negative_c2_upload_time = 0, 0
prev_time = time.time()

SERVO_INIT = {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
servo_angles = SERVO_INIT
vector_history = deque(maxlen=VECTOR_HISTORY_SIZE)
prev_position = None
balloon_positions_history = []

arduino = init_arduino(initial_angles=servo_angles)
#service = authenticate_drive()
#folder_id = create_folder(service, "frames")

cap1 = init_camera(CAMERA_INDEX_1)
cap2 = init_camera(CAMERA_INDEX_2)
frame1 = read_frame(cap1)
frame2 = read_frame(cap2)

x1_center, y1_center = calculate_center(frame1)
x2_center, y2_center = calculate_center(frame2)
pid_pan1, pid_tilt1 = init_pid(x1_center, y1_center)
pid_pan2, pid_tilt2 = init_pid(x2_center, y2_center)

print_div("Program started")
try:
    while True:
        print(f"Frame number: {frame_count}")
        current_time = time.time()
        frame_delay = current_time - prev_time
        total_time += frame_delay
        avg_frame_delay = total_time / frame_count if frame_count > 0 else frame_delay
        prev_time = current_time
        
        c1_found, c2_found = False, False
        balloon_position = triangulation(servo_angles)
        balloon_positions_history.append(balloon_position.copy())
        dist_c1 = get_distance('C1', balloon_position)
        dist_c2 = get_distance('C2', balloon_position)
        print(f"Servo angles: {servo_angles}")
        
        x1_correction, y1_correction = 0, 0
        frame1 = read_frame(cap1)
        results1 = MODEL(frame1, stream=True)
        for r1 in results1:
            if not r1.boxes:
                continue
            for box1 in r1.boxes:
                if valid_class(box1):
                    #upload_frame(service, frame1, folder_id, 'Y1')
                    draw_bounding_box(frame1, box1)
                    prev_position = draw_movement_vector(frame1, box1, balloon_position, vector_history, avg_frame_delay, prev_position)
                    x1_correction, y1_correction = calculate_corrections(box1, pid_pan1, pid_tilt1)
                    #send_telegram_alert(balloon_position, dist_c1, dist_c2)
                    c1_found = True
                
        x2_correction, y2_correction = 0, 0
        frame2 = read_frame(cap2)
        results2 = MODEL(frame2, stream=True)
        for r2 in results2:
            if not r2.boxes:
                continue
            for box2 in r2.boxes:
                if valid_class(box2):
                    #upload_frame(service, frame2, folder_id, 'Y2')
                    draw_bounding_box(frame2, box2)
                    prev_position = draw_movement_vector(frame2, box2, balloon_position, vector_history, avg_frame_delay, prev_position)
                    x2_correction, y2_correction = calculate_corrections(box2, pid_pan2, pid_tilt2)
                    #send_telegram_alert(balloon_position, dist_c1, dist_c2)
                    c2_found = True
        
        #if c1_found == False:
            #upload_frame(service, frame1, folder_id, 'N1')
        #if c2_found == False:
            #upload_frame(service, frame2, folder_id, 'N2')

        c1_change = x1_correction != 0 or y1_correction != 0
        c2_change = x2_correction != 0 or y2_correction != 0
        if c1_change:
            y1_correction *= -1 # type: ignore
            servo_angles['x1'] = update_angle(servo_angles['x1'], x1_correction)
            servo_angles['y1'] = update_angle(servo_angles['y1'], y1_correction)
        if c2_change:
            y2_correction *= -1 # type: ignore
            servo_angles['x2'] = update_angle(servo_angles['x2'], x2_correction)
            servo_angles['y2'] = update_angle(servo_angles['y2'], y2_correction)
        if c1_change or c2_change:
            move_servos(arduino, servo_angles)
        
        cv2.imshow("Image1", frame1)
        cv2.imshow("Image2", frame2)
        if cv2.waitKey(1) == ord('q'):
            break
        frame_count += 1
finally:
    print_div("Program finished")
    lyap_exp, lyap_time = compute_lyapunov_exponent(balloon_positions_history, avg_frame_delay)
    final_prints(frame_count, x1_center, y1_center, x2_center, y2_center, avg_frame_delay, 
                 balloon_position, dist_c1, dist_c2, servo_angles, lyap_exp, lyap_time)
    cap1.release()
    cap2.release()
    cv2.destroyAllWindows()
    arduino.close()
# Out:
# ---------------------------------------- Available cameras -----------------------------------------
#
# 1200: USB Camera VID:1133 PID:2085
# 1201: C270 HD WEBCAM
# 1202: iPhone Leo Camera
# 1203: MacBook Air Camera
#
# ----------------------------------------- Initial settings -----------------------------------------
#
# Connected to Arduino on /dev/cu.usbmodem11301 at 9600 baud.
# C1 → X: 65.0°, Y: 90.0°
# C2 → X: 115.0°, Y: 90.0°
# Camera 1200 opened successfully.
# Camera 1201 opened successfully.
# PID controller initialized.
# PID controller initialized.
#
# ----------------------------------------- Program started ------------------------------------------
#
# Frame number: 0
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 4 persons, 1 chair, 121.7ms
# Speed: 1.3ms preprocess, 121.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 airplane, 1 scissors, 116.4ms
# Speed: 1.0ms preprocess, 116.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 1
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 4 persons, 119.6ms
# Speed: 1.1ms preprocess, 119.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 airplane, 1 scissors, 132.5ms
# Speed: 1.0ms preprocess, 132.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 2
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 4 persons, 116.7ms
# Speed: 0.9ms preprocess, 116.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 airplane, 1 scissors, 115.6ms
# Speed: 1.0ms preprocess, 115.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 3
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 4 persons, 117.3ms
# Speed: 0.9ms preprocess, 117.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 airplane, 1 scissors, 118.4ms
# Speed: 0.9ms preprocess, 118.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 4
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 4 persons, 1 chair, 117.2ms
# Speed: 0.9ms preprocess, 117.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 airplane, 1 scissors, 115.4ms
# Speed: 1.0ms preprocess, 115.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 5
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 4 persons, 1 chair, 118.2ms
# Speed: 0.9ms preprocess, 118.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 airplane, 1 scissors, 115.2ms
# Speed: 1.0ms preprocess, 115.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 6
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 4 persons, 1 remote, 118.1ms
# Speed: 1.0ms preprocess, 118.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 scissors, 116.4ms
# Speed: 1.0ms preprocess, 116.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 7
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 4 persons, 1 chair, 2 remotes, 117.2ms
# Speed: 0.9ms preprocess, 117.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 airplane, 1 scissors, 114.7ms
# Speed: 0.9ms preprocess, 114.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 8
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 4 persons, 1 chair, 1 remote, 116.5ms
# Speed: 0.9ms preprocess, 116.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 114.0ms
# Speed: 0.9ms preprocess, 114.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 9
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 4 persons, 116.0ms
# Speed: 0.9ms preprocess, 116.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 133.0ms
# Speed: 0.9ms preprocess, 133.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 10
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 3 persons, 117.5ms
# Speed: 1.1ms preprocess, 117.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 115.0ms
# Speed: 1.0ms preprocess, 115.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 11
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 3 persons, 114.9ms
# Speed: 0.9ms preprocess, 114.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 114.5ms
# Speed: 0.9ms preprocess, 114.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 12
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 4 persons, 116.0ms
# Speed: 0.9ms preprocess, 116.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 airplane, 1 scissors, 114.0ms
# Speed: 0.9ms preprocess, 114.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 13
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 4 persons, 116.7ms
# Speed: 0.9ms preprocess, 116.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 scissors, 114.1ms
# Speed: 0.9ms preprocess, 114.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 14
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 4 persons, 116.2ms
# Speed: 0.9ms preprocess, 116.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 scissors, 115.7ms
# Speed: 1.0ms preprocess, 115.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 15
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 5 persons, 115.4ms
# Speed: 0.9ms preprocess, 115.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 airplane, 1 scissors, 114.1ms
# Speed: 0.9ms preprocess, 114.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 16
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 4 persons, 115.9ms
# Speed: 0.9ms preprocess, 115.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 scissors, 113.4ms
# Speed: 0.9ms preprocess, 113.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 17
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 5 persons, 134.7ms
# Speed: 0.9ms preprocess, 134.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 airplane, 1 scissors, 113.6ms
# Speed: 0.9ms preprocess, 113.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 18
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 4 persons, 1 chair, 115.9ms
# Speed: 0.9ms preprocess, 115.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 scissors, 113.3ms
# Speed: 0.9ms preprocess, 113.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 19
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 4 persons, 116.9ms
# Speed: 0.9ms preprocess, 116.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 airplane, 1 scissors, 115.3ms
# Speed: 0.9ms preprocess, 115.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 20
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 4 persons, 117.0ms
# Speed: 0.9ms preprocess, 117.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 scissors, 111.7ms
# Speed: 1.0ms preprocess, 111.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 21
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 4 persons, 117.6ms
# Speed: 0.9ms preprocess, 117.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 1 scissors, 115.7ms
# Speed: 1.0ms preprocess, 115.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 22
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 4 persons, 116.5ms
# Speed: 1.0ms preprocess, 116.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 airplane, 114.9ms
# Speed: 1.1ms preprocess, 114.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 23
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 3 persons, 115.9ms
# Speed: 0.9ms preprocess, 115.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 115.1ms
# Speed: 1.0ms preprocess, 115.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 24
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 1 person, 1 sports ball, 116.4ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (0.000, 0.000, 0.000)
# Velocity: 0.000 cm/s
# Box: (407.76666259765625, 566.0444946289062)
# Pan: 0.6000000000000001, Tilt: -0.6000000000000001
# Speed: 1.1ms preprocess, 116.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 115.4ms
# Speed: 1.0ms preprocess, 115.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 66.0°, Y: 91.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 25
# Balloon position: (7.39, 16.60, -0.16)
# C1 Distance: 18.18 cm
# C2 Distance: 39.29 cm
# Servo angles: {'x1': 66, 'y1': 91, 'x2': 115, 'y2': 90}
#
# 0: 480x640 3 persons, 1 sports ball, 124.9ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (-0.287, 0.134, -0.159)
# Velocity: 0.763 cm/s
# Box: (594.9567260742188, 500.719482421875)
# Pan: -0.12, Tilt: 0.12
# Speed: 1.0ms preprocess, 124.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 114.5ms
# Speed: 0.9ms preprocess, 114.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 66.0°, Y: 91.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 26
# Balloon position: (7.39, 16.60, -0.16)
# C1 Distance: 18.18 cm
# C2 Distance: 39.29 cm
# Servo angles: {'x1': 66, 'y1': 91, 'x2': 115, 'y2': 90}
#
# 0: 480x640 3 persons, 1 sports ball, 117.1ms
# Class: sports ball, Confidence: 0.97
# 3D displacement: (-0.144, 0.067, -0.079)
# Velocity: 0.387 cm/s
# Box: (648.6455078125, 491.9823303222656)
# Pan: -0.6960000000000001, Tilt: 0.21326983430742408
# Speed: 0.9ms preprocess, 117.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 120.1ms
# Speed: 1.0ms preprocess, 120.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 66.0°, Y: 91.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 27
# Balloon position: (7.39, 16.60, -0.16)
# C1 Distance: 18.18 cm
# C2 Distance: 39.29 cm
# Servo angles: {'x1': 66, 'y1': 91, 'x2': 115, 'y2': 90}
#
# 0: 480x640 2 persons, 1 sports ball, 115.8ms
# Class: sports ball, Confidence: 0.94
# 3D displacement: (-0.096, 0.045, -0.053)
# Velocity: 0.262 cm/s
# Box: (613.8814697265625, 499.306396484375)
# Pan: 0.043200000000000016, Tilt: -0.4293841325540608
# Speed: 0.9ms preprocess, 115.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 113.6ms
# Speed: 1.0ms preprocess, 113.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 67.0°, Y: 92.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 28
# Balloon position: (7.10, 16.74, -0.32)
# C1 Distance: 18.19 cm
# C2 Distance: 39.61 cm
# Servo angles: {'x1': 67, 'y1': 92, 'x2': 115, 'y2': 90}
#
# 0: 480x640 2 persons, 1 sports ball, 117.1ms
# Class: sports ball, Confidence: 0.95
# 3D displacement: (-0.360, 0.168, -0.199)
# Velocity: 0.997 cm/s
# Box: (568.4432983398438, 500.832763671875)
# Pan: 0.6345600000000001, Tilt: -0.923374883132164
# Speed: 1.0ms preprocess, 117.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 112.9ms
# Speed: 0.9ms preprocess, 112.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 68.0°, Y: 93.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 29
# Balloon position: (6.82, 16.87, -0.48)
# C1 Distance: 18.20 cm
# C2 Distance: 39.93 cm
# Servo angles: {'x1': 68, 'y1': 93, 'x2': 115, 'y2': 90}
#
# 0: 480x640 3 persons, 1 sports ball, 115.8ms
# Class: sports ball, Confidence: 0.91
# 3D displacement: (-0.576, 0.268, -0.318)
# Velocity: 1.617 cm/s
# Box: (550.6104736328125, 503.49322509765625)
# Pan: 1.1076480000000002, Tilt: -1.3386999065057315
# Speed: 0.9ms preprocess, 115.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 114.5ms
# Speed: 1.0ms preprocess, 114.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 70.0°, Y: 95.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 30
# Balloon position: (6.24, 17.14, -0.80)
# C1 Distance: 18.26 cm
# C2 Distance: 40.57 cm
# Servo angles: {'x1': 70, 'y1': 95, 'x2': 115, 'y2': 90}
#
# 0: 480x640 3 persons, 1 sports ball, 115.7ms
# Class: sports ball, Confidence: 0.94
# 3D displacement: (-1.057, 0.493, -0.586)
# Velocity: 3.008 cm/s
# Box: (525.3572387695312, 556.537109375)
# Pan: 1.4861184000000003, Tilt: -1.6709599252045853
# Speed: 0.9ms preprocess, 115.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 114.1ms
# Speed: 0.9ms preprocess, 114.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 72.0°, Y: 97.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 31
# Balloon position: (5.66, 17.41, -1.12)
# C1 Distance: 18.34 cm
# C2 Distance: 41.22 cm
# Servo angles: {'x1': 72, 'y1': 97, 'x2': 115, 'y2': 90}
#
# 0: 480x640 3 persons, 1 sports ball, 116.5ms
# Class: sports ball, Confidence: 0.92
# 3D displacement: (-1.399, 0.652, -0.779)
# Velocity: 4.029 cm/s
# Box: (513.2747192382812, 595.794189453125)
# Pan: 1.7888947200000003, Tilt: -1.9367679401636684
# Speed: 0.9ms preprocess, 116.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 114.0ms
# Speed: 0.9ms preprocess, 114.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 74.0°, Y: 99.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 32
# Balloon position: (5.07, 17.69, -1.46)
# C1 Distance: 18.46 cm
# C2 Distance: 41.87 cm
# Servo angles: {'x1': 74, 'y1': 99, 'x2': 115, 'y2': 90}
#
# 0: 480x640 3 persons, 1 sports ball, 115.0ms
# Class: sports ball, Confidence: 0.94
# 3D displacement: (-1.696, 0.791, -0.951)
# Velocity: 4.945 cm/s
# Box: (511.118896484375, 619.3406982421875)
# Pan: 2.0311157760000005, Tilt: -2.149414352130935
# Speed: 0.9ms preprocess, 115.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 129.7ms
# Speed: 1.0ms preprocess, 129.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 77.0°, Y: 102.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 33
# Balloon position: (4.18, 18.10, -1.97)
# C1 Distance: 18.68 cm
# C2 Distance: 42.88 cm
# Servo angles: {'x1': 77, 'y1': 102, 'x2': 115, 'y2': 90}
#
# 0: 480x640 3 persons, 1 sports ball, 115.2ms
# Class: sports ball, Confidence: 0.92
# 3D displacement: (-2.201, 1.026, -1.252)
# Velocity: 6.497 cm/s
# Box: (518.3907470703125, 652.0332641601562)
# Pan: 2.180838236666169, Tilt: -2.319531481704748
# Speed: 0.9ms preprocess, 115.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 114.3ms
# Speed: 1.0ms preprocess, 114.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 80.0°, Y: 105.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 34
# Balloon position: (3.27, 18.53, -2.52)
# C1 Distance: 18.98 cm
# C2 Distance: 43.91 cm
# Servo angles: {'x1': 80, 'y1': 105, 'x2': 115, 'y2': 90}
#
# 0: 480x640 3 persons, 1 sports ball, 116.8ms
# Class: sports ball, Confidence: 0.84
# 3D displacement: (-2.578, 1.202, -1.496)
# Velocity: 7.704 cm/s
# Box: (527.1901245117188, 678.2703857421875)
# Pan: 2.126390958989033, Tilt: -2.4556251853637985
# Speed: 0.9ms preprocess, 116.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 114.1ms
# Speed: 1.0ms preprocess, 114.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 83.0°, Y: 108.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 35
# Balloon position: (2.33, 18.97, -3.10)
# C1 Distance: 19.36 cm
# C2 Distance: 44.98 cm
# Servo angles: {'x1': 83, 'y1': 108, 'x2': 115, 'y2': 90}
#
# 0: 480x640 3 persons, 1 sports ball, 115.6ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (-2.877, 1.341, -1.712)
# Velocity: 8.727 cm/s
# Box: (533.552001953125, 704.2432861328125)
# Pan: 2.2078855038334506, Tilt: -2.564500148291039
# Speed: 0.9ms preprocess, 115.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 113.7ms
# Speed: 0.9ms preprocess, 113.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 86.0°, Y: 111.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 36
# Balloon position: (1.36, 19.42, -3.74)
# C1 Distance: 19.82 cm
# C2 Distance: 46.10 cm
# Servo angles: {'x1': 86, 'y1': 111, 'x2': 115, 'y2': 90}
#
# 0: 480x640 3 persons, 1 sports ball, 115.3ms
# Class: sports ball, Confidence: 0.85
# 3D displacement: (-3.099, 1.445, -1.906)
# Velocity: 9.560 cm/s
# Box: (546.088134765625, 724.7747802734375)
# Pan: 1.8405997419379667, Tilt: -2.6516001186328313
# Speed: 0.9ms preprocess, 115.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 114.7ms
# Speed: 0.9ms preprocess, 114.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 88.0°, Y: 114.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 37
# Balloon position: (0.69, 19.73, -4.39)
# C1 Distance: 20.23 cm
# C2 Distance: 46.89 cm
# Servo angles: {'x1': 88, 'y1': 114, 'x2': 115, 'y2': 90}
#
# 0: 480x640 3 persons, 1 sports ball, 116.2ms
# Class: sports ball, Confidence: 0.92
# 3D displacement: (-2.955, 1.378, -2.075)
# Velocity: 9.517 cm/s
# Box: (550.2511596679688, 751.31787109375)
# Pan: 2.0724797935503734, Tilt: -2.721280094906265
# Speed: 0.9ms preprocess, 116.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 114.0ms
# Speed: 0.9ms preprocess, 114.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 91.0°, Y: 117.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 38
# Balloon position: (-0.35, 20.22, -5.15)
# C1 Distance: 20.86 cm
# C2 Distance: 48.11 cm
# Servo angles: {'x1': 91, 'y1': 117, 'x2': 115, 'y2': 90}
#
# 0: 480x640 3 persons, 1 sports ball, 115.6ms
# Class: sports ball, Confidence: 0.91
# 3D displacement: (-3.168, 1.477, -2.286)
# Velocity: 10.373 cm/s
# Box: (544.9058227539062, 769.9715576171875)
# Pan: 2.257983834840299, Tilt: -2.7770240759250124
# Speed: 0.9ms preprocess, 115.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 116.8ms
# Speed: 0.9ms preprocess, 116.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 94.0°, Y: 120.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 39
# Balloon position: (-1.45, 20.73, -6.00)
# C1 Distance: 21.63 cm
# C2 Distance: 49.41 cm
# Servo angles: {'x1': 94, 'y1': 120, 'x2': 115, 'y2': 90}
#
# 0: 480x640 3 persons, 1 sports ball, 116.0ms
# Class: sports ball, Confidence: 0.93
# 3D displacement: (-3.361, 1.567, -2.518)
# Velocity: 11.214 cm/s
# Box: (545.576416015625, 792.86669921875)
# Pan: 2.4063870678722394, Tilt: -2.82161926074001
# Speed: 0.9ms preprocess, 116.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 115.6ms
# Speed: 1.0ms preprocess, 115.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 97.0°, Y: 123.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 40
# Balloon position: (-2.61, 21.27, -6.96)
# C1 Distance: 22.53 cm
# C2 Distance: 50.81 cm
# Servo angles: {'x1': 97, 'y1': 123, 'x2': 115, 'y2': 90}
#
# 0: 480x640 3 persons, 1 sports ball, 123.1ms
# Class: sports ball, Confidence: 0.92
# 3D displacement: (-3.585, 1.672, -2.807)
# Velocity: 12.227 cm/s
# Box: (549.58349609375, 798.7337646484375)
# Pan: 2.5251096542977916, Tilt: -2.8572954085920084
# Speed: 1.9ms preprocess, 123.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 113.7ms
# Speed: 1.1ms preprocess, 113.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 100.0°, Y: 126.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 41
# Balloon position: (-3.85, 21.85, -8.06)
# C1 Distance: 23.60 cm
# C2 Distance: 52.32 cm
# Servo angles: {'x1': 100, 'y1': 126, 'x2': 115, 'y2': 90}
#
# 0: 480x640 2 persons, 1 sports ball, 115.2ms
# Class: sports ball, Confidence: 0.94
# 3D displacement: (-3.846, 1.793, -3.169)
# Velocity: 13.450 cm/s
# Box: (556.9309692382812, 791.7259521484375)
# Pan: 2.3906825937948897, Tilt: -2.8858363268736067
# Speed: 0.9ms preprocess, 115.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 118.3ms
# Speed: 0.9ms preprocess, 118.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 103.0°, Y: 129.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 42
# Balloon position: (-5.19, 22.47, -9.34)
# C1 Distance: 24.88 cm
# C2 Distance: 53.98 cm
# Servo angles: {'x1': 103, 'y1': 129, 'x2': 115, 'y2': 90}
#
# 0: 480x640 2 persons, 1 sports ball, 115.9ms
# Class: sports ball, Confidence: 0.94
# 3D displacement: (-4.151, 1.936, -3.621)
# Velocity: 14.927 cm/s
# Box: (562.215576171875, 759.1280517578125)
# Pan: 2.40866423282671, Tilt: -1.7086690614988855
# Speed: 0.9ms preprocess, 115.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 112.4ms
# Speed: 1.0ms preprocess, 112.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 106.0°, Y: 131.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 43
# Balloon position: (-6.64, 23.15, -10.47)
# C1 Distance: 26.26 cm
# C2 Distance: 55.76 cm
# Servo angles: {'x1': 106, 'y1': 131, 'x2': 115, 'y2': 90}
#
# 0: 480x640 2 persons, 1 sports ball, 116.6ms
# Class: sports ball, Confidence: 0.91
# 3D displacement: (-4.510, 2.103, -3.816)
# Velocity: 16.144 cm/s
# Box: (563.566162109375, 738.9356689453125)
# Pan: 2.526931386261368, Tilt: -1.4426109773683082
# Speed: 0.9ms preprocess, 116.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 114.9ms
# Speed: 0.9ms preprocess, 114.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 109.0°, Y: 133.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 44
# Balloon position: (-8.22, 23.89, -11.78)
# C1 Distance: 27.87 cm
# C2 Distance: 57.73 cm
# Servo angles: {'x1': 109, 'y1': 133, 'x2': 115, 'y2': 90}
#
# 0: 480x640 2 persons, 1 sports ball, 115.6ms
# Class: sports ball, Confidence: 0.85
# 3D displacement: (-4.876, 2.274, -4.117)
# Velocity: 17.552 cm/s
# Box: (558.7410888671875, 720.7990112304688)
# Pan: 2.6215451090090944, Tilt: -1.3067600375278148
# Speed: 0.9ms preprocess, 115.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 113.0ms
# Speed: 1.1ms preprocess, 113.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 112.0°, Y: 135.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 45
# Balloon position: (-9.98, 24.71, -13.32)
# C1 Distance: 29.79 cm
# C2 Distance: 59.96 cm
# Servo angles: {'x1': 112, 'y1': 135, 'x2': 115, 'y2': 90}
#
# 0: 480x640 2 persons, 1 sports ball, 114.4ms
# Class: sports ball, Confidence: 0.95
# 3D displacement: (-5.321, 2.481, -4.557)
# Velocity: 19.374 cm/s
# Box: (556.701171875, 672.3138427734375)
# Pan: 2.697236087207276, Tilt: -0.4454080300222518
# Speed: 0.9ms preprocess, 114.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 115.0ms
# Speed: 1.0ms preprocess, 115.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 115.0°, Y: 136.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 46
# Balloon position: (-11.95, 25.62, -14.64)
# C1 Distance: 31.84 cm
# C2 Distance: 62.37 cm
# Servo angles: {'x1': 115, 'y1': 136, 'x2': 115, 'y2': 90}
#
# 0: 480x640 2 persons, 1 sports ball, 115.7ms
# Class: sports ball, Confidence: 0.94
# 3D displacement: (-5.866, 2.735, -4.651)
# Velocity: 20.895 cm/s
# Box: (557.1639404296875, 607.4732666015625)
# Pan: 2.757788869765821, Tilt: 0.24367357598219863
# Speed: 0.9ms preprocess, 115.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 113.6ms
# Speed: 1.0ms preprocess, 113.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 118.0°, Y: 136.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 47
# Balloon position: (-14.18, 26.66, -15.63)
# C1 Distance: 34.00 cm
# C2 Distance: 65.00 cm
# Servo angles: {'x1': 118, 'y1': 136, 'x2': 115, 'y2': 90}
#
# 0: 480x640 2 persons, 1 sports ball, 115.6ms
# Class: sports ball, Confidence: 0.95
# 3D displacement: (-6.538, 3.049, -4.368)
# Velocity: 22.236 cm/s
# Box: (551.337890625, 549.9769287109375)
# Pan: 2.806231095812657, Tilt: 0.794938860785759
# Speed: 0.9ms preprocess, 115.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 129.2ms
# Speed: 1.7ms preprocess, 129.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 121.0°, Y: 136.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 48
# Balloon position: (-16.74, 27.86, -16.83)
# C1 Distance: 36.60 cm
# C2 Distance: 68.03 cm
# Servo angles: {'x1': 121, 'y1': 136, 'x2': 115, 'y2': 90}
#
# 0: 480x640 2 persons, 1 sports ball, 114.0ms
# Class: sports ball, Confidence: 0.94
# 3D displacement: (-7.378, 3.441, -4.297)
# Velocity: 24.386 cm/s
# Box: (550.0543212890625, 512.4591674804688)
# Pan: 2.8449848766501256, Tilt: 1.2359510886286074
# Speed: 0.9ms preprocess, 114.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 113.9ms
# Speed: 0.9ms preprocess, 113.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 124.0°, Y: 135.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 49
# Balloon position: (-19.73, 29.25, -17.64)
# C1 Distance: 39.45 cm
# C2 Distance: 71.43 cm
# Servo angles: {'x1': 124, 'y1': 135, 'x2': 115, 'y2': 90}
#
# 0: 480x640 2 persons, 1 sports ball, 116.0ms
# Class: sports ball, Confidence: 0.95
# 3D displacement: (-8.446, 3.939, -3.864)
# Velocity: 26.833 cm/s
# Box: (541.2568969726562, 483.9920654296875)
# Pan: 2.8759879013201006, Tilt: 1.588760870902886
# Speed: 0.9ms preprocess, 116.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 113.9ms
# Speed: 0.9ms preprocess, 113.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 127.0°, Y: 134.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 50
# Balloon position: (-23.30, 30.91, -18.69)
# C1 Distance: 42.98 cm
# C2 Distance: 75.50 cm
# Servo angles: {'x1': 127, 'y1': 134, 'x2': 115, 'y2': 90}
#
# 0: 480x640 2 persons, 1 sports ball, 114.9ms
# Class: sports ball, Confidence: 0.95
# 3D displacement: (-9.829, 4.583, -3.716)
# Velocity: 30.648 cm/s
# Box: (537.854248046875, 444.98553466796875)
# Pan: 2.9007903210560806, Tilt: 1.871008696722309
# Speed: 0.9ms preprocess, 114.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 114.4ms
# Speed: 1.0ms preprocess, 114.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 130.0°, Y: 133.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 51
# Balloon position: (-27.64, 32.94, -20.05)
# C1 Distance: 47.44 cm
# C2 Distance: 80.48 cm
# Servo angles: {'x1': 130, 'y1': 133, 'x2': 115, 'y2': 90}
#
# 0: 480x640 2 persons, 1 sports ball, 116.0ms
# Class: sports ball, Confidence: 0.95
# 3D displacement: (-11.662, 5.438, -3.923)
# Velocity: 36.139 cm/s
# Box: (538.5621948242188, 401.6519775390625)
# Pan: 2.920632256844865, Tilt: 2.096806957377847
# Speed: 0.9ms preprocess, 116.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 114.1ms
# Speed: 0.9ms preprocess, 114.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 133.0°, Y: 131.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 52
# Balloon position: (-33.08, 35.48, -21.09)
# C1 Distance: 52.90 cm
# C2 Distance: 86.56 cm
# Servo angles: {'x1': 133, 'y1': 131, 'x2': 115, 'y2': 90}
#
# 0: 480x640 2 persons, 1 sports ball, 115.7ms
# Class: sports ball, Confidence: 0.97
# 3D displacement: (-14.163, 6.604, -3.838)
# Velocity: 43.438 cm/s
# Box: (534.293212890625, 358.2520751953125)
# Pan: 2.936505805475892, Tilt: 2.277445565902278
# Speed: 1.0ms preprocess, 115.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 113.1ms
# Speed: 1.0ms preprocess, 113.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 136.0°, Y: 129.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 53
# Balloon position: (-40.15, 38.77, -22.60)
# C1 Distance: 60.22 cm
# C2 Distance: 94.49 cm
# Servo angles: {'x1': 136, 'y1': 129, 'x2': 115, 'y2': 90}
#
# 0: 480x640 4 persons, 1 sports ball, 114.7ms
# Class: sports ball, Confidence: 0.95
# 3D displacement: (-17.708, 8.257, -4.279)
# Velocity: 54.243 cm/s
# Box: (879.8663330078125, 372.2203369140625)
# Pan: 1.7492046443807139, Tilt: 1.2219564527218225
# Speed: 0.9ms preprocess, 114.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 113.5ms
# Speed: 0.9ms preprocess, 113.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 138.0°, Y: 128.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 54
# Balloon position: (-46.19, 41.59, -24.28)
# C1 Distance: 66.73 cm
# C2 Distance: 101.36 cm
# Servo angles: {'x1': 138, 'y1': 128, 'x2': 115, 'y2': 90}
#
# 0: 480x640 4 persons, 1 sports ball, 115.8ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (-19.417, 9.054, -4.799)
# Velocity: 59.812 cm/s
# Box: (874.9204711914062, 326.7950744628906)
# Pan: 1.5279959170007849, Tilt: 1.577565162177458
# Speed: 0.9ms preprocess, 115.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 130.8ms
# Speed: 0.9ms preprocess, 130.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 140.0°, Y: 127.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 55
# Balloon position: (-53.79, 45.13, -26.45)
# C1 Distance: 75.03 cm
# C2 Distance: 110.02 cm
# Servo angles: {'x1': 140, 'y1': 127, 'x2': 115, 'y2': 90}
#
# 0: 480x640 4 persons, 1 sports ball, 115.9ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (-22.104, 10.307, -5.730)
# Velocity: 68.486 cm/s
# Box: (874.6705322265625, 305.01171875)
# Pan: 1.007837581036862, Tilt: 1.8620521297419665
# Speed: 0.9ms preprocess, 115.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 113.0ms
# Speed: 0.9ms preprocess, 113.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 142.0°, Y: 126.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 56
# Balloon position: (-63.66, 49.74, -29.35)
# C1 Distance: 85.95 cm
# C2 Distance: 121.29 cm
# Servo angles: {'x1': 142, 'y1': 126, 'x2': 115, 'y2': 90}
#
# 0: 480x640 4 persons, 1 sports ball, 115.0ms
# Class: sports ball, Confidence: 0.97
# 3D displacement: (-26.301, 12.264, -7.153)
# Velocity: 81.956 cm/s
# Box: (867.0777587890625, 290.49365234375)
# Pan: 1.061831994557426, Tilt: 2.0896417037935735
# Speed: 0.9ms preprocess, 115.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 113.4ms
# Speed: 0.9ms preprocess, 113.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 144.0°, Y: 124.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 57
# Balloon position: (-77.05, 55.98, -32.12)
# C1 Distance: 100.51 cm
# C2 Distance: 136.30 cm
# Servo angles: {'x1': 144, 'y1': 124, 'x2': 115, 'y2': 90}
#
# 0: 480x640 4 persons, 1 sports ball, 117.8ms
# Class: sports ball, Confidence: 0.95
# 3D displacement: (-32.965, 15.372, -8.151)
# Velocity: 102.628 cm/s
# Box: (852.285400390625, 278.72650146484375)
# Pan: 1.449465595645941, Tilt: 2.271713363034859
# Speed: 0.9ms preprocess, 117.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 116.9ms
# Speed: 0.9ms preprocess, 116.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 146.0°, Y: 122.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 58
# Balloon position: (-96.31, 64.96, -36.29)
# C1 Distance: 121.71 cm
# C2 Distance: 157.94 cm
# Servo angles: {'x1': 146, 'y1': 122, 'x2': 115, 'y2': 90}
#
# 0: 480x640 4 persons, 1 sports ball, 115.1ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (-43.987, 20.511, -10.313)
# Velocity: 137.132 cm/s
# Box: (841.65380859375, 266.5055236816406)
# Pan: 1.608717834927924, Tilt: 2.4173706904278873
# Speed: 1.0ms preprocess, 115.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 112.3ms
# Speed: 0.9ms preprocess, 112.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 148.0°, Y: 120.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 59
# Balloon position: (-126.46, 79.02, -43.05)
# C1 Distance: 155.20 cm
# C2 Distance: 191.87 cm
# Servo angles: {'x1': 148, 'y1': 120, 'x2': 115, 'y2': 90}
#
# 0: 480x640 5 persons, 1 sports ball, 115.2ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (-63.599, 29.657, -14.530)
# Velocity: 198.853 cm/s
# Box: (843.9597778320312, 256.47662353515625)
# Pan: 0.8601334413712203, Tilt: 2.53389655234231
# Speed: 0.9ms preprocess, 115.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 111.8ms
# Speed: 0.9ms preprocess, 111.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 149.0°, Y: 118.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 60
# Balloon position: (-149.02, 89.54, -46.22)
# C1 Distance: 179.89 cm
# C2 Distance: 216.85 cm
# Servo angles: {'x1': 149, 'y1': 118, 'x2': 115, 'y2': 90}
#
# 0: 480x640 4 persons, 1 sports ball, 1 laptop, 115.0ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (-71.779, 33.471, -14.296)
# Velocity: 224.155 cm/s
# Box: (830.354736328125, 234.04931640625)
# Pan: 1.2881067530969763, Tilt: 2.627117241873848
# Speed: 0.9ms preprocess, 115.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 113.5ms
# Speed: 0.9ms preprocess, 113.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 151.0°, Y: 116.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 61
# Balloon position: (-227.85, 126.30, -63.53)
# C1 Distance: 268.15 cm
# C2 Distance: 305.53 cm
# Servo angles: {'x1': 151, 'y1': 116, 'x2': 115, 'y2': 90}
#
# 0: 480x640 4 persons, 1 sports ball, 130.2ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (-133.471, 62.239, -27.950)
# Velocity: 418.997 cm/s
# Box: (837.0174560546875, 229.39590454101562)
# Pan: 0.43048540247758105, Tilt: 2.7016937934990786
# Speed: 0.9ms preprocess, 130.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 112.9ms
# Speed: 0.9ms preprocess, 112.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 152.0°, Y: 114.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 62
# Balloon position: (-306.59, 163.01, -77.30)
# C1 Distance: 355.73 cm
# C2 Distance: 393.39 cm
# Servo angles: {'x1': 152, 'y1': 114, 'x2': 115, 'y2': 90}
#
# 0: 480x640 4 persons, 1 backpack, 1 sports ball, 114.2ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (-183.194, 85.425, -35.539)
# Velocity: 574.673 cm/s
# Box: (840.5322875976562, 253.61459350585938)
# Pan: -0.2351654176864601, Tilt: 1.5613550347992629
# Speed: 0.9ms preprocess, 114.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 113.7ms
# Speed: 0.9ms preprocess, 113.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 152.0°, Y: 113.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 63
# Balloon position: (-306.59, 163.01, -73.70)
# C1 Distance: 354.96 cm
# C2 Distance: 392.70 cm
# Servo angles: {'x1': 152, 'y1': 113, 'x2': 115, 'y2': 90}
#
# 0: 480x640 4 persons, 1 handbag, 1 sports ball, 115.6ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (-142.707, 66.545, -23.944)
# Velocity: 447.475 cm/s
# Box: (842.994873046875, 282.00091552734375)
# Pan: -0.7593607624648993, Tilt: 0.6490840278394103
# Speed: 0.9ms preprocess, 115.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 116.9ms
# Speed: 0.9ms preprocess, 116.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 152.0°, Y: 113.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 64
# Balloon position: (-306.59, 163.01, -73.70)
# C1 Distance: 354.96 cm
# C2 Distance: 392.70 cm
# Servo angles: {'x1': 152, 'y1': 113, 'x2': 115, 'y2': 90}
#
# 0: 480x640 4 persons, 1 sports ball, 116.1ms
# Class: sports ball, Confidence: 0.97
# 3D displacement: (-104.451, 48.706, -17.014)
# Velocity: 328.369 cm/s
# Box: (816.320068359375, 301.61724853515625)
# Pan: -0.007488609971919358, Tilt: -0.08073277772847176
# Speed: 0.9ms preprocess, 116.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 112.9ms
# Speed: 1.1ms preprocess, 112.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 152.0°, Y: 114.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 65
# Balloon position: (-306.59, 163.01, -77.30)
# C1 Distance: 355.73 cm
# C2 Distance: 393.39 cm
# Servo angles: {'x1': 152, 'y1': 114, 'x2': 115, 'y2': 90}
#
# 0: 480x640 4 persons, 1 sports ball, 115.2ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (-69.404, 32.364, -14.384)
# Velocity: 220.372 cm/s
# Box: (771.0662841796875, 310.80694580078125)
# Pan: 0.5940091120224646, Tilt: -0.27264679843165035
# Speed: 0.9ms preprocess, 115.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 113.6ms
# Speed: 0.9ms preprocess, 113.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 153.0°, Y: 115.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 66
# Balloon position: (-463.96, 236.40, -121.41)
# C1 Distance: 534.68 cm
# C2 Distance: 572.39 cm
# Servo angles: {'x1': 153, 'y1': 115, 'x2': 115, 'y2': 90}
#
# 0: 480x640 4 persons, 1 sports ball, 115.7ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (-196.755, 91.749, -52.783)
# Velocity: 633.853 cm/s
# Box: (742.6346435546875, 320.1014099121094)
# Pan: 1.0752072896179719, Tilt: -0.35832278594067835
# Speed: 0.9ms preprocess, 115.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 114.6ms
# Speed: 1.0ms preprocess, 114.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 155.0°, Y: 116.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 67
# Balloon position: (-134487392924433792.00, 62712501245963872.00, -36187421767046832.00)
# C1 Distance: 152739144171630752.00 cm
# C2 Distance: 152739144171630784.00 cm
# Servo angles: {'x1': 155, 'y1': 116, 'x2': 115, 'y2': 90}
#
# 0: 480x640 4 persons, 1 handbag, 1 sports ball, 116.1ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (-134487392924433472.000, 62712501245963704.000, -36187421767046752.000)
# Velocity: 433923232550215168.000 cm/s
# Box: (746.056884765625, 326.9144287109375)
# Pan: 0.4286320247868908, Tilt: -0.33383395217957246
# Speed: 0.9ms preprocess, 116.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 114.4ms
# Speed: 1.0ms preprocess, 114.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 156.0°, Y: 117.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 68
# Balloon position: (951.24, -423.52, 265.28)
# C1 Distance: 1074.53 cm
# C2 Distance: 1036.65 cm
# Servo angles: {'x1': 156, 'y1': 117, 'x2': 115, 'y2': 90}
#
# 0: 480x640 5 persons, 1 sports ball, 132.6ms
# Class: sports ball, Confidence: 0.95
# 3D displacement: (22414565487406868.000, -10452083540994550.000, 6031236961174808.000)
# Velocity: 72537088138230128.000 cm/s
# Box: (789.84716796875, 336.0016174316406)
# Pan: -0.25709438017048747, Tilt: -0.42705276030001027
# Speed: 0.9ms preprocess, 132.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 113.3ms
# Speed: 0.9ms preprocess, 113.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 156.0°, Y: 118.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 69
# Balloon position: (951.24, -423.52, 276.83)
# C1 Distance: 1077.43 cm
# C2 Distance: 1039.67 cm
# Servo angles: {'x1': 156, 'y1': 118, 'x2': 115, 'y2': 90}
#
# 0: 480x640 6 persons, 1 handbag, 1 sports ball, 114.9ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (22414565487406656.000, -10452083540994454.000, 6031236961174762.000)
# Velocity: 72636294818074016.000 cm/s
# Box: (848.0451049804688, 344.3015441894531)
# Pan: -0.8056755041363901, Tilt: -0.44828765595826253
# Speed: 0.9ms preprocess, 114.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 112.7ms
# Speed: 1.0ms preprocess, 112.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 156.0°, Y: 119.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 70
# Balloon position: (951.24, -423.52, 288.59)
# C1 Distance: 1080.52 cm
# C2 Distance: 1042.86 cm
# Servo angles: {'x1': 156, 'y1': 119, 'x2': 115, 'y2': 90}
#
# 0: 480x640 5 persons, 2 handbags, 1 sports ball, 115.0ms
# Class: sports ball, Confidence: 0.95
# 3D displacement: (22414565487406444.000, -10452083540994354.000, 6031236961174716.000)
# Velocity: 72844401487956576.000 cm/s
# Box: (971.9136962890625, 335.01165771484375)
# Pan: -1.244540403309112, Tilt: 0.24136987523339004
# Speed: 0.9ms preprocess, 115.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 112.9ms
# Speed: 0.9ms preprocess, 112.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 155.0°, Y: 119.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 71
# Balloon position: (-134487392924433792.00, 62712501245963872.00, -41127076403065344.00)
# C1 Distance: 153984262447821728.00 cm
# C2 Distance: 153984262447821760.00 cm
# Servo angles: {'x1': 155, 'y1': 119, 'x2': 115, 'y2': 90}
#
# 0: 480x640 7 persons, 1 backpack, 1 handbag, 1 sports ball, 116.1ms
# Class: sports ball, Confidence: 0.95
# 3D displacement: (-112072827437028512.000, 52260417704970040.000, -35095839441890976.000)
# Velocity: 368830580751593472.000 cm/s
# Box: (1067.2471923828125, 333.2889099121094)
# Pan: -1.59563232264729, Tilt: 0.7753619395493692
# Speed: 1.0ms preprocess, 116.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 113.4ms
# Speed: 1.0ms preprocess, 113.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 154.0°, Y: 119.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 72
# Balloon position: (-935.88, 456.46, -288.59)
# C1 Distance: 1080.52 cm
# C2 Distance: 1117.97 cm
# Servo angles: {'x1': 154, 'y1': 119, 'x2': 115, 'y2': 90}
#
# 0: 480x640 6 persons, 1 handbag, 1 sports ball, 115.7ms
# Class: sports ball, Confidence: 0.94
# 3D displacement: (44829130974809928.000, -20904167081987328.000, 12885749695018290.000)
# Velocity: 147076751353528384.000 cm/s
# Box: (1210.057373046875, 337.5245361328125)
# Pan: -1.8765058581178322, Tilt: 0.8335748527917829
# Speed: 0.9ms preprocess, 115.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 119.1ms
# Speed: 0.9ms preprocess, 119.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 153.0°, Y: 119.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 73
# Balloon position: (-463.96, 236.40, -144.32)
# C1 Distance: 540.34 cm
# C2 Distance: 577.68 cm
# Servo angles: {'x1': 153, 'y1': 119, 'x2': 115, 'y2': 90}
#
# 0: 480x640 6 persons, 1 handbag, 114.9ms
# Speed: 0.9ms preprocess, 114.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 117.2ms
# Speed: 1.0ms preprocess, 117.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 74
# Balloon position: (-463.96, 236.40, -144.32)
# C1 Distance: 540.34 cm
# C2 Distance: 577.68 cm
# Servo angles: {'x1': 153, 'y1': 119, 'x2': 115, 'y2': 90}
#
# 0: 480x640 6 persons, 1 cell phone, 115.7ms
# Speed: 0.9ms preprocess, 115.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 131.8ms
# Speed: 0.9ms preprocess, 131.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 75
# Balloon position: (-463.96, 236.40, -144.32)
# C1 Distance: 540.34 cm
# C2 Distance: 577.68 cm
# Servo angles: {'x1': 153, 'y1': 119, 'x2': 115, 'y2': 90}
#
# 0: 480x640 6 persons, 1 backpack, 116.7ms
# Speed: 0.9ms preprocess, 116.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 115.2ms
# Speed: 0.9ms preprocess, 115.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 76
# Balloon position: (-463.96, 236.40, -144.32)
# C1 Distance: 540.34 cm
# C2 Distance: 577.68 cm
# Servo angles: {'x1': 153, 'y1': 119, 'x2': 115, 'y2': 90}
#
# 0: 480x640 6 persons, 115.2ms
# Speed: 0.9ms preprocess, 115.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 114.2ms
# Speed: 0.9ms preprocess, 114.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 77
# Balloon position: (-463.96, 236.40, -144.32)
# C1 Distance: 540.34 cm
# C2 Distance: 577.68 cm
# Servo angles: {'x1': 153, 'y1': 119, 'x2': 115, 'y2': 90}
#
# 0: 480x640 7 persons, 1 apple, 116.3ms
# Speed: 0.9ms preprocess, 116.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 112.9ms
# Speed: 0.9ms preprocess, 112.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 78
# Balloon position: (-463.96, 236.40, -144.32)
# C1 Distance: 540.34 cm
# C2 Distance: 577.68 cm
# Servo angles: {'x1': 153, 'y1': 119, 'x2': 115, 'y2': 90}
#
# 0: 480x640 7 persons, 1 sports ball, 1 laptop, 115.7ms
# Class: sports ball, Confidence: 0.93
# 3D displacement: (44829130974810480.000, -20904167081987584.000, 12885749695018462.000)
# Velocity: 149084040754596672.000 cm/s
# Box: (1229.1337890625, 329.30633544921875)
# Pan: -2.101204686494266, Tilt: 1.2668598822334265
# Speed: 0.9ms preprocess, 115.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# ...
# C1 Distance: 85.95 cm
# C2 Distance: 121.29 cm
# Servo angles: {'x1': 142, 'y1': 54, 'x2': 115, 'y2': 90}
#
# 0: 480x640 4 persons, 1 backpack, 1 sports ball, 1 bottle, 1 laptop, 115.9ms
# Class: sports ball, Confidence: 0.96
# 3D displacement: (-12.992, 6.058, 6.341)
# Velocity: 49.509 cm/s
# Box: (703.6873779296875, 180.20785522460938)
# Pan: 0.10468004842924684, Tilt: 1.1965615095894457
# Speed: 0.9ms preprocess, 115.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.9ms
# Speed: 0.9ms preprocess, 124.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 143.0°, Y: 53.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 147
# Balloon position: (-69.80, 52.60, 32.93)
# C1 Distance: 93.40 cm
# C2 Distance: 128.75 cm
# Servo angles: {'x1': 143, 'y1': 53, 'x2': 115, 'y2': 90}
#
# 0: 480x640 4 persons, 1 backpack, 1 sports ball, 1 bottle, 117.4ms
# Class: sports ball, Confidence: 0.84
# 3D displacement: (-15.696, 7.319, 8.341)
# Velocity: 60.751 cm/s
# Box: (702.0791625976562, 198.70877075195312)
# Pan: -0.23259634918485483, Tilt: 1.3639892617000586
# Speed: 1.0ms preprocess, 117.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 112.9ms
# Speed: 0.9ms preprocess, 112.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 143.0°, Y: 52.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 148
# Balloon position: (-69.80, 52.60, 34.14)
# C1 Distance: 93.84 cm
# C2 Distance: 129.06 cm
# Servo angles: {'x1': 143, 'y1': 52, 'x2': 115, 'y2': 90}
#
# 0: 480x640 4 persons, 1 backpack, 1 sports ball, 2 laptops, 116.0ms
# Class: sports ball, Confidence: 0.9
# 3D displacement: (-11.230, 5.237, 7.496)
# Velocity: 45.776 cm/s
# Box: (766.6751098632812, 256.3941955566406)
# Pan: -0.786077079347884, Tilt: 0.4911914093600469
# Speed: 0.9ms preprocess, 116.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 115.0ms
# Speed: 1.0ms preprocess, 115.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 143.0°, Y: 52.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 149
# Balloon position: (-69.80, 52.60, 34.14)
# C1 Distance: 93.84 cm
# C2 Distance: 129.06 cm
# Servo angles: {'x1': 143, 'y1': 52, 'x2': 115, 'y2': 90}
#
# 0: 480x640 4 persons, 1 backpack, 1 sports ball, 2 laptops, 117.1ms
# Class: sports ball, Confidence: 0.78
# 3D displacement: (-7.294, 3.401, 5.432)
# Velocity: 30.715 cm/s
# Box: (715.2216796875, 222.1544189453125)
# Pan: -0.028861663478307098, Tilt: 0.9929531274880377
# Speed: 0.9ms preprocess, 117.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 114.0ms
# Speed: 0.9ms preprocess, 114.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 143.0°, Y: 52.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 150
# Balloon position: (-69.80, 52.60, 34.14)
# C1 Distance: 93.84 cm
# C2 Distance: 129.06 cm
# Servo angles: {'x1': 143, 'y1': 52, 'x2': 115, 'y2': 90}
#
# 0: 480x640 4 persons, 1 backpack, 1 sports ball, 1 bottle, 1 chair, 116.8ms
# Class: sports ball, Confidence: 0.28
# 3D displacement: (-3.953, 1.843, 3.447)
# Velocity: 17.600 cm/s
# Box: (692.533935546875, 218.36575317382812)
# Pan: 0.5769106692173545, Tilt: 1.3943625019904302
# Speed: 0.9ms preprocess, 116.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 114.3ms
# Speed: 1.0ms preprocess, 114.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 144.0°, Y: 51.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 151
# Balloon position: (-77.05, 55.98, 38.56)
# C1 Distance: 102.75 cm
# C2 Distance: 137.96 cm
# Servo angles: {'x1': 144, 'y1': 51, 'x2': 115, 'y2': 90}
#
# 0: 480x640 4 persons, 1 backpack, 1 sports ball, 1 bottle, 116.4ms
# Class: sports ball, Confidence: 0.53
# 3D displacement: (-9.294, 4.334, 6.396)
# Velocity: 38.289 cm/s
# Box: (707.3726196289062, 239.01858520507812)
# Pan: -0.13847146462611648, Tilt: 1.1080671020668837
# Speed: 0.9ms preprocess, 116.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 114.6ms
# Speed: 1.2ms preprocess, 114.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 144.0°, Y: 50.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 152
# Balloon position: (-77.05, 55.98, 39.96)
# C1 Distance: 103.28 cm
# C2 Distance: 138.36 cm
# Servo angles: {'x1': 144, 'y1': 50, 'x2': 115, 'y2': 90}
#
# 0: 480x640 4 persons, 1 backpack, 1 sports ball, 1 bottle, 1 laptop, 130.4ms
# Class: sports ball, Confidence: 0.79
# 3D displacement: (-7.062, 3.293, 6.079)
# Velocity: 31.333 cm/s
# Box: (732.8814697265625, 253.29458618164062)
# Pan: -0.7107771717008933, Tilt: 1.2888220070475884
# Speed: 0.9ms preprocess, 130.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.6ms
# Speed: 0.9ms preprocess, 119.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 144.0°, Y: 49.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 153
# Balloon position: (-77.05, 55.98, 41.40)
# C1 Distance: 103.85 cm
# C2 Distance: 138.78 cm
# Servo angles: {'x1': 144, 'y1': 49, 'x2': 115, 'y2': 90}
#
# 0: 480x640 4 persons, 2 laptops, 115.7ms
# Speed: 0.9ms preprocess, 115.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 113.7ms
# Speed: 0.9ms preprocess, 113.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 154
# Balloon position: (-77.05, 55.98, 41.40)
# C1 Distance: 103.85 cm
# C2 Distance: 138.78 cm
# Servo angles: {'x1': 144, 'y1': 49, 'x2': 115, 'y2': 90}
#
# 0: 480x640 7 persons, 1 sports ball, 1 bottle, 1 laptop, 115.5ms
# Class: sports ball, Confidence: 0.39
# 3D displacement: (-4.830, 2.252, 5.748)
# Velocity: 24.868 cm/s
# Box: (692.0983276367188, 787.19775390625)
# Pan: 0.03137826263928545, Tilt: 0.4310576056380706
# Speed: 0.9ms preprocess, 115.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 114.3ms
# Speed: 0.9ms preprocess, 114.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 145.0°, Y: 49.0°
# C2 → X: 115.0°, Y: 90.0°
# Frame number: 155
# Balloon position: (-85.73, 60.03, 45.49)
# C1 Distance: 114.11 cm
# C2 Distance: 149.14 cm
# Servo angles: {'x1': 145, 'y1': 49, 'x2': 115, 'y2': 90}
#
# 0: 480x640 5 persons, 1 backpack, 2 laptops, 116.0ms
# Speed: 0.9ms preprocess, 116.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 114.0ms
# Speed: 1.0ms preprocess, 114.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 156
# Balloon position: (-85.73, 60.03, 45.49)
# C1 Distance: 114.11 cm
# C2 Distance: 149.14 cm
# Servo angles: {'x1': 145, 'y1': 49, 'x2': 115, 'y2': 90}
#
# 0: 480x640 5 persons, 1 backpack, 2 laptops, 115.9ms
# Speed: 0.9ms preprocess, 115.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 119.7ms
# Speed: 0.9ms preprocess, 119.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 157
# Balloon position: (-85.73, 60.03, 45.49)
# C1 Distance: 114.11 cm
# C2 Distance: 149.14 cm
# Servo angles: {'x1': 145, 'y1': 49, 'x2': 115, 'y2': 90}
#
# 0: 480x640 5 persons, 1 laptop, 116.2ms
# Speed: 0.9ms preprocess, 116.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 128.8ms
# Speed: 1.0ms preprocess, 128.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 158
# Balloon position: (-85.73, 60.03, 45.49)
# C1 Distance: 114.11 cm
# C2 Distance: 149.14 cm
# Servo angles: {'x1': 145, 'y1': 49, 'x2': 115, 'y2': 90}
#
# 0: 480x640 7 persons, 1 backpack, 1 laptop, 117.3ms
# Speed: 0.9ms preprocess, 117.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 114.0ms
# Speed: 0.9ms preprocess, 114.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 159
# Balloon position: (-85.73, 60.03, 45.49)
# C1 Distance: 114.11 cm
# C2 Distance: 149.14 cm
# Servo angles: {'x1': 145, 'y1': 49, 'x2': 115, 'y2': 90}
#
# 0: 480x640 5 persons, 1 backpack, 117.1ms
# Speed: 0.9ms preprocess, 117.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 114.9ms
# Speed: 0.9ms preprocess, 114.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 160
# Balloon position: (-85.73, 60.03, 45.49)
# C1 Distance: 114.11 cm
# C2 Distance: 149.14 cm
# Servo angles: {'x1': 145, 'y1': 49, 'x2': 115, 'y2': 90}
#
# 0: 480x640 5 persons, 1 backpack, 2 laptops, 116.8ms
# Speed: 0.9ms preprocess, 116.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 117.5ms
# Speed: 1.0ms preprocess, 117.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 161
# Balloon position: (-85.73, 60.03, 45.49)
# C1 Distance: 114.11 cm
# C2 Distance: 149.14 cm
# Servo angles: {'x1': 145, 'y1': 49, 'x2': 115, 'y2': 90}
#
# 0: 480x640 5 persons, 1 backpack, 2 laptops, 116.7ms
# Speed: 0.9ms preprocess, 116.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 115.4ms
# Speed: 1.0ms preprocess, 115.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 162
# Balloon position: (-85.73, 60.03, 45.49)
# C1 Distance: 114.11 cm
# C2 Distance: 149.14 cm
# Servo angles: {'x1': 145, 'y1': 49, 'x2': 115, 'y2': 90}
#
# 0: 480x640 5 persons, 1 backpack, 1 laptop, 118.1ms
# Speed: 0.9ms preprocess, 118.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 114.8ms
# Speed: 0.9ms preprocess, 114.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 163
# Balloon position: (-85.73, 60.03, 45.49)
# C1 Distance: 114.11 cm
# C2 Distance: 149.14 cm
# Servo angles: {'x1': 145, 'y1': 49, 'x2': 115, 'y2': 90}
#
# 0: 480x640 7 persons, 1 bottle, 1 laptop, 129.0ms
# Speed: 0.9ms preprocess, 129.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 114.1ms
# Speed: 0.9ms preprocess, 114.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 164
# Balloon position: (-85.73, 60.03, 45.49)
# C1 Distance: 114.11 cm
# C2 Distance: 149.14 cm
# Servo angles: {'x1': 145, 'y1': 49, 'x2': 115, 'y2': 90}
#
# 0: 480x640 6 persons, 1 backpack, 1 bottle, 116.5ms
# Speed: 0.9ms preprocess, 116.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 114.4ms
# Speed: 0.9ms preprocess, 114.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 165
# Balloon position: (-85.73, 60.03, 45.49)
# C1 Distance: 114.11 cm
# C2 Distance: 149.14 cm
# Servo angles: {'x1': 145, 'y1': 49, 'x2': 115, 'y2': 90}
#
# 0: 480x640 8 persons, 1 backpack, 117.9ms
# Speed: 0.9ms preprocess, 117.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 113.3ms
# Speed: 0.9ms preprocess, 113.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 166
# Balloon position: (-85.73, 60.03, 45.49)
# C1 Distance: 114.11 cm
# C2 Distance: 149.14 cm
# Servo angles: {'x1': 145, 'y1': 49, 'x2': 115, 'y2': 90}
#
# 0: 480x640 7 persons, 1 handbag, 115.1ms
# Speed: 0.9ms preprocess, 115.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 112.9ms
# Speed: 0.9ms preprocess, 112.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 167
# Balloon position: (-85.73, 60.03, 45.49)
# C1 Distance: 114.11 cm
# C2 Distance: 149.14 cm
# Servo angles: {'x1': 145, 'y1': 49, 'x2': 115, 'y2': 90}
#
# 0: 480x640 6 persons, 1 handbag, 115.4ms
# Speed: 0.9ms preprocess, 115.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 116.7ms
# Speed: 0.9ms preprocess, 116.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 168
# Balloon position: (-85.73, 60.03, 45.49)
# C1 Distance: 114.11 cm
# C2 Distance: 149.14 cm
# Servo angles: {'x1': 145, 'y1': 49, 'x2': 115, 'y2': 90}
#
# 0: 480x640 6 persons, 115.4ms
# Speed: 0.9ms preprocess, 115.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 114.1ms
# Speed: 1.0ms preprocess, 114.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 169
# Balloon position: (-85.73, 60.03, 45.49)
# C1 Distance: 114.11 cm
# C2 Distance: 149.14 cm
# Servo angles: {'x1': 145, 'y1': 49, 'x2': 115, 'y2': 90}
#
# 0: 480x640 6 persons, 1 refrigerator, 126.4ms
# Speed: 1.4ms preprocess, 126.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 113.2ms
# Speed: 0.9ms preprocess, 113.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 170
# Balloon position: (-85.73, 60.03, 45.49)
# C1 Distance: 114.11 cm
# C2 Distance: 149.14 cm
# Servo angles: {'x1': 145, 'y1': 49, 'x2': 115, 'y2': 90}
#
# 0: 480x640 7 persons, 116.0ms
# Speed: 0.9ms preprocess, 116.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 112.8ms
# Speed: 0.9ms preprocess, 112.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 171
# Balloon position: (-85.73, 60.03, 45.49)
# C1 Distance: 114.11 cm
# C2 Distance: 149.14 cm
# Servo angles: {'x1': 145, 'y1': 49, 'x2': 115, 'y2': 90}
#
# 0: 480x640 5 persons, 114.8ms
# Speed: 0.9ms preprocess, 114.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 119.1ms
# Speed: 1.0ms preprocess, 119.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 172
# Balloon position: (-85.73, 60.03, 45.49)
# C1 Distance: 114.11 cm
# C2 Distance: 149.14 cm
# Servo angles: {'x1': 145, 'y1': 49, 'x2': 115, 'y2': 90}
#
# 0: 480x640 8 persons, 116.8ms
# Speed: 0.9ms preprocess, 116.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 113.6ms
# Speed: 0.9ms preprocess, 113.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 173
# Balloon position: (-85.73, 60.03, 45.49)
# C1 Distance: 114.11 cm
# C2 Distance: 149.14 cm
# Servo angles: {'x1': 145, 'y1': 49, 'x2': 115, 'y2': 90}
#
# 0: 480x640 7 persons, 115.2ms
# Speed: 0.9ms preprocess, 115.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 scissors, 114.4ms
# Speed: 1.0ms preprocess, 114.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 174
# Balloon position: (-85.73, 60.03, 45.49)
# C1 Distance: 114.11 cm
# C2 Distance: 149.14 cm
# Servo angles: {'x1': 145, 'y1': 49, 'x2': 115, 'y2': 90}
#
# 0: 480x640 6 persons, 116.1ms
# Speed: 0.9ms preprocess, 116.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 scissors, 129.9ms
# Speed: 1.2ms preprocess, 129.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 175
# Balloon position: (-85.73, 60.03, 45.49)
# C1 Distance: 114.11 cm
# C2 Distance: 149.14 cm
# Servo angles: {'x1': 145, 'y1': 49, 'x2': 115, 'y2': 90}
#
# 0: 480x640 4 persons, 115.9ms
# Speed: 0.9ms preprocess, 115.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 airplane, 1 scissors, 115.2ms
# Speed: 0.9ms preprocess, 115.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# ----------------------------------------- Program finished -----------------------------------------
# Total frames: 175, Total time: 54.52 seconds
# Detected classes: ['sports ball']
# Frame centers: (640.0, 480.0), (640.0, 480.0)
# FPS: 3.21
# Final balloon position: (-85.73, 60.03, 45.49)
# Final C1 distance: 114.11 cm
# Final C2 distance: 149.14 cm
# Servo angles: {'x1': 145, 'y1': 49, 'x2': 115, 'y2': 90}
# Lyapunov exponent: 0.7126 per second
# Predictability horizon: 1.40 seconds
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
enumerate_cameras()
# Out:
# [1200: MacBook Air Camera]
