# %%
# Install dependencies
# %pip install ultralytics
# %pip install opencv-python
# %pip install simple_pid
# %pip install numpy
# %pip install pyserial
# %pip install cv2-enumerate-cameras
# %pip install scikit-learn
# %pip install nolds
# %pip install google-api-python-client
# %pip install google-auth-httplib2
# %pip install google-auth-oauthlib
# Out:
# Requirement already satisfied: ultralytics in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (8.3.186)
# Requirement already satisfied: numpy>=1.23.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (2.3.1)
# Requirement already satisfied: matplotlib>=3.3.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (3.10.3)
# Requirement already satisfied: opencv-python>=4.6.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (1.16.0)
# Requirement already satisfied: torch>=1.8.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (2.7.1)
# Requirement already satisfied: torchvision>=0.9.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (0.22.1)
# Requirement already satisfied: psutil in /Users/Leonardo/Library/Python/3.13/lib/python/site-packages (from ultralytics) (7.0.0)
# Requirement already satisfied: py-cpuinfo in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (2.3.0)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/Leonardo/Library/Python/3.13/lib/python/site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/Leonardo/Library/Python/3.13/lib/python/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/Leonardo/Library/Python/3.13/lib/python/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (2026.1.4)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (3.20.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (4.14.0)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (2025.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: opencv-python in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from opencv-python) (2.3.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: simple_pid in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (2.0.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (2.3.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pyserial in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (3.5)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: cv2-enumerate-cameras in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (1.3.0)
# Requirement already satisfied: pyobjc-framework-AVFoundation in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from cv2-enumerate-cameras) (11.1)
# Requirement already satisfied: pyobjc-core>=11.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pyobjc-framework-AVFoundation->cv2-enumerate-cameras) (11.1)
# Requirement already satisfied: pyobjc-framework-CoreMedia>=11.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pyobjc-framework-AVFoundation->cv2-enumerate-cameras) (11.1)
# Requirement already satisfied: pyobjc-framework-CoreAudio>=11.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pyobjc-framework-AVFoundation->cv2-enumerate-cameras) (11.1)
# Requirement already satisfied: pyobjc-framework-Cocoa>=11.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pyobjc-framework-AVFoundation->cv2-enumerate-cameras) (11.1)
# Requirement already satisfied: pyobjc-framework-Quartz>=11.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pyobjc-framework-AVFoundation->cv2-enumerate-cameras) (11.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from scikit-learn) (2.3.1)
# Requirement already satisfied: scipy>=1.8.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from scikit-learn) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: nolds in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (0.6.2)
# Requirement already satisfied: numpy<3.0,>1.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from nolds) (2.3.1)
# Requirement already satisfied: future in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from nolds) (1.0.0)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from nolds) (80.9.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: google-api-python-client in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (2.192.0)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-python-client) (0.31.2)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-python-client) (2.49.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-python-client) (0.3.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-python-client) (2.30.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-python-client) (4.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (1.73.0)
# Requirement already satisfied: protobuf<7.0.0,>=4.25.8 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (6.33.5)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (1.27.1)
# Requirement already satisfied: requests<3.0.0,>=2.20.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.32.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (46.0.5)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (4.9.1)
# Requirement already satisfied: pyparsing<4,>=3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client) (3.2.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests<3.0.0,>=2.20.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests<3.0.0,>=2.20.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests<3.0.0,>=2.20.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests<3.0.0,>=2.20.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2026.1.4)
# Requirement already satisfied: pyasn1>=0.1.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from rsa<5,>=3.1.4->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (0.6.2)
# Requirement already satisfied: cffi>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from cryptography>=38.0.3->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (2.0.0)
# Requirement already satisfied: pycparser in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (3.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: google-auth-httplib2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (0.3.0)
# Requirement already satisfied: google-auth<3.0.0,>=1.32.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth-httplib2) (2.49.0)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth-httplib2) (0.31.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth<3.0.0,>=1.32.0->google-auth-httplib2) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth<3.0.0,>=1.32.0->google-auth-httplib2) (46.0.5)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth<3.0.0,>=1.32.0->google-auth-httplib2) (4.9.1)
# Requirement already satisfied: pyparsing<4,>=3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httplib2<1.0.0,>=0.19.0->google-auth-httplib2) (3.2.3)
# Requirement already satisfied: pyasn1>=0.1.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=1.32.0->google-auth-httplib2) (0.6.2)
# Requirement already satisfied: cffi>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=1.32.0->google-auth-httplib2) (2.0.0)
# Requirement already satisfied: pycparser in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=1.32.0->google-auth-httplib2) (3.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: google-auth-oauthlib in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (1.3.0)
# Requirement already satisfied: google-auth!=2.43.0,!=2.44.0,!=2.45.0,<3.0.0,>=2.15.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth-oauthlib) (2.49.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth-oauthlib) (2.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth!=2.43.0,!=2.44.0,!=2.45.0,<3.0.0,>=2.15.0->google-auth-oauthlib) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth!=2.43.0,!=2.44.0,!=2.45.0,<3.0.0,>=2.15.0->google-auth-oauthlib) (46.0.5)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth!=2.43.0,!=2.44.0,!=2.45.0,<3.0.0,>=2.15.0->google-auth-oauthlib) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from rsa<5,>=3.1.4->google-auth!=2.43.0,!=2.44.0,!=2.45.0,<3.0.0,>=2.15.0->google-auth-oauthlib) (0.6.2)
# Requirement already satisfied: cffi>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from cryptography>=38.0.3->google-auth!=2.43.0,!=2.44.0,!=2.45.0,<3.0.0,>=2.15.0->google-auth-oauthlib) (2.0.0)
# Requirement already satisfied: pycparser in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth!=2.43.0,!=2.44.0,!=2.45.0,<3.0.0,>=2.15.0->google-auth-oauthlib) (3.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.3.1)
# Requirement already satisfied: requests>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2026.1.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Configurations
import cv2
import os
import io
import math
import serial
import time
import numpy as np
import nolds
import requests
import pickle
from ultralytics import YOLO
from simple_pid import PID
from cv2_enumerate_cameras import enumerate_cameras
from collections import deque
from sklearn.decomposition import PCA
from googleapiclient.discovery import build
from googleapiclient.http import MediaIoBaseUpload
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request

# Camera configuration
CAMERA_INDEX_1 = 1200                  # Index of the camera  to be used (custom value; check with enumerate_cameras)
CAMERA_INDEX_2 = 1201                  # Index of the camera to be used (custom value; check with enumerate_cameras)

# Movement vector filtering
VECTOR_MIN_LENGTH = 20                 # Minimum length of movement vector to consider (in pixels)
VECTOR_MAX_LENGTH = 200                # Maximum length of movement vector to consider (in pixels)
PIXELS_PER_UNIT = 200.0                # Conversion factor from pixels to real-world units (e.g., cm)
VECTOR_HISTORY_SIZE = 8                # Number of previous positions to store for movement vector calculation

# Geometry setup
CAMERA_DISTANCE = 43                   # Distance between two cameras (used for triangulation)
DISTANCE_UNIT = "cm"                   # Unit of measurement for camera distance

# YOLO model setup
MODEL = YOLO('yolov10s.pt')            # Load YOLOv8 nano model for object detection
CLASS_NAMES = MODEL.names              # List of all class labels in the model
DESIRED_CLASSES = ["sports ball"]      # Classes we want to detect (only track sports balls)

# PID control parameters
PID_KP = 0.015                         # PID Proportional gain
PID_KI = 0.003                         # PID Integral gain
PID_KD = 0.09                          # PID Derivative gain
PID_OUTPUT_LIMITS = (-3, 3)            # Output limits for PID correction to smooth servo movement
ALPHA = 0.2                            # Smoothing factor for servo movement (0 < ALPHA < 1)

# Servo configuration
SERVO_MIN = 0                          # Minimum angle a servo can rotate to
SERVO_MAX = 180                        # Maximum angle a servo can rotate to
SERVO_INIT = {                         # Initial servo positions (centered)
    'x1': 65, 
    'y1': 90, 
    'x2': 115, 
    'y2': 90
}

# Arduino serial communication
ARDUINO_PORT = '/dev/cu.usbmodem11301'  # Serial port where Arduino is connected
ARDUINO_BAUDRATE = 9600                 # Communication speed between Python and Arduino


# Telegram bot configuration
TOKEN = "8750939695:AAHakcI-1T_IC6WkK2CvcPSsSsAT5hnzCrI" # Change to your bot token
CHAT_ID = "-4856182101"                  # Change to your chat ID
ALERT_COOLDOWN = 30                      # Seconds between alerts

# Google Drive configuration
SCOPES = ['https://www.googleapis.com/auth/drive.file'] # Scope for uploading files to Google Drive
POSITIVE_IMAGE_UPLOAD_INTERVAL = 30      # Seconds between positive image uploads to Google Drive
NEGATIVE_IMAGE_UPLOAD_INTERVAL = 60      # Seconds between negative image uploads to Google Drive
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/nolds/datasets.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
# CV2 and camera settings

# Initialize camera
def init_camera(index, verbose=True):
    cap = cv2.VideoCapture(index)
    if not cap.isOpened():
        raise RuntimeError(f"Error: Could not open webcam {index}.")
    if verbose:
        print(f"Camera {index} opened successfully.")
    return cap


# Read current frame
def read_frame(cap):
    ret, frame = cap.read()
    if not ret:
        raise RuntimeError("Failed to capture image from webcam.")
    return frame


# Calculate frame center
def calculate_center(frame):
    height, width = frame.shape[:2]
    x_center, y_center = width / 2, height / 2
    return x_center, y_center


# Check if class is in desired classes
def valid_class(box, class_names=CLASS_NAMES, desired_classes=DESIRED_CLASSES):
    return class_names[int(box.cls)] in desired_classes


# Draw bounding box
def draw_bounding_box(frame, box, class_names=CLASS_NAMES, verbose=True):
    x1, y1, x2, y2 = map(int, box.xyxy[0])
    cv2.rectangle(frame, (x1, y1), (x2, y2), (255, 0, 255), 3)
    
    cls = int(box.cls[0])
    confidence = math.ceil((box.conf[0] * 100)) / 100
    
    org = [x1, y1]
    font = cv2.FONT_HERSHEY_SIMPLEX
    font_scale = 1
    color = (255, 0, 0)
    thickness = 2
    cv2.putText(frame, class_names[cls], org, font, font_scale, color, thickness)
    
    if verbose:
        print(f"Class: {class_names[cls]}, Confidence: {confidence}")


# Draw movement vector
def draw_movement_vector(frame, box, balloon_position, vector_history, avg_dt, prev_position=None, verbose=True):
    x1, y1, x2, y2 = map(int, box.xyxy[0])
    cx_pixel, cy_pixel = int((x1 + x2) / 2), int((y1 + y2) / 2)
    x, y, z = float(balloon_position[0]), float(balloon_position[1]), float(balloon_position[2])

    if len(vector_history) == 0:
        base_px, base_py, base_pz = prev_position if prev_position is not None else (x, y, z)
    else:
        base_px = sum(p[0] for p in vector_history) / len(vector_history)
        base_py = sum(p[1] for p in vector_history) / len(vector_history)
        base_pz = sum(p[2] for p in vector_history) / len(vector_history)

    dx_w, dy_w, dz_w = x - base_px, y - base_py, z - base_pz
    mag_w = math.sqrt(dx_w**2 + dy_w**2 + dz_w**2)
    vel_w = mag_w / avg_dt

    if mag_w > 1e-9:
        ux, uy = dx_w / mag_w, dz_w / mag_w
        length_px = mag_w * PIXELS_PER_UNIT
        length_px = max(VECTOR_MIN_LENGTH, min(length_px, VECTOR_MAX_LENGTH))
        
        end_x = int(cx_pixel - ux * length_px)
        end_y = int(cy_pixel - uy * length_px)
        cv2.arrowedLine(frame, (cx_pixel, cy_pixel), (end_x, end_y), (0, 0, 255), 3, tipLength=0.3)

    vector_history.append((x, y, z))
    new_prev_position = (x, y, z)

    if verbose:
        print(f"3D displacement: ({dx_w:.3f}, {dy_w:.3f}, {dz_w:.3f})")
        print(f"Velocity: {vel_w:.3f} {DISTANCE_UNIT}/s")

    return new_prev_position

# %%
# Calculations

# Calculate balloon coordinates
def triangulation(angles: dict, d=CAMERA_DISTANCE, verbose=True):
    alpha = np.radians(angles['x1'])
    beta = np.radians(angles['x2']-90)
    gamma = np.radians(90-angles['y1'])
    delta = np.radians(90-angles['y2'])
    
    if (np.sin(alpha + beta)) == 0:
        raise ValueError("Invalid angles for triangulation.")
    
    n = d * np.sin(beta) / np.sin(alpha + beta)
    m = d * np.sin(alpha) / np.sin(alpha + beta)

    x1 = n * np.cos(alpha)
    y1 = n * np.sin(alpha)
    z1 = n * np.tan(gamma)
    
    x2 = d - (m * np.cos(beta))
    y2 = m * np.sin(beta)
    z2 = m * np.tan(delta)

    x = (x1 + x2) / 2
    y = (y1 + y2) / 2
    z = (z1 + z2) / 2
    
    if verbose:
        print(f"Balloon position: ({x:.2f}, {y:.2f}, {z:.2f})")
    
    return np.array([x, y, z])


# Calculate distance to camera
def get_distance(camera, balloon_position, d=CAMERA_DISTANCE, verbose=True):
    if camera == 'C1':
        camera_position = np.array([0, 0, 0])
    elif camera == 'C2':
        camera_position = np.array([d, 0, 0])
    else:
        raise ValueError("Invalid camera ID. Use 'C1' or 'C2'.")
    
    distance = np.linalg.norm(balloon_position - camera_position)
    
    if verbose:
        print(f"{camera} Distance: {distance:.2f} {DISTANCE_UNIT}")
    
    return distance

# %%
# Lyapunov exponent

def compute_lyapunov_exponent(positions, dt, method="pca", emb_dim=6, tau=1, min_tsep=10, trajectory_len=20, debug_plot=True):
    positions = np.array(positions)
    if positions.shape[1] != 3:
        raise ValueError("Positions must be of shape (N,3).")

    if method.lower() == "pca":
        pca = PCA(n_components=1)
        scalar_series = pca.fit_transform(positions).flatten()
    elif method.lower() == "norm":
        scalar_series = np.linalg.norm(positions, axis=1)
    elif method.lower() in ["x", "y", "z"]:
        idx = {"x":0, "y":1, "z":2}[method.lower()]
        scalar_series = positions[:, idx]
    else:
        raise ValueError("Invalid method. Choose 'pca', 'norm', 'x', 'y', or 'z'.")

    scalar_series = (scalar_series - np.mean(scalar_series)) / (np.std(scalar_series) + 1e-12)

    lyap_raw = nolds.lyap_r(
        scalar_series,
        emb_dim=emb_dim,
        tau=tau,
        min_tsep=min_tsep,
        trajectory_len=trajectory_len,
        debug_plot=debug_plot
    )
    lyap_exp = lyap_raw / dt
    lyap_time = 1 / lyap_exp if lyap_exp > 0 else float('inf')

    return lyap_exp, lyap_time

# %%
# PID controller

# Initialize PID controller
def init_pid(x_center, y_center, verbose=True):
    global prev_pan, prev_tilt
    prev_pan, prev_tilt = 0, 0
    pid_pan = PID(Kp=PID_KP, Ki=PID_KI, Kd=PID_KD, setpoint=x_center)
    pid_pan.output_limits = PID_OUTPUT_LIMITS
    pid_tilt = PID(Kp=PID_KP, Ki=PID_KI, Kd=PID_KD, setpoint=y_center)
    pid_tilt.output_limits = PID_OUTPUT_LIMITS
    if verbose:
        print("PID controller initialized.")
    return pid_pan, pid_tilt


# Calculate corrections using PID controller
def calculate_corrections(box, pid_pan, pid_tilt, verbose=True):
    global prev_pan, prev_tilt
    x1, y1, x2, y2 = box.xyxy[0]
    x_box = float((x1 + x2) / 2)
    y_box = float((y1 + y2) / 2)
    
    pan_raw = pid_pan(x_box)
    tilt_raw = pid_tilt(y_box)
    pan = ALPHA * pan_raw + (1 - ALPHA) * prev_pan
    tilt = ALPHA * tilt_raw + (1 - ALPHA) * prev_tilt
    prev_pan, prev_tilt = pan, tilt
    
    if verbose:
        print(f"Box: ({x_box}, {y_box})")
        print(f"Pan: {pan}, Tilt: {tilt}")
    return pan, tilt


# Update servo angle
def update_angle(servo_angle, correction):
    if correction > 10:
        correction = 10
    elif correction < -10:
        correction = -10
    return max(SERVO_MIN, min(SERVO_MAX, math.ceil(servo_angle + correction)))

# %%
# Arduino

# Initialize serial connection to arduino
def init_arduino(*, port=ARDUINO_PORT, baudrate=ARDUINO_BAUDRATE, initial_angles=SERVO_INIT, verbose=True):
    try:
        arduino = serial.Serial(port, baudrate)
        time.sleep(2)
        if verbose:
            print(f"Connected to Arduino on {port} at {baudrate} baud.")
        move_servos(arduino, initial_angles)
        return arduino
    except serial.SerialException as e:
        raise RuntimeError(f"Could not connect to Arduino on {port}: {e}")


# Move servos
def move_servos(arduino, angles: dict, verbose=True):
    try:
        command = f"{angles['x1']},{angles['y1']},{angles['x2']},{angles['y2']}\n"
        arduino.write(command.encode())
        arduino.flush()
        if verbose:
            print(f"C1 → X: {angles['x1']:.1f}°, Y: {angles['y1']:.1f}°")
            print(f"C2 → X: {angles['x2']:.1f}°, Y: {angles['y2']:.1f}°")
            
    except serial.SerialException as e:
        print(f"Serial communication error: {e}")

# %%
# Telegram alert

def send_telegram_alert(position, dist_c1, dist_c2, message="🎈 Balão detectado!"):
    global last_alert_time
    now = time.time()
    
    if now - last_alert_time >= ALERT_COOLDOWN:
        x, y, z = position
        message = f"🎈 Balão detectado!\n" \
                f"📍 Coordenadas: x={x:.2f}, y={y:.2f}, z={z:.2f}\n"
        
        if dist_c1 is not None:
            message += f"📏 Distância C1: {dist_c1:.2f} cm\n"
        if dist_c2 is not None:
            message += f"📏 Distância C2: {dist_c2:.2f} cm\n"

        url = f"https://api.telegram.org/bot{TOKEN}/sendMessage"
        data = {"chat_id": CHAT_ID, "text": message}
        response = requests.post(url, data=data)
        
        if response.status_code == 200:
            print("📩 Coordenadas enviadas com sucesso!")
        else:
            print("⚠️ Erro ao enviar coordenadas:", response.text)
        
        last_alert_time = now

# %%
# Drive upload

# Authenticate and create Google Drive service
def authenticate_drive():
    creds = None

    if os.path.exists("token.pickle"):
        with open("token.pickle", "rb") as f:
            creds = pickle.load(f)

    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file("credentials.json", SCOPES)
            creds = flow.run_local_server(port=0)

        with open("token.pickle", "wb") as f:
            pickle.dump(creds, f)

    return build("drive", "v3", credentials=creds)


# Create folder to store frames in Google Drive
def create_folder(service, name):
    folder_metadata = {
        "name": name,
        "mimeType": "application/vnd.google-apps.folder"
    }

    folder = service.files().create(
        body=folder_metadata,
        fields="id"
    ).execute()

    return folder["id"]


# Upload frame to Google Drive
def upload_frame(service, frame, folder_id, code):
    global last_positive_c1_upload_time, last_positive_c2_upload_time, last_negative_c1_upload_time, last_negative_c2_upload_time, frame_count
    now = time.time()
    
    y1 = code == 'Y1' and now - last_positive_c1_upload_time >= POSITIVE_IMAGE_UPLOAD_INTERVAL
    y2 = code == 'Y2' and now - last_positive_c2_upload_time >= POSITIVE_IMAGE_UPLOAD_INTERVAL
    n1 = code == 'N1' and now - last_negative_c1_upload_time >= NEGATIVE_IMAGE_UPLOAD_INTERVAL
    n2 = code == 'N2' and now - last_negative_c2_upload_time >= NEGATIVE_IMAGE_UPLOAD_INTERVAL

    if y1 or y2 or n1 or n2:
        _, buffer = cv2.imencode(".jpg", frame)
        file_bytes = io.BytesIO(buffer)

        media = MediaIoBaseUpload(file_bytes, mimetype="image/jpeg")
        
        filename = f"{code}_{frame_count}"

        file_metadata = {
            "name": filename,
            "parents": [folder_id]
        }

        service.files().create(
            body=file_metadata,
            media_body=media
        ).execute()
        
        if n1:
            last_negative_c1_upload_time = now
        elif n2:
            last_negative_c2_upload_time = now
        elif y1:
            last_positive_c1_upload_time = now
        elif y2:
            last_positive_c2_upload_time = now
        n1, n2, y1, y2 = False, False, False, False

# %%
# Print functions

# Print divider
def print_div(text):
    print("\n" + f" {text} ".center(100, '-') + "\n")


# Print available cameras
def print_cameras():
    for camera_info in enumerate_cameras():
        print(f'{camera_info.index}: {camera_info.name}')


# Print final information
def final_prints(frame_count, x1_center, y1_center, x2_center, y2_center, frame_delay, balloon_position, dist_c1, dist_c2, servo_angles, lyap_exp, lyap_time):
    x, y, z = balloon_position
    print(f"Total frames: {frame_count}, Total time: {frame_delay*frame_count:.2f} seconds")
    print(f"Detected classes: {DESIRED_CLASSES}")
    print(f"Frame centers: ({x1_center}, {y1_center}), ({x2_center}, {y2_center})")
    print(f"FPS: {(1/frame_delay):.2f}")
    print(f"Final balloon position: ({x:.2f}, {y:.2f}, {z:.2f})")
    print(f"Final C1 distance: {dist_c1:.2f} {DISTANCE_UNIT}")
    print(f"Final C2 distance: {dist_c2:.2f} {DISTANCE_UNIT}")
    print(f"Servo angles: {servo_angles}")
    print(f"Lyapunov exponent: {lyap_exp:.4f} per second")
    if lyap_time != float('inf'):
        print(f"Predictability horizon: {lyap_time:.2f} seconds\n")
    else:
        print("Predictability horizon: Infinite (non-chaotic behavior)\n")

# %%
# Main program
print_div("Available cameras")
print_cameras()

print_div("Initial settings")
frame_count, total_time, last_alert_time= 0, 0, 0
last_positive_c1_upload_time, last_positive_c2_upload_time = 0, 0
last_negative_c1_upload_time, last_negative_c2_upload_time = 0, 0
prev_time = time.time()

SERVO_INIT = {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
servo_angles = SERVO_INIT
vector_history = deque(maxlen=VECTOR_HISTORY_SIZE)
prev_position = None
balloon_positions_history = []

arduino = init_arduino(initial_angles=servo_angles)
service = authenticate_drive()
folder_id = create_folder(service, "frames")

cap1 = init_camera(CAMERA_INDEX_1)
cap2 = init_camera(CAMERA_INDEX_2)
frame1 = read_frame(cap1)
frame2 = read_frame(cap2)

x1_center, y1_center = calculate_center(frame1)
x2_center, y2_center = calculate_center(frame2)
pid_pan1, pid_tilt1 = init_pid(x1_center, y1_center)
pid_pan2, pid_tilt2 = init_pid(x2_center, y2_center)

print_div("Program started")
try:
    while True:
        print(f"Frame number: {frame_count}")
        current_time = time.time()
        frame_delay = current_time - prev_time
        total_time += frame_delay
        avg_frame_delay = total_time / frame_count if frame_count > 0 else frame_delay
        prev_time = current_time
        
        c1_found, c2_found = False, False
        balloon_position = triangulation(servo_angles)
        balloon_positions_history.append(balloon_position.copy())
        dist_c1 = get_distance('C1', balloon_position)
        dist_c2 = get_distance('C2', balloon_position)
        print(f"Servo angles: {servo_angles}")
        
        x1_correction, y1_correction = 0, 0
        frame1 = read_frame(cap1)
        results1 = MODEL(frame1, stream=True)
        for r1 in results1:
            if not r1.boxes:
                continue
            for box1 in r1.boxes:
                if valid_class(box1):
                    #upload_frame(service, frame1, folder_id, 'Y1')
                    draw_bounding_box(frame1, box1)
                    prev_position = draw_movement_vector(frame1, box1, balloon_position, vector_history, avg_frame_delay, prev_position)
                    x1_correction, y1_correction = calculate_corrections(box1, pid_pan1, pid_tilt1)
                    #send_telegram_alert(balloon_position, dist_c1, dist_c2)
                    c1_found = True
                
        x2_correction, y2_correction = 0, 0
        frame2 = read_frame(cap2)
        results2 = MODEL(frame2, stream=True)
        for r2 in results2:
            if not r2.boxes:
                continue
            for box2 in r2.boxes:
                if valid_class(box2):
                    #upload_frame(service, frame2, folder_id, 'Y2')
                    draw_bounding_box(frame2, box2)
                    prev_position = draw_movement_vector(frame2, box2, balloon_position, vector_history, avg_frame_delay, prev_position)
                    x2_correction, y2_correction = calculate_corrections(box2, pid_pan2, pid_tilt2)
                    #send_telegram_alert(balloon_position, dist_c1, dist_c2)
                    c2_found = True
        
        if c1_found == False:
            upload_frame(service, frame1, folder_id, 'N1')
        if c2_found == False:
            upload_frame(service, frame2, folder_id, 'N2')

        c1_change = x1_correction != 0 or y1_correction != 0
        c2_change = x2_correction != 0 or y2_correction != 0
        if c1_change:
            y1_correction *= -1 # type: ignore
            servo_angles['x1'] = update_angle(servo_angles['x1'], x1_correction)
            servo_angles['y1'] = update_angle(servo_angles['y1'], y1_correction)
        if c2_change:
            y2_correction *= -1 # type: ignore
            servo_angles['x2'] = update_angle(servo_angles['x2'], x2_correction)
            servo_angles['y2'] = update_angle(servo_angles['y2'], y2_correction)
        if c1_change or c2_change:
            move_servos(arduino, servo_angles)
        
        cv2.imshow("Image1", frame1)
        cv2.imshow("Image2", frame2)
        if cv2.waitKey(1) == ord('q'):
            break
        frame_count += 1
finally:
    print_div("Program finished")
    lyap_exp, lyap_time = compute_lyapunov_exponent(balloon_positions_history, avg_frame_delay)
    final_prints(frame_count, x1_center, y1_center, x2_center, y2_center, avg_frame_delay, 
                 balloon_position, dist_c1, dist_c2, servo_angles, lyap_exp, lyap_time)
    cap1.release()
    cap2.release()
    cv2.destroyAllWindows()
    arduino.close()
# Out:
# ---------------------------------------- Available cameras -----------------------------------------
#
# 1200: USB Camera VID:1133 PID:2085
# 1201: C270 HD WEBCAM
# 1202: MacBook Air Camera
#
# ----------------------------------------- Initial settings -----------------------------------------
#
# Connected to Arduino on /dev/cu.usbmodem11301 at 9600 baud.
# C1 → X: 65.0°, Y: 90.0°
# C2 → X: 115.0°, Y: 90.0°
# Camera 1200 opened successfully.
# Camera 1201 opened successfully.
# PID controller initialized.
# PID controller initialized.
#
# ----------------------------------------- Program started ------------------------------------------
#
# Frame number: 0
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 (no detections), 113.1ms
# Speed: 3.5ms preprocess, 113.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 98.0ms
# Speed: 1.6ms preprocess, 98.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 1
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 (no detections), 127.0ms
# Speed: 6.2ms preprocess, 127.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 94.8ms
# Speed: 0.9ms preprocess, 94.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 2
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 (no detections), 95.0ms
# Speed: 1.0ms preprocess, 95.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 230.8ms
# Speed: 0.9ms preprocess, 230.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 3
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 (no detections), 108.5ms
# Speed: 1.0ms preprocess, 108.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 100.1ms
# Speed: 1.0ms preprocess, 100.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 4
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 (no detections), 93.6ms
# Speed: 0.9ms preprocess, 93.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 89.0ms
# Speed: 0.9ms preprocess, 89.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 5
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 (no detections), 90.1ms
# Speed: 0.9ms preprocess, 90.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 93.4ms
# Speed: 1.0ms preprocess, 93.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 6
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 (no detections), 93.4ms
# Speed: 0.9ms preprocess, 93.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 95.0ms
# Speed: 0.9ms preprocess, 95.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 7
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 (no detections), 92.8ms
# Speed: 1.0ms preprocess, 92.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 93.8ms
# Speed: 0.9ms preprocess, 93.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 8
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 (no detections), 94.7ms
# Speed: 0.9ms preprocess, 94.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 92.2ms
# Speed: 0.9ms preprocess, 92.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 9
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 (no detections), 93.4ms
# Speed: 0.9ms preprocess, 93.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 95.1ms
# Speed: 0.9ms preprocess, 95.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 10
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 (no detections), 94.7ms
# Speed: 0.9ms preprocess, 94.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 95.0ms
# Speed: 0.9ms preprocess, 95.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 11
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 (no detections), 94.2ms
# Speed: 0.9ms preprocess, 94.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 94.3ms
# Speed: 0.9ms preprocess, 94.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 12
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 (no detections), 93.6ms
# Speed: 1.1ms preprocess, 93.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 94.5ms
# Speed: 0.9ms preprocess, 94.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 13
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 (no detections), 94.8ms
# Speed: 1.0ms preprocess, 94.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 92.7ms
# Speed: 0.9ms preprocess, 92.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 14
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 (no detections), 92.2ms
# Speed: 0.9ms preprocess, 92.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 94.0ms
# Speed: 0.9ms preprocess, 94.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 15
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 (no detections), 94.2ms
# Speed: 1.0ms preprocess, 94.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 94.4ms
# Speed: 0.9ms preprocess, 94.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 16
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 (no detections), 95.0ms
# Speed: 0.9ms preprocess, 95.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 94.5ms
# Speed: 0.9ms preprocess, 94.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 17
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 (no detections), 94.7ms
# Speed: 0.9ms preprocess, 94.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 94.0ms
# Speed: 0.9ms preprocess, 94.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 18
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 (no detections), 94.3ms
# Speed: 1.0ms preprocess, 94.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 95.2ms
# Speed: 0.9ms preprocess, 95.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 19
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 (no detections), 94.3ms
# Speed: 0.9ms preprocess, 94.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 95.6ms
# Speed: 0.9ms preprocess, 95.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 20
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 (no detections), 93.0ms
# Speed: 0.9ms preprocess, 93.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 93.5ms
# Speed: 0.9ms preprocess, 93.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 21
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 (no detections), 94.5ms
# Speed: 1.0ms preprocess, 94.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 92.2ms
# Speed: 0.9ms preprocess, 92.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 22
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 (no detections), 93.7ms
# Speed: 0.9ms preprocess, 93.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 94.7ms
# Speed: 0.9ms preprocess, 94.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 23
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 (no detections), 94.4ms
# Speed: 1.0ms preprocess, 94.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 94.4ms
# Speed: 0.9ms preprocess, 94.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 24
# Balloon position: (7.68, 16.47, 0.00)
# C1 Distance: 18.17 cm
# C2 Distance: 38.97 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 115, 'y2': 90}
#
# 0: 480x640 (no detections), 95.6ms
# Speed: 0.9ms preprocess, 95.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 balloon, 93.3ms
# Class: balloon, Confidence: 0.74
# 3D displacement: (0.000, 0.000, 0.000)
# Velocity: 0.000 cm/s
# Box: (138.88565063476562, 348.558349609375)
# Pan: 0.6000000000000001, Tilt: 0.6000000000000001
# Speed: 0.9ms preprocess, 93.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 65.0°, Y: 90.0°
# C2 → X: 116.0°, Y: 90.0°
# Frame number: 25
# Balloon position: (7.97, 17.09, 0.00)
# C1 Distance: 18.85 cm
# C2 Distance: 38.98 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 116, 'y2': 90}
#
# 0: 480x640 (no detections), 94.6ms
# Speed: 1.0ms preprocess, 94.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 balloon, 93.6ms
# Class: balloon, Confidence: 0.79
# 3D displacement: (0.287, 0.617, 0.000)
# Velocity: 0.885 cm/s
# Box: (207.65127563476562, 418.01556396484375)
# Pan: -0.12, Tilt: -0.12
# Speed: 0.9ms preprocess, 93.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 65.0°, Y: 90.0°
# C2 → X: 116.0°, Y: 91.0°
# Frame number: 26
# Balloon position: (7.97, 17.09, -0.34)
# C1 Distance: 18.86 cm
# C2 Distance: 38.98 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 116, 'y2': 91}
#
# 0: 480x640 (no detections), 94.9ms
# Speed: 1.0ms preprocess, 94.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 balloon, 93.2ms
# Class: balloon, Confidence: 0.91
# 3D displacement: (0.144, 0.308, -0.340)
# Velocity: 0.642 cm/s
# Box: (228.78880310058594, 362.980224609375)
# Pan: 0.36945307542468553, Tilt: 0.5040000000000001
# Speed: 0.9ms preprocess, 93.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 65.0°, Y: 90.0°
# C2 → X: 117.0°, Y: 91.0°
# Frame number: 27
# Balloon position: (8.26, 17.70, -0.34)
# C1 Distance: 19.54 cm
# C2 Distance: 39.00 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 117, 'y2': 91}
#
# 0: 480x640 (no detections), 94.3ms
# Speed: 0.9ms preprocess, 94.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 balloon, 94.8ms
# Class: balloon, Confidence: 0.91
# 3D displacement: (0.383, 0.822, -0.227)
# Velocity: 1.278 cm/s
# Box: (227.0216064453125, 369.85980224609375)
# Pan: 0.8955624603397485, Tilt: 0.821780491335058
# Speed: 0.9ms preprocess, 94.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 65.0°, Y: 90.0°
# C2 → X: 118.0°, Y: 91.0°
# Frame number: 28
# Balloon position: (8.54, 18.32, -0.34)
# C1 Distance: 20.22 cm
# C2 Distance: 39.03 cm
# Servo angles: {'x1': 65, 'y1': 90, 'x2': 118, 'y2': 91}
#
# 0: 480x640 1 balloon, 95.0ms
# Class: balloon, Confidence: 0.29
# 3D displacement: (0.576, 1.234, -0.170)
# Velocity: 1.921 cm/s
# Box: (604.635986328125, 480.8995361328125)
# Pan: 1.1563673328389286, Tilt: 0.6462344442534678
# Speed: 1.0ms preprocess, 95.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 balloon, 92.6ms
# Class: balloon, Confidence: 0.89
# 3D displacement: (0.461, 0.988, -0.136)
# Velocity: 1.537 cm/s
# Box: (235.36688232421875, 369.4071044921875)
# Pan: 1.5250938662711429, Tilt: 1.1169875554027744
# Speed: 0.9ms preprocess, 92.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 67.0°, Y: 90.0°
# C2 → X: 120.0°, Y: 90.0°
# Frame number: 29
# Balloon position: (8.46, 19.94, 0.00)
# C1 Distance: 21.66 cm
# C2 Distance: 39.88 cm
# Servo angles: {'x1': 67, 'y1': 90, 'x2': 120, 'y2': 90}
#
# 0: 480x640 1 balloon, 94.2ms
# Class: balloon, Confidence: 0.4
# 3D displacement: (0.304, 2.441, 0.227)
# Velocity: 3.533 cm/s
# Box: (286.73126220703125, 262.0074462890625)
# Pan: 1.8200750930169145, Tilt: 1.4935900443222196
# Speed: 1.0ms preprocess, 94.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 balloon, 94.6ms
# Class: balloon, Confidence: 0.69
# 3D displacement: (0.261, 2.093, 0.195)
# Velocity: 3.028 cm/s
# Box: (286.24420166015625, 387.4854736328125)
# Pan: 0.8560600744135316, Tilt: 0.9172026354527487
# Speed: 0.9ms preprocess, 94.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 69.0°, Y: 89.0°
# C2 → X: 121.0°, Y: 90.0°
# Frame number: 30
# Balloon position: (8.06, 20.99, 0.20)
# C1 Distance: 22.49 cm
# C2 Distance: 40.76 cm
# Servo angles: {'x1': 69, 'y1': 89, 'x2': 121, 'y2': 90}
#
# 0: 480x640 (no detections), 94.2ms
# Speed: 1.0ms preprocess, 94.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 balloon, 94.4ms
# Class: balloon, Confidence: 0.9
# 3D displacement: (-0.176, 2.886, 0.366)
# Velocity: 4.252 cm/s
# Box: (306.96221923828125, 397.0379638671875)
# Pan: 0.9582590786270886, Tilt: 0.9714051137818331
# Speed: 0.9ms preprocess, 94.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 69.0°, Y: 89.0°
# C2 → X: 122.0°, Y: 90.0°
# Frame number: 31
# Balloon position: (8.32, 21.67, 0.20)
# C1 Distance: 23.21 cm
# C2 Distance: 40.90 cm
# Servo angles: {'x1': 69, 'y1': 89, 'x2': 122, 'y2': 90}
#
# 0: 480x640 (no detections), 94.7ms
# Speed: 1.0ms preprocess, 94.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 balloon, 92.8ms
# Class: balloon, Confidence: 0.94
# 3D displacement: (0.036, 2.997, 0.348)
# Velocity: 4.488 cm/s
# Box: (317.95465087890625, 405.7852783203125)
# Pan: 1.366607262901671, Tilt: 1.0335788475550236
# Speed: 0.9ms preprocess, 92.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 69.0°, Y: 89.0°
# C2 → X: 124.0°, Y: 89.0°
# Frame number: 32
# Balloon position: (8.84, 23.04, 0.57)
# C1 Distance: 24.68 cm
# C2 Distance: 41.20 cm
# Servo angles: {'x1': 69, 'y1': 89, 'x2': 124, 'y2': 89}
#
# 0: 480x640 (no detections), 94.8ms
# Speed: 1.0ms preprocess, 94.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 balloon, 93.7ms
# Class: balloon, Confidence: 0.8
# 3D displacement: (0.517, 3.792, 0.695)
# Velocity: 5.892 cm/s
# Box: (342.0179443359375, 405.1217041015625)
# Pan: 1.0456405145939198, Tilt: 1.426863078044019
# Speed: 0.9ms preprocess, 93.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 69.0°, Y: 89.0°
# C2 → X: 126.0°, Y: 88.0°
# Frame number: 33
# Balloon position: (9.38, 24.43, 0.95)
# C1 Distance: 26.18 cm
# C2 Distance: 41.57 cm
# Servo angles: {'x1': 69, 'y1': 89, 'x2': 126, 'y2': 88}
#
# 0: 480x640 (no detections), 94.7ms
# Speed: 0.9ms preprocess, 94.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 balloon, 93.0ms
# Class: balloon, Confidence: 0.46
# 3D displacement: (0.941, 4.437, 0.960)
# Velocity: 7.148 cm/s
# Box: (403.196533203125, 552.6866455078125)
# Pan: 0.23651241167513581, Tilt: 0.5414904624352153
# Speed: 0.9ms preprocess, 93.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 69.0°, Y: 89.0°
# C2 → X: 127.0°, Y: 88.0°
# Frame number: 34
# Balloon position: (9.65, 25.13, 0.96)
# C1 Distance: 26.94 cm
# C2 Distance: 41.77 cm
# Servo angles: {'x1': 69, 'y1': 89, 'x2': 127, 'y2': 88}
#
# 0: 480x640 (no detections), 93.5ms
# Speed: 0.9ms preprocess, 93.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 balloon, 94.4ms
# Class: balloon, Confidence: 0.71
# 3D displacement: (1.071, 4.301, 0.808)
# Velocity: 7.064 cm/s
# Box: (408.73797607421875, 461.80340576171875)
# Pan: 0.7892099293401087, Tilt: 1.0331923699481722
# Speed: 0.9ms preprocess, 94.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 69.0°, Y: 89.0°
# C2 → X: 128.0°, Y: 87.0°
# Frame number: 35
# Balloon position: (9.92, 25.84, 1.34)
# C1 Distance: 27.72 cm
# C2 Distance: 42.00 cm
# Servo angles: {'x1': 69, 'y1': 89, 'x2': 128, 'y2': 87}
#
# 0: 480x640 (no detections), 93.8ms
# Speed: 1.2ms preprocess, 93.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 balloon, 91.5ms
# Class: balloon, Confidence: 0.8
# 3D displacement: (1.206, 4.161, 1.023)
# Velocity: 7.093 cm/s
# Box: (410.8284606933594, 469.5539245605469)
# Pan: 1.2313679434720872, Tilt: 0.9477079524816974
# Speed: 0.9ms preprocess, 91.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 69.0°, Y: 89.0°
# C2 → X: 130.0°, Y: 87.0°
# Frame number: 36
# Balloon position: (10.48, 27.29, 1.37)
# C1 Distance: 29.26 cm
# C2 Distance: 42.48 cm
# Servo angles: {'x1': 69, 'y1': 89, 'x2': 130, 'y2': 87}
#
# 0: 480x640 1 balloon, 94.0ms
# Class: balloon, Confidence: 0.77
# 3D displacement: (1.589, 4.667, 0.838)
# Velocity: 8.095 cm/s
# Box: (268.0955810546875, 283.65545654296875)
# Pan: 1.58509435477767, Tilt: 1.358166361985358
# Speed: 1.0ms preprocess, 94.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 balloon, 94.2ms
# Class: balloon, Confidence: 0.72
# 3D displacement: (1.338, 3.748, 0.668)
# Velocity: 6.532 cm/s
# Box: (434.96429443359375, 464.97296142578125)
# Pan: 0.6960512313480873, Tilt: 1.6865330895882864
# Speed: 0.9ms preprocess, 94.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 71.0°, Y: 88.0°
# C2 → X: 131.0°, Y: 86.0°
# Frame number: 37
# Balloon position: (9.91, 28.77, 2.06)
# C1 Distance: 30.50 cm
# C2 Distance: 43.90 cm
# Servo angles: {'x1': 71, 'y1': 88, 'x2': 131, 'y2': 86}
#
# 0: 480x640 1 balloon, 94.4ms
# Class: balloon, Confidence: 0.82
# 3D displacement: (0.516, 4.307, 1.193)
# Velocity: 7.403 cm/s
# Box: (263.95751953125, 281.207275390625)
# Pan: 1.15684098507847, Tilt: 1.9492264716706293
# Speed: 1.0ms preprocess, 94.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 balloon, 94.4ms
# Class: balloon, Confidence: 0.46
# 3D displacement: (0.285, 3.335, 0.960)
# Velocity: 5.730 cm/s
# Box: (467.42626953125, 480.0)
# Pan: 0.3254727880627759, Tilt: 1.1861613226173366
# Speed: 0.9ms preprocess, 94.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 73.0°, Y: 87.0°
# C2 → X: 132.0°, Y: 85.0°
# Frame number: 38
# Balloon position: (9.28, 30.36, 2.82)
# C1 Distance: 31.87 cm
# C2 Distance: 45.46 cm
# Servo angles: {'x1': 73, 'y1': 87, 'x2': 132, 'y2': 85}
#
# 0: 480x640 1 balloon, 94.8ms
# Class: balloon, Confidence: 0.74
# 3D displacement: (-0.537, 4.040, 1.479)
# Velocity: 7.237 cm/s
# Box: (266.66229248046875, 293.1246337890625)
# Pan: 0.8603782304502208, Tilt: 1.06188188533778
# Speed: 1.0ms preprocess, 94.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 94.4ms
# Speed: 0.9ms preprocess, 94.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 74.0°, Y: 86.0°
# C2 → X: 132.0°, Y: 85.0°
# Frame number: 39
# Balloon position: (8.82, 30.77, 3.13)
# C1 Distance: 32.17 cm
# C2 Distance: 46.10 cm
# Servo angles: {'x1': 74, 'y1': 86, 'x2': 132, 'y2': 85}
#
# 0: 480x640 1 balloon, 90.5ms
# Class: balloon, Confidence: 0.38
# 3D displacement: (-1.050, 3.537, 1.513)
# Velocity: 6.749 cm/s
# Box: (640.5574951171875, 477.6038818359375)
# Pan: 0.08830258436017657, Tilt: 0.249505508270224
# Speed: 0.9ms preprocess, 90.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 94.8ms
# Speed: 1.2ms preprocess, 94.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 75.0°, Y: 86.0°
# C2 → X: 132.0°, Y: 85.0°
# Frame number: 40
# Balloon position: (8.36, 31.19, 3.17)
# C1 Distance: 32.45 cm
# C2 Distance: 46.72 cm
# Servo angles: {'x1': 75, 'y1': 86, 'x2': 132, 'y2': 85}
#
# 0: 480x640 1 balloon, 94.8ms
# Class: balloon, Confidence: 0.29
# 3D displacement: (-1.447, 3.163, 1.279)
# Velocity: 6.355 cm/s
# Box: (299.9276428222656, 313.98321533203125)
# Pan: 0.6706420674881414, Tilt: 0.7996044066161793
# Speed: 0.9ms preprocess, 94.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 balloon, 94.1ms
# Class: balloon, Confidence: 0.33
# 3D displacement: (-1.286, 2.406, 1.003)
# Velocity: 4.984 cm/s
# Box: (480.8799743652344, 480.0)
# Pan: 1.1365136539905132, Tilt: 1.2344590049511344
# Speed: 0.9ms preprocess, 94.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 76.0°, Y: 86.0°
# C2 → X: 134.0°, Y: 84.0°
# Frame number: 41
# Balloon position: (8.34, 33.47, 3.74)
# C1 Distance: 34.69 cm
# C2 Distance: 48.32 cm
# Servo angles: {'x1': 76, 'y1': 86, 'x2': 134, 'y2': 84}
#
# 0: 480x640 (no detections), 94.7ms
# Speed: 0.9ms preprocess, 94.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 balloon, 93.9ms
# Class: balloon, Confidence: 0.76
# 3D displacement: (-1.104, 4.012, 1.344)
# Velocity: 7.596 cm/s
# Box: (408.8802185058594, 480.09869384765625)
# Pan: 1.5092109231924107, Tilt: 1.5756609170155147
# Speed: 0.9ms preprocess, 93.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 76.0°, Y: 86.0°
# C2 → X: 136.0°, Y: 83.0°
# Frame number: 42
# Balloon position: (8.82, 35.39, 4.30)
# C1 Distance: 36.73 cm
# C2 Distance: 49.39 cm
# Servo angles: {'x1': 76, 'y1': 86, 'x2': 136, 'y2': 83}
#
# 0: 480x640 1 airplane, 1 balloon, 95.5ms
# Class: balloon, Confidence: 0.58
# 3D displacement: (-0.358, 5.164, 1.606)
# Velocity: 9.531 cm/s
# Box: (730.909423828125, 480.4495849609375)
# Pan: 0.6073687385539286, Tilt: 0.6605287336124117
# Speed: 0.9ms preprocess, 95.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 balloons, 94.4ms
# Class: balloon, Confidence: 0.39
# 3D displacement: (-0.151, 4.152, 1.240)
# Velocity: 7.624 cm/s
# Box: (433.30462646484375, 480.5121154785156)
# Pan: 0.13737302342237823, Tilt: 1.095008353294423
# Class: balloon, Confidence: 0.36
# 3D displacement: (-0.016, 3.324, 0.961)
# Velocity: 6.084 cm/s
# Box: (496.36968994140625, 160.1710205078125)
# Pan: -0.23862354868286212, Tilt: 1.4425920490400321
# Speed: 0.9ms preprocess, 94.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 77.0°, Y: 86.0°
# C2 → X: 136.0°, Y: 82.0°
# Frame number: 43
# Balloon position: (8.30, 35.94, 4.80)
# C1 Distance: 37.19 cm
# C2 Distance: 50.19 cm
# Servo angles: {'x1': 77, 'y1': 86, 'x2': 136, 'y2': 82}
#
# 0: 480x640 1 balloon, 91.1ms
# Class: balloon, Confidence: 0.56
# 3D displacement: (-0.408, 3.042, 1.186)
# Velocity: 5.856 cm/s
# Box: (744.8924560546875, 480.45343017578125)
# Pan: -0.7908988389462898, Tilt: 1.4998451992841249
# Speed: 0.9ms preprocess, 91.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 balloon, 93.9ms
# Class: balloon, Confidence: 0.84
# 3D displacement: (-0.285, 2.345, 0.939)
# Velocity: 4.523 cm/s
# Box: (500.5079345703125, 153.80210876464844)
# Pan: -1.232719071157032, Tilt: 1.7998761594273
# Speed: 1.0ms preprocess, 93.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 77.0°, Y: 85.0°
# C2 → X: 135.0°, Y: 81.0°
# Frame number: 44
# Balloon position: (8.07, 34.93, 5.48)
# C1 Distance: 36.27 cm
# C2 Distance: 49.71 cm
# Servo angles: {'x1': 77, 'y1': 85, 'x2': 135, 'y2': 81}
#
# 0: 480x640 (no detections), 95.5ms
# Speed: 0.9ms preprocess, 95.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 93.5ms
# Speed: 0.9ms preprocess, 93.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 45
# Balloon position: (8.07, 34.93, 5.48)
# C1 Distance: 36.27 cm
# C2 Distance: 49.71 cm
# Servo angles: {'x1': 77, 'y1': 85, 'x2': 135, 'y2': 81}
#
# 0: 480x640 (no detections), 94.1ms
# Speed: 0.9ms preprocess, 94.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 93.7ms
# Speed: 1.0ms preprocess, 93.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 46
# Balloon position: (8.07, 34.93, 5.48)
# C1 Distance: 36.27 cm
# C2 Distance: 49.71 cm
# Servo angles: {'x1': 77, 'y1': 85, 'x2': 135, 'y2': 81}
#
# 0: 480x640 1 balloon, 95.0ms
# Class: balloon, Confidence: 0.34
# 3D displacement: (-0.450, 0.698, 1.411)
# Velocity: 3.017 cm/s
# Box: (790.6331787109375, 480.4053955078125)
# Pan: -1.5861752569256256, Tilt: 1.7869488774526472
# Speed: 1.0ms preprocess, 95.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 balloons, 96.7ms
# Class: balloon, Confidence: 0.83
# 3D displacement: (-0.414, 0.230, 1.122)
# Velocity: 2.243 cm/s
# Box: (278.46173095703125, 482.06317138671875)
# Pan: -0.6689402055405005, Tilt: 0.8295591019621178
# Class: balloon, Confidence: 0.37
# 3D displacement: (-0.377, -0.238, 0.833)
# Velocity: 1.740 cm/s
# Box: (20.439395904541016, 74.3145980834961)
# Pan: 0.06484783556759965, Tilt: 0.06364728156969424
# Speed: 0.9ms preprocess, 96.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 76.0°, Y: 84.0°
# C2 → X: 136.0°, Y: 81.0°
# Frame number: 47
# Balloon position: (8.82, 35.39, 5.81)
# C1 Distance: 36.93 cm
# C2 Distance: 49.54 cm
# Servo angles: {'x1': 76, 'y1': 84, 'x2': 136, 'y2': 81}
#
# 0: 480x640 (no detections), 93.9ms
# Speed: 1.0ms preprocess, 93.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 balloon, 94.3ms
# Class: balloon, Confidence: 0.53
# 3D displacement: (0.416, 0.034, 0.947)
# Velocity: 1.926 cm/s
# Box: (291.10955810546875, 483.8278503417969)
# Pan: 0.6518782684540798, Tilt: 0.5237128184274629
# Speed: 0.9ms preprocess, 94.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 76.0°, Y: 84.0°
# C2 → X: 137.0°, Y: 81.0°
# Frame number: 48
# Balloon position: (9.07, 36.38, 5.91)
# C1 Distance: 37.96 cm
# C2 Distance: 50.10 cm
# Servo angles: {'x1': 76, 'y1': 84, 'x2': 137, 'y2': 81}
#
# 0: 480x640 1 balloon, 94.9ms
# Class: balloon, Confidence: 0.29
# 3D displacement: (0.664, 1.028, 0.854)
# Velocity: 2.806 cm/s
# Box: (786.8409423828125, 480.4157409667969)
# Pan: 0.6326484231552467, Tilt: 0.7644412203160416
# Speed: 0.9ms preprocess, 94.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 balloon, 93.3ms
# Class: balloon, Confidence: 0.4
# 3D displacement: (0.633, 0.904, 0.653)
# Velocity: 2.410 cm/s
# Box: (322.7552795410156, 481.52783203125)
# Pan: 0.01285719962796128, Tilt: 1.2115529762528334
# Speed: 1.0ms preprocess, 93.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 77.0°, Y: 84.0°
# C2 → X: 138.0°, Y: 80.0°
# Frame number: 49
# Balloon position: (8.78, 38.01, 6.56)
# C1 Distance: 39.56 cm
# C2 Distance: 51.57 cm
# Servo angles: {'x1': 77, 'y1': 84, 'x2': 138, 'y2': 80}
#
# 0: 480x640 2 balloons, 95.0ms
# Class: balloon, Confidence: 0.59
# 3D displacement: (0.306, 2.406, 1.100)
# Velocity: 5.057 cm/s
# Box: (774.0406494140625, 480.473388671875)
# Pan: 0.6102857597023691, Tilt: 1.311094682399911
# Class: balloon, Confidence: 0.35
# 3D displacement: (0.246, 2.147, 0.880)
# Velocity: 4.430 cm/s
# Box: (72.4664306640625, 230.95001220703125)
# Pan: 1.0882286077618955, Tilt: 1.3907280473175732
# Speed: 1.0ms preprocess, 95.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 93.3ms
# Speed: 0.9ms preprocess, 93.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 79.0°, Y: 83.0°
# C2 → X: 138.0°, Y: 80.0°
# Frame number: 50
# Balloon position: (7.63, 39.28, 7.12)
# C1 Distance: 40.64 cm
# C2 Distance: 53.33 cm
# Servo angles: {'x1': 79, 'y1': 83, 'x2': 138, 'y2': 80}
#
# 0: 480x640 (no detections), 95.4ms
# Speed: 1.0ms preprocess, 95.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 balloon, 93.3ms
# Class: balloon, Confidence: 0.91
# 3D displacement: (-0.954, 3.154, 1.217)
# Velocity: 6.734 cm/s
# Box: (842.2701416015625, 480.0)
# Pan: 0.2705828862095163, Tilt: 1.7125824378540586
# Speed: 0.9ms preprocess, 93.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 79.0°, Y: 83.0°
# C2 → X: 139.0°, Y: 79.0°
# Frame number: 51
# Balloon position: (7.86, 40.43, 7.73)
# C1 Distance: 41.90 cm
# C2 Distance: 54.12 cm
# Servo angles: {'x1': 79, 'y1': 83, 'x2': 139, 'y2': 79}
#
# 0: 480x640 1 balloon, 93.5ms
# Class: balloon, Confidence: 0.5
# 3D displacement: (-0.677, 3.761, 1.631)
# Velocity: 8.036 cm/s
# Box: (640.3159790039062, 480.16998291015625)
# Pan: 0.8164663089676132, Tilt: 1.7263044820788798
# Speed: 1.0ms preprocess, 93.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 94.1ms
# Speed: 1.1ms preprocess, 94.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 80.0°, Y: 82.0°
# C2 → X: 139.0°, Y: 79.0°
# Frame number: 52
# Balloon position: (7.25, 41.12, 8.23)
# C1 Distance: 42.56 cm
# C2 Distance: 55.11 cm
# Servo angles: {'x1': 80, 'y1': 82, 'x2': 139, 'y2': 79}
#
# 0: 480x640 1 balloon, 95.7ms
# Class: balloon, Confidence: 0.76
# 3D displacement: (-1.258, 3.772, 1.845)
# Velocity: 8.555 cm/s
# Box: (640.0, 480.22650146484375)
# Pan: 1.0804038240930922, Tilt: 1.7236842428783041
# Speed: 1.0ms preprocess, 95.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 balloon, 95.6ms
# Class: balloon, Confidence: 0.58
# 3D displacement: (-1.156, 2.998, 1.501)
# Velocity: 6.922 cm/s
# Box: (955.1797485351562, 480.5820007324219)
# Pan: 0.26432305927447375, Tilt: 1.9564892679876515
# Speed: 0.9ms preprocess, 95.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 82.0°, Y: 81.0°
# C2 → X: 140.0°, Y: 78.0°
# Frame number: 53
# Balloon position: (6.17, 43.89, 9.60)
# C1 Distance: 45.35 cm
# C2 Distance: 58.10 cm
# Servo angles: {'x1': 82, 'y1': 81, 'x2': 140, 'y2': 78}
#
# 0: 480x640 1 balloon, 161.3ms
# Class: balloon, Confidence: 0.9
# 3D displacement: (-2.042, 5.051, 2.569)
# Velocity: 11.856 cm/s
# Box: (640.37890625, 480.0)
# Pan: 0.5985059916430128, Tilt: 1.923479192244988
# Speed: 12.3ms preprocess, 161.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 balloon, 94.8ms
# Class: balloon, Confidence: 0.41
# 3D displacement: (-1.679, 4.112, 2.107)
# Velocity: 9.677 cm/s
# Box: (647.30859375, 478.3892517089844)
# Pan: 1.0788047933144103, Tilt: 2.138783353795991
# Speed: 0.9ms preprocess, 94.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 83.0°, Y: 80.0°
# C2 → X: 142.0°, Y: 76.0°
# Frame number: 54
# Balloon position: (5.84, 47.56, 11.75)
# C1 Distance: 49.34 cm
# C2 Distance: 61.49 cm
# Servo angles: {'x1': 83, 'y1': 80, 'x2': 142, 'y2': 76}
#
# 0: 480x640 2 balloons, 95.7ms
# Class: balloon, Confidence: 0.87
# 3D displacement: (-1.646, 6.843, 3.796)
# Velocity: 15.824 cm/s
# Box: (641.7562255859375, 480.53631591796875)
# Pan: 1.176626233594984, Tilt: 2.0218854244995432
# Class: balloon, Confidence: 0.51
# 3D displacement: (-1.279, 5.649, 3.147)
# Velocity: 13.044 cm/s
# Box: (661.2891845703125, 95.21730041503906)
# Pan: 1.2548833858194428, Tilt: 1.9283670810623847
# Speed: 1.0ms preprocess, 95.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 94.7ms
# Speed: 0.9ms preprocess, 94.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 85.0°, Y: 79.0°
# C2 → X: 142.0°, Y: 76.0°
# Frame number: 55
# Balloon position: (4.33, 49.50, 12.66)
# C1 Distance: 51.27 cm
# C2 Distance: 64.07 cm
# Servo angles: {'x1': 85, 'y1': 79, 'x2': 142, 'y2': 76}
#
# 0: 480x640 1 balloon, 94.3ms
# Class: balloon, Confidence: 0.71
# 3D displacement: (-2.421, 6.387, 3.408)
# Velocity: 15.231 cm/s
# Box: (642.458740234375, 480.4024658203125)
# Pan: 1.3577204638931966, Tilt: 1.896849354779104
# Speed: 1.0ms preprocess, 94.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 95.4ms
# Speed: 0.9ms preprocess, 95.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 87.0°, Y: 78.0°
# C2 → X: 142.0°, Y: 76.0°
# Frame number: 56
# Balloon position: (2.70, 51.58, 13.65)
# C1 Distance: 53.42 cm
# C2 Distance: 66.86 cm
# Servo angles: {'x1': 87, 'y1': 78, 'x2': 142, 'y2': 76}
#
# 0: 480x640 2 balloons, 94.4ms
# Class: balloon, Confidence: 0.93
# 3D displacement: (-3.635, 7.192, 3.705)
# Velocity: 17.837 cm/s
# Box: (641.1783447265625, 480.7398681640625)
# Pan: 1.5713572243734688, Tilt: 1.8401535947133183
# Class: balloon, Confidence: 0.65
# 3D displacement: (-2.991, 5.798, 2.965)
# Velocity: 14.413 cm/s
# Box: (645.9104614257812, 106.4124755859375)
# Pan: 1.7422666327576866, Tilt: 1.7947969866606897
# Speed: 1.2ms preprocess, 94.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 92.4ms
# Speed: 0.9ms preprocess, 92.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 89.0°, Y: 77.0°
# C2 → X: 142.0°, Y: 76.0°
# Frame number: 57
# Balloon position: (0.94, 53.83, 14.73)
# C1 Distance: 55.82 cm
# C2 Distance: 69.89 cm
# Servo angles: {'x1': 89, 'y1': 77, 'x2': 142, 'y2': 76}
#
# 0: 480x640 (no detections), 94.3ms
# Speed: 1.0ms preprocess, 94.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 92.7ms
# Speed: 0.9ms preprocess, 92.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 58
# Balloon position: (0.94, 53.83, 14.73)
# C1 Distance: 55.82 cm
# C2 Distance: 69.89 cm
# Servo angles: {'x1': 89, 'y1': 77, 'x2': 142, 'y2': 76}
#
# 0: 480x640 3 balloons, 92.3ms
# Class: balloon, Confidence: 0.88
# 3D displacement: (-4.186, 6.749, 3.371)
# Velocity: 17.618 cm/s
# Box: (641.3931884765625, 480.0)
# Pan: 1.788094309772374, Tilt: 1.8081840962529814
# Class: balloon, Confidence: 0.35
# 3D displacement: (-3.397, 5.160, 2.559)
# Velocity: 13.654 cm/s
# Box: (1268.906005859375, 28.450939178466797)
# Pan: 1.8247564513841241, Tilt: 1.8188937839268149
# Class: balloon, Confidence: 0.27
# 3D displacement: (-2.743, 3.917, 1.917)
# Velocity: 10.521 cm/s
# Box: (648.0386962890625, 107.209228515625)
# Pan: 1.854086164673524, Tilt: 1.8274615340658815
# Speed: 0.9ms preprocess, 92.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 93.1ms
# Speed: 0.9ms preprocess, 93.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 91.0°, Y: 76.0°
# C2 → X: 142.0°, Y: 76.0°
# Frame number: 59
# Balloon position: (-0.98, 56.30, 15.93)
# C1 Distance: 58.51 cm
# C2 Distance: 73.19 cm
# Servo angles: {'x1': 91, 'y1': 76, 'x2': 142, 'y2': 76}
#
# 0: 480x640 2 balloons, 123.1ms
# Class: balloon, Confidence: 0.73
# 3D displacement: (-4.012, 5.135, 2.469)
# Velocity: 14.353 cm/s
# Box: (640.6007080078125, 480.8868713378906)
# Pan: 1.9330284105520648, Tilt: 1.7545528518488596
# Class: balloon, Confidence: 0.41
# 3D displacement: (-3.159, 4.044, 1.947)
# Velocity: 11.304 cm/s
# Box: (652.78759765625, 120.81040954589844)
# Pan: 1.9961822072548974, Tilt: 1.6962259060752418
# Speed: 1.0ms preprocess, 123.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 94.3ms
# Speed: 0.9ms preprocess, 94.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 93.0°, Y: 75.0°
# C2 → X: 142.0°, Y: 76.0°
# Frame number: 60
# Balloon position: (-3.09, 58.99, 17.25)
# C1 Distance: 61.54 cm
# C2 Distance: 76.83 cm
# Servo angles: {'x1': 93, 'y1': 75, 'x2': 142, 'y2': 76}
#
# 0: 480x640 2 balloons, 93.9ms
# Class: balloon, Confidence: 0.66
# 3D displacement: (-4.416, 5.652, 2.747)
# Velocity: 15.898 cm/s
# Box: (647.3851928710938, 480.76165771484375)
# Pan: 1.55243247575573, Tilt: 1.7088709055582072
# Class: balloon, Confidence: 0.61
# 3D displacement: (-3.488, 4.464, 2.174)
# Velocity: 12.560 cm/s
# Box: (651.7166748046875, 138.9169464111328)
# Pan: 1.1974326905563961, Tilt: 1.7189869051445796
# Speed: 0.9ms preprocess, 93.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 94.5ms
# Speed: 0.9ms preprocess, 94.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 95.0°, Y: 74.0°
# C2 → X: 142.0°, Y: 76.0°
# Frame number: 61
# Balloon position: (-5.42, 61.98, 18.72)
# C1 Distance: 64.97 cm
# C2 Distance: 80.85 cm
# Servo angles: {'x1': 95, 'y1': 74, 'x2': 142, 'y2': 76}
#
# 0: 480x640 1 balloon, 94.6ms
# Class: balloon, Confidence: 0.9
# 3D displacement: (-5.094, 6.520, 3.201)
# Velocity: 18.505 cm/s
# Box: (641.1394653320312, 480.0)
# Pan: 1.557946152445117, Tilt: 1.769428626581441
# Speed: 0.9ms preprocess, 94.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 94.2ms
# Speed: 0.9ms preprocess, 94.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 97.0°, Y: 73.0°
# C2 → X: 142.0°, Y: 76.0°
# Frame number: 62
# Balloon position: (-8.02, 65.30, 20.39)
# C1 Distance: 68.88 cm
# C2 Distance: 85.34 cm
# Servo angles: {'x1': 97, 'y1': 73, 'x2': 142, 'y2': 76}
#
# 0: 480x640 2 balloons, 94.5ms
# Class: balloon, Confidence: 0.9
# 3D displacement: (-6.674, 8.542, 4.229)
# Velocity: 24.434 cm/s
# Box: (641.5570068359375, 480.1597595214844)
# Pan: 1.618958267784916, Tilt: 1.7510673344267746
# Class: balloon, Confidence: 0.6
# 3D displacement: (-5.554, 7.109, 3.522)
# Velocity: 20.336 cm/s
# Box: (673.7860107421875, 160.99911499023438)
# Pan: 1.667767960056755, Tilt: 1.7363783007030416
# Speed: 1.0ms preprocess, 94.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 93.9ms
# Speed: 0.9ms preprocess, 93.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 99.0°, Y: 72.0°
# C2 → X: 142.0°, Y: 76.0°
# Frame number: 63
# Balloon position: (-10.93, 69.03, 22.28)
# C1 Distance: 73.36 cm
# C2 Distance: 90.39 cm
# Servo angles: {'x1': 99, 'y1': 72, 'x2': 142, 'y2': 76}
#
# 0: 480x640 2 balloons, 95.2ms
# Class: balloon, Confidence: 0.84
# 3D displacement: (-7.350, 9.408, 4.703)
# Velocity: 27.124 cm/s
# Box: (642.251708984375, 480.02392578125)
# Pan: 1.6867137387684576, Tilt: 1.74399062817214
# Class: balloon, Confidence: 0.32
# 3D displacement: (-5.866, 7.508, 3.760)
# Velocity: 21.652 cm/s
# Box: (680.888427734375, 171.2584228515625)
# Pan: 1.7018703617378197, Tilt: 1.7500804901474187
# Speed: 1.0ms preprocess, 95.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 92.9ms
# Speed: 0.9ms preprocess, 92.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 101.0°, Y: 71.0°
# C2 → X: 142.0°, Y: 76.0°
# Frame number: 64
# Balloon position: (-14.24, 73.27, 24.44)
# C1 Distance: 78.54 cm
# C2 Distance: 96.13 cm
# Servo angles: {'x1': 101, 'y1': 71, 'x2': 142, 'y2': 76}
#
# 0: 480x640 1 balloon, 95.2ms
# Class: balloon, Confidence: 0.9
# 3D displacement: (-7.930, 10.150, 5.132)
# Velocity: 29.497 cm/s
# Box: (646.718017578125, 480.0)
# Pan: 1.45541246989905, Tilt: 1.7478751706253313
# Speed: 0.9ms preprocess, 95.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 94.3ms
# Speed: 0.9ms preprocess, 94.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 103.0°, Y: 70.0°
# C2 → X: 142.0°, Y: 76.0°
# Frame number: 65
# Balloon position: (-18.04, 78.12, 26.95)
# C1 Distance: 84.59 cm
# C2 Distance: 102.74 cm
# Servo angles: {'x1': 103, 'y1': 70, 'x2': 142, 'y2': 76}
#
# 0: 480x640 (no detections), 93.6ms
# Speed: 1.0ms preprocess, 93.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 balloon, 94.8ms
# Class: balloon, Confidence: 0.53
# 3D displacement: (-10.067, 12.885, 6.577)
# Velocity: 37.729 cm/s
# Box: (969.3888549804688, 480.1876220703125)
# Pan: 0.56432997591924, Tilt: 1.9859853184188547
# Speed: 0.9ms preprocess, 94.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 103.0°, Y: 70.0°
# C2 → X: 143.0°, Y: 75.0°
# Frame number: 66
# Balloon position: (-18.99, 82.27, 29.17)
# C1 Distance: 89.33 cm
# C2 Distance: 107.06 cm
# Servo angles: {'x1': 103, 'y1': 70, 'x2': 143, 'y2': 75}
#
# 0: 480x640 1 balloon, 95.4ms
# Class: balloon, Confidence: 0.75
# 3D displacement: (-9.156, 14.639, 7.580)
# Velocity: 40.612 cm/s
# Box: (462.058349609375, 180.90281677246094)
# Pan: 1.051463980735392, Tilt: 2.188788254735084
# Speed: 0.9ms preprocess, 95.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 95.4ms
# Speed: 0.9ms preprocess, 95.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 105.0°, Y: 68.0°
# C2 → X: 143.0°, Y: 75.0°
# Frame number: 67
# Balloon position: (-23.73, 88.55, 33.37)
# C1 Distance: 97.56 cm
# C2 Distance: 115.79 cm
# Servo angles: {'x1': 105, 'y1': 68, 'x2': 143, 'y2': 75}
#
# 0: 480x640 1 balloon, 94.5ms
# Class: balloon, Confidence: 0.35
# 3D displacement: (-11.902, 18.012, 10.298)
# Velocity: 51.821 cm/s
# Box: (1267.8092041015625, 167.97390747070312)
# Pan: 0.24117118458831355, Tilt: 2.3510306037880673
# Speed: 1.0ms preprocess, 94.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 93.6ms
# Speed: 0.9ms preprocess, 93.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 106.0°, Y: 66.0°
# C2 → X: 143.0°, Y: 75.0°
# Frame number: 68
# Balloon position: (-26.41, 92.11, 36.79)
# C1 Distance: 102.64 cm
# C2 Distance: 121.06 cm
# Servo angles: {'x1': 106, 'y1': 66, 'x2': 143, 'y2': 75}
#
# 0: 480x640 1 balloon, 94.8ms
# Class: balloon, Confidence: 0.57
# 3D displacement: (-12.301, 18.256, 11.878)
# Velocity: 54.508 cm/s
# Box: (247.26513671875, 205.85147094726562)
# Pan: 0.7929369476706509, Tilt: 1.2808244830304538
# Speed: 0.9ms preprocess, 94.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 94.8ms
# Speed: 0.9ms preprocess, 94.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 107.0°, Y: 65.0°
# C2 → X: 143.0°, Y: 75.0°
# Frame number: 69
# Balloon position: (-29.36, 96.02, 39.52)
# C1 Distance: 107.90 cm
# C2 Distance: 126.56 cm
# Servo angles: {'x1': 107, 'y1': 65, 'x2': 143, 'y2': 75}
#
# 0: 480x640 (no detections), 95.9ms
# Speed: 1.0ms preprocess, 95.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 balloon, 94.3ms
# Class: balloon, Confidence: 0.29
# 3D displacement: (-12.944, 18.810, 12.561)
# Velocity: 57.112 cm/s
# Box: (923.7147827148438, 614.0464477539062)
# Pan: 0.08755614979360027, Tilt: 0.42465958642436297
# Speed: 0.9ms preprocess, 94.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 107.0°, Y: 65.0°
# C2 → X: 144.0°, Y: 75.0°
# Frame number: 70
# Balloon position: (-31.24, 102.18, 41.83)
# C1 Distance: 114.75 cm
# C2 Distance: 133.05 cm
# Servo angles: {'x1': 107, 'y1': 65, 'x2': 144, 'y2': 75}
#
# 0: 480x640 1 balloon, 94.3ms
# Class: balloon, Confidence: 0.32
# 3D displacement: (-12.161, 21.133, 12.487)
# Velocity: 60.368 cm/s
# Box: (205.35243225097656, 235.93072509765625)
# Pan: 0.6700449198348803, Tilt: 0.6988715302945805
# Speed: 0.9ms preprocess, 94.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 95.0ms
# Speed: 0.9ms preprocess, 95.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 108.0°, Y: 65.0°
# C2 → X: 144.0°, Y: 75.0°
# Frame number: 71
# Balloon position: (-34.79, 107.07, 43.98)
# C1 Distance: 120.86 cm
# C2 Distance: 139.46 cm
# Servo angles: {'x1': 108, 'y1': 65, 'x2': 144, 'y2': 75}
#
# 0: 480x640 1 balloon, 93.8ms
# Class: balloon, Confidence: 0.75
# 3D displacement: (-13.170, 21.871, 12.185)
# Velocity: 62.677 cm/s
# Box: (641.3043823242188, 548.7008056640625)
# Pan: -0.06396406413209577, Tilt: -0.04090277576433565
# Speed: 1.2ms preprocess, 93.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 91.0ms
# Speed: 0.9ms preprocess, 91.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 108.0°, Y: 66.0°
# C2 → X: 144.0°, Y: 75.0°
# Frame number: 72
# Balloon position: (-34.79, 107.07, 42.79)
# C1 Distance: 120.43 cm
# C2 Distance: 139.09 cm
# Servo angles: {'x1': 108, 'y1': 66, 'x2': 144, 'y2': 75}
#
# 0: 480x640 2 balloons, 93.8ms
# Class: balloon, Confidence: 0.69
# 3D displacement: (-10.188, 17.117, 8.285)
# Velocity: 48.058 cm/s
# Box: (640.980224609375, 550.8017578125)
# Pan: 0.5380311359114722, Tilt: 0.1751492696755551
# Class: balloon, Confidence: 0.31
# 3D displacement: (-7.620, 12.892, 5.992)
# Velocity: 35.930 cm/s
# Box: (249.76173400878906, 239.6602783203125)
# Pan: 1.0196272959463266, Tilt: 0.34799090602746774
# Speed: 0.9ms preprocess, 93.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 94.8ms
# Speed: 0.9ms preprocess, 94.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 110.0°, Y: 66.0°
# C2 → X: 144.0°, Y: 75.0°
# Frame number: 73
# Balloon position: (-43.17, 118.60, 47.74)
# C1 Distance: 134.93 cm
# C2 Distance: 154.17 cm
# Servo angles: {'x1': 110, 'y1': 66, 'x2': 144, 'y2': 75}
#
# 0: 480x640 1 balloon, 93.8ms
# Class: balloon, Confidence: 0.81
# 3D displacement: (-13.904, 20.806, 8.956)
# Velocity: 59.579 cm/s
# Box: (639.5721435546875, 555.145263671875)
# Pan: 1.4157018367570613, Tilt: 0.33958206837638216
# Speed: 0.9ms preprocess, 93.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 balloon, 94.6ms
# Class: balloon, Confidence: 0.67
# 3D displacement: (-10.883, 16.264, 6.635)
# Velocity: 46.320 cm/s
# Box: (918.993896484375, 482.5631103515625)
# Pan: 0.5325614694056491, Tilt: 0.8716656547011059
# Speed: 0.9ms preprocess, 94.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 112.0°, Y: 66.0°
# C2 → X: 145.0°, Y: 75.0°
# Frame number: 74
# Balloon position: (-58.66, 145.18, 58.60)
# C1 Distance: 167.19 cm
# C2 Distance: 186.67 cm
# Servo angles: {'x1': 112, 'y1': 66, 'x2': 145, 'y2': 75}
#
# 0: 480x640 1 balloon, 93.6ms
# Class: balloon, Confidence: 0.8
# 3D displacement: (-23.944, 39.093, 15.706)
# Velocity: 109.174 cm/s
# Box: (640.0, 549.6987915039062)
# Pan: 0.9663593065525066, Tilt: 1.2973325237608848
# Speed: 0.9ms preprocess, 93.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 balloon, 94.6ms
# Class: balloon, Confidence: 0.28
# 3D displacement: (-19.913, 32.459, 12.979)
# Velocity: 90.640 cm/s
# Box: (921.1370239257812, 481.578369140625)
# Pan: 0.17308744524200526, Tilt: 1.6023345663874364
# Speed: 0.9ms preprocess, 94.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 113.0°, Y: 65.0°
# C2 → X: 146.0°, Y: 74.0°
# Frame number: 75
# Balloon position: (-73.00, 171.98, 73.30)
# C1 Distance: 200.69 cm
# C2 Distance: 220.01 cm
# Servo angles: {'x1': 113, 'y1': 65, 'x2': 146, 'y2': 74}
#
# 0: 480x640 1 balloon, 95.5ms
# Class: balloon, Confidence: 0.41
# 3D displacement: (-30.594, 53.110, 25.292)
# Velocity: 150.120 cm/s
# Box: (639.609130859375, 556.0267944335938)
# Pan: 0.7324109934914526, Tilt: 1.1922979203266098
# Speed: 1.0ms preprocess, 95.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 balloon, 94.1ms
# Class: balloon, Confidence: 0.43
# 3D displacement: (-25.374, 44.386, 21.359)
# Velocity: 125.450 cm/s
# Box: (914.2347412109375, 480.30267333984375)
# Pan: -0.014071205206838022, Tilt: 1.5409689935288315
# Speed: 1.0ms preprocess, 94.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 114.0°, Y: 64.0°
# C2 → X: 146.0°, Y: 73.0°
# Frame number: 76
# Balloon position: (-83.50, 187.54, 84.64)
# C1 Distance: 222.06 cm
# C2 Distance: 241.54 cm
# Servo angles: {'x1': 114, 'y1': 64, 'x2': 146, 'y2': 73}
#
# 0: 480x640 1 balloon, 95.8ms
# Class: balloon, Confidence: 0.47
# 3D displacement: (-31.097, 51.839, 29.037)
# Velocity: 152.573 cm/s
# Box: (640.9689331054688, 565.1680297851562)
# Pan: 0.4665564224080111, Tilt: 0.9189030009504561
# Speed: 0.9ms preprocess, 95.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 balloon, 94.1ms
# Class: balloon, Confidence: 0.83
# 3D displacement: (-25.008, 41.779, 23.805)
# Velocity: 123.308 cm/s
# Box: (919.3179931640625, 489.6011047363281)
# Pan: -0.2267548620735912, Tilt: 0.612886500576629
# Speed: 0.9ms preprocess, 94.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 115.0°, Y: 64.0°
# C2 → X: 146.0°, Y: 73.0°
# Frame number: 77
# Balloon position: (-96.31, 206.53, 93.65)
# C1 Distance: 246.38 cm
# C2 Distance: 266.14 cm
# Servo angles: {'x1': 115, 'y1': 64, 'x2': 146, 'y2': 73}
#
# 0: 480x640 (no detections), 94.9ms
# Speed: 1.0ms preprocess, 94.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 balloon, 95.2ms
# Class: balloon, Confidence: 0.93
# 3D displacement: (-31.727, 50.707, 27.584)
# Velocity: 150.558 cm/s
# Box: (891.7823486328125, 480.79376220703125)
# Pan: 0.2326369627368398, Tilt: 1.0903092004613033
# Speed: 0.9ms preprocess, 95.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 115.0°, Y: 64.0°
# C2 → X: 147.0°, Y: 72.0°
# Frame number: 78
# Balloon position: (-109.51, 234.84, 108.68)
# C1 Distance: 280.99 cm
# C2 Distance: 300.37 cm
# Servo angles: {'x1': 115, 'y1': 64, 'x2': 147, 'y2': 72}
#
# 0: 480x640 1 balloon, 93.7ms
# Class: balloon, Confidence: 0.67
# 3D displacement: (-38.286, 68.028, 36.872)
# Velocity: 198.257 cm/s
# Box: (182.7417755126953, 229.39468383789062)
# Pan: 0.7861095701894719, Tilt: 1.472247360369043
# Speed: 0.9ms preprocess, 93.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 95.4ms
# Speed: 0.9ms preprocess, 95.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 116.0°, Y: 63.0°
# C2 → X: 147.0°, Y: 72.0°
# Frame number: 79
# Balloon position: (-129.72, 265.97, 126.91)
# C1 Distance: 321.98 cm
# C2 Distance: 341.58 cm
# Servo angles: {'x1': 116, 'y1': 63, 'x2': 147, 'y2': 72}
#
# 0: 480x640 (no detections), 93.6ms
# Speed: 0.9ms preprocess, 93.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 94.1ms
# Speed: 0.9ms preprocess, 94.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 80
# Balloon position: (-129.72, 265.97, 126.91)
# C1 Distance: 321.98 cm
# C2 Distance: 341.58 cm
# Servo angles: {'x1': 116, 'y1': 63, 'x2': 147, 'y2': 72}
#
# 0: 480x640 1 balloon, 94.5ms
# Class: balloon, Confidence: 0.47
# 3D displacement: (-50.204, 84.618, 47.479)
# Velocity: 253.153 cm/s
# Box: (547.8966064453125, 581.4478759765625)
# Pan: 0.028887656151577512, Tilt: 0.5777978882952344
# Speed: 0.9ms preprocess, 94.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 99.1ms
# Speed: 0.9ms preprocess, 99.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 117.0°, Y: 63.0°
# C2 → X: 147.0°, Y: 72.0°
# Frame number: 81
# Balloon position: (-156.63, 307.40, 147.44)
# C1 Distance: 375.19 cm
# C2 Distance: 395.08 cm
# Servo angles: {'x1': 117, 'y1': 63, 'x2': 147, 'y2': 72}
#
# 0: 480x640 1 balloon, 93.8ms
# Class: balloon, Confidence: 0.4
# 3D displacement: (-68.230, 110.956, 59.474)
# Velocity: 333.207 cm/s
# Box: (288.7281799316406, 157.45947265625)
# Pan: 0.623110124921262, Tilt: 1.0622383106361877
# Speed: 1.0ms preprocess, 93.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 balloon, 93.8ms
# Class: balloon, Confidence: 0.81
# 3D displacement: (-55.983, 90.679, 48.369)
# Velocity: 272.333 cm/s
# Box: (640.0, 480.0)
# Pan: 1.0984880999370097, Tilt: 1.366736438712855
# Speed: 0.9ms preprocess, 93.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 118.0°, Y: 62.0°
# C2 → X: 149.0°, Y: 71.0°
# Frame number: 82
# Balloon position: (-330.63, 621.83, 312.13)
# C1 Distance: 770.33 cm
# C2 Distance: 789.74 cm
# Servo angles: {'x1': 118, 'y1': 62, 'x2': 149, 'y2': 71}
#
# 0: 480x640 1 balloon, 95.2ms
# Class: balloon, Confidence: 0.9
# 3D displacement: (-219.531, 388.175, 203.786)
# Velocity: 1145.974 cm/s
# Box: (640.5718383789062, 481.89056396484375)
# Pan: 0.2787904799496077, Tilt: 0.49338915097028413
# Speed: 0.9ms preprocess, 95.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 95.2ms
# Speed: 0.9ms preprocess, 95.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 119.0°, Y: 62.0°
# C2 → X: 149.0°, Y: 71.0°
# Frame number: 83
# Balloon position: (-512.02, 923.71, 466.30)
# C1 Distance: 1154.49 cm
# C2 Distance: 1174.19 cm
# Servo angles: {'x1': 119, 'y1': 62, 'x2': 149, 'y2': 71}
#
# 0: 480x640 (no detections), 94.1ms
# Speed: 1.5ms preprocess, 94.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 95.9ms
# Speed: 0.9ms preprocess, 95.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 84
# Balloon position: (-512.02, 923.71, 466.30)
# C1 Distance: 1154.49 cm
# C2 Distance: 1174.19 cm
# Servo angles: {'x1': 119, 'y1': 62, 'x2': 149, 'y2': 71}
#
# 0: 480x640 1 balloon, 94.6ms
# Class: balloon, Confidence: 0.31
# 3D displacement: (-368.716, 633.825, 328.111)
# Velocity: 1895.215 cm/s
# Box: (134.1181182861328, 451.79791259765625)
# Pan: 0.8230323839596863, Tilt: 0.9947113207762275
# Speed: 0.9ms preprocess, 94.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 93.6ms
# Speed: 0.9ms preprocess, 93.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# C1 → X: 120.0°, Y: 62.0°
# C2 → X: 149.0°, Y: 71.0°
# Frame number: 85
# Balloon position: (-1055.96, 1828.98, 928.82)
# C1 Distance: 2307.15 cm
# C2 Distance: 2327.14 cm
# Servo angles: {'x1': 120, 'y1': 62, 'x2': 149, 'y2': 71}
#
# 0: 480x640 (no detections), 93.6ms
# Speed: 0.9ms preprocess, 93.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 124.4ms
# Speed: 1.2ms preprocess, 124.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 86
# Balloon position: (-1055.96, 1828.98, 928.82)
# C1 Distance: 2307.15 cm
# C2 Distance: 2327.14 cm
# Servo angles: {'x1': 120, 'y1': 62, 'x2': 149, 'y2': 71}
#
# 0: 480x640 (no detections), 90.5ms
# Speed: 0.9ms preprocess, 90.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 93.0ms
# Speed: 0.9ms preprocess, 93.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 87
# Balloon position: (-1055.96, 1828.98, 928.82)
# C1 Distance: 2307.15 cm
# C2 Distance: 2327.14 cm
# Servo angles: {'x1': 120, 'y1': 62, 'x2': 149, 'y2': 71}
#
# 0: 480x640 (no detections), 92.4ms
# Speed: 0.9ms preprocess, 92.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 94.2ms
# Speed: 0.9ms preprocess, 94.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 88
# Balloon position: (-1055.96, 1828.98, 928.82)
# C1 Distance: 2307.15 cm
# C2 Distance: 2327.14 cm
# Servo angles: {'x1': 120, 'y1': 62, 'x2': 149, 'y2': 71}
#
# 0: 480x640 (no detections), 92.8ms
# Speed: 0.9ms preprocess, 92.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 93.9ms
# Speed: 0.9ms preprocess, 93.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 89
# Balloon position: (-1055.96, 1828.98, 928.82)
# C1 Distance: 2307.15 cm
# C2 Distance: 2327.14 cm
# Servo angles: {'x1': 120, 'y1': 62, 'x2': 149, 'y2': 71}
#
# 0: 480x640 (no detections), 93.3ms
# Speed: 0.9ms preprocess, 93.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 94.8ms
# Speed: 0.9ms preprocess, 94.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 90
# Balloon position: (-1055.96, 1828.98, 928.82)
# C1 Distance: 2307.15 cm
# C2 Distance: 2327.14 cm
# Servo angles: {'x1': 120, 'y1': 62, 'x2': 149, 'y2': 71}
#
# 0: 480x640 (no detections), 92.8ms
# Speed: 0.9ms preprocess, 92.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 94.2ms
# Speed: 0.9ms preprocess, 94.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 91
# Balloon position: (-1055.96, 1828.98, 928.82)
# C1 Distance: 2307.15 cm
# C2 Distance: 2327.14 cm
# Servo angles: {'x1': 120, 'y1': 62, 'x2': 149, 'y2': 71}
#
# 0: 480x640 (no detections), 93.1ms
# Speed: 0.9ms preprocess, 93.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 91.7ms
# Speed: 0.9ms preprocess, 91.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 92
# Balloon position: (-1055.96, 1828.98, 928.82)
# C1 Distance: 2307.15 cm
# C2 Distance: 2327.14 cm
# Servo angles: {'x1': 120, 'y1': 62, 'x2': 149, 'y2': 71}
#
# 0: 480x640 (no detections), 93.9ms
# Speed: 0.9ms preprocess, 93.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 93.9ms
# Speed: 0.9ms preprocess, 93.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 93
# Balloon position: (-1055.96, 1828.98, 928.82)
# C1 Distance: 2307.15 cm
# C2 Distance: 2327.14 cm
# Servo angles: {'x1': 120, 'y1': 62, 'x2': 149, 'y2': 71}
#
# 0: 480x640 (no detections), 94.0ms
# Speed: 1.0ms preprocess, 94.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 93.2ms
# Speed: 0.9ms preprocess, 93.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 94
# Balloon position: (-1055.96, 1828.98, 928.82)
# C1 Distance: 2307.15 cm
# C2 Distance: 2327.14 cm
# Servo angles: {'x1': 120, 'y1': 62, 'x2': 149, 'y2': 71}
#
# 0: 480x640 (no detections), 93.8ms
# Speed: 1.3ms preprocess, 93.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 93.7ms
# Speed: 0.9ms preprocess, 93.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 95
# Balloon position: (-1055.96, 1828.98, 928.82)
# C1 Distance: 2307.15 cm
# C2 Distance: 2327.14 cm
# Servo angles: {'x1': 120, 'y1': 62, 'x2': 149, 'y2': 71}
#
# 0: 480x640 (no detections), 93.2ms
# Speed: 0.9ms preprocess, 93.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 95.7ms
# Speed: 0.9ms preprocess, 95.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# ----------------------------------------- Program finished -----------------------------------------
# Total frames: 95, Total time: 38.52 seconds
# Detected classes: ['balloon']
# Frame centers: (640.0, 480.0), (640.0, 480.0)
# FPS: 2.47
# Final balloon position: (-1055.96, 1828.98, 928.82)
# Final C1 distance: 2307.15 cm
# Final C2 distance: 2327.14 cm
# Servo angles: {'x1': 120, 'y1': 62, 'x2': 149, 'y2': 71}
# Lyapunov exponent: 0.2583 per second
# Predictability horizon: 3.87 seconds

# %%
enumerate_cameras()
# Out:
# [1200: MacBook Air Camera]
