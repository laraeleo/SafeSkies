# %%
from ultralytics import YOLO

# Carrega modelo pré-treinado
model = YOLO("best.pt")

# Aplica em uma imagem
results = model("images/IMG_8454.JPG")

# Mostra resultado
results[0].show()
# Out:
# image 1/1 /Users/Leonardo/Desktop/SafeSkies/working_directory/images/IMG_8454.JPG: 640x480 1 balloon, 103.0ms
# Speed: 1.5ms preprocess, 103.0ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 480)

# %%
8443
8444
8445
8454

# %%
results[0].save(filename="out_4354.jpg")
# Out:
# 'out_4354.jpg'

# %%
from ultralytics import YOLO
import cv2

# Carrega modelo
model = YOLO("best.pt")

# Carrega imagem
img_path = "images/IMG_8454.JPG"
result = model(img_path)

# Pega imagem em formato OpenCV
img = cv2.imread(img_path)

# Loop nas detecções
for box in result[0].boxes:
    x1, y1, x2, y2 = map(int, box.xyxy[0])

    # Calcula dimensões
    width = x2 - x1
    height = y2 - y1
    area = width * height

    # Texto
    text = f"W:{width} H:{height} A:{area}"

    # Desenha bounding box
    cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)

    # Escreve texto acima da caixa
    cv2.putText(img, text, (x1, y1 - 10),
                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

# Mostra imagem
cv2.imshow("Result", img)

cv2.imwrite("out_8454_pxl.jpg", img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# image 1/1 /Users/Leonardo/Desktop/SafeSkies/working_directory/images/IMG_8454.JPG: 640x480 1 balloon, 105.2ms
# Speed: 1.4ms preprocess, 105.2ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 480)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
