# %%
# Install dependencies
# %pip install ultralytics
# %pip install opencv-python
# %pip install simple_pid
# %pip install numpy
# %pip install pyserial
# %pip install cv2-enumerate-cameras
# Out:
# Requirement already satisfied: ultralytics in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (8.3.186)
# Requirement already satisfied: numpy>=1.23.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (2.3.1)
# Requirement already satisfied: matplotlib>=3.3.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (3.10.3)
# Requirement already satisfied: opencv-python>=4.6.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (1.16.0)
# Requirement already satisfied: torch>=1.8.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (2.7.1)
# Requirement already satisfied: torchvision>=0.9.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (0.22.1)
# Requirement already satisfied: psutil in /Users/Leonardo/Library/Python/3.13/lib/python/site-packages (from ultralytics) (7.0.0)
# Requirement already satisfied: py-cpuinfo in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (2.3.0)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/Leonardo/Library/Python/3.13/lib/python/site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/Leonardo/Library/Python/3.13/lib/python/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/Leonardo/Library/Python/3.13/lib/python/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (2025.6.15)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (4.14.0)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (2025.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: opencv-python in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from opencv-python) (2.3.1)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: simple_pid in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (2.0.1)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (2.3.1)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pyserial in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (3.5)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: cv2-enumerate-cameras in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (1.3.0)
# Requirement already satisfied: pyobjc-framework-AVFoundation in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from cv2-enumerate-cameras) (11.1)
# Requirement already satisfied: pyobjc-core>=11.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pyobjc-framework-AVFoundation->cv2-enumerate-cameras) (11.1)
# Requirement already satisfied: pyobjc-framework-CoreMedia>=11.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pyobjc-framework-AVFoundation->cv2-enumerate-cameras) (11.1)
# Requirement already satisfied: pyobjc-framework-CoreAudio>=11.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pyobjc-framework-AVFoundation->cv2-enumerate-cameras) (11.1)
# Requirement already satisfied: pyobjc-framework-Cocoa>=11.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pyobjc-framework-AVFoundation->cv2-enumerate-cameras) (11.1)
# Requirement already satisfied: pyobjc-framework-Quartz>=11.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pyobjc-framework-AVFoundation->cv2-enumerate-cameras) (11.1)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Configurations
import cv2
import math
import serial
import time
import numpy as np
from ultralytics import YOLO
from simple_pid import PID
from cv2_enumerate_cameras import enumerate_cameras
from collections import deque

# Camera configuration
CAMERA_INDEX = 1200                    # Index of the camera to be used (custom value; check with enumerate_cameras)
FRAME_DELAY = 0.01                     # Delay between frames in seconds for processing

# Movement vector filtering
VECTOR_MIN_LENGTH = 50                 # Minimum length of movement vector to consider (in pixels)
VECTOR_MAX_LENGTH = 100                # Maximum length of movement vector to consider (in pixels)
VECTOR_HISTORY_SIZE = 10               # Number of previous positions to store for movement vector calculation

# Geometry setup
CAMERA_DISTANCE = 20                   # Distance between two cameras (used for triangulation)
DISTANCE_UNIT = "cm"                   # Unit of measurement for camera distance

# YOLO model setup
MODEL = YOLO('yolov10m.pt')            # Load YOLOv8 nano model for object detection
CLASS_NAMES = MODEL.names              # List of all class labels in the model
DESIRED_CLASSES = ["sports ball"]      # Classes we want to detect (only track sports balls)

# PID control parameters
PID_KP = 0.015                         # PID Proportional gain
PID_KI = 0.003                         # PID Integral gain
PID_KD = 0.09                          # PID Derivative gain
PID_OUTPUT_LIMITS = (-3, 3)            # Output limits for PID correction to smooth servo movement
ALPHA = 0.2                            # Smoothing factor for servo movement (0 < ALPHA < 1)

# Servo configuration
SERVO_MIN = 0                          # Minimum angle a servo can rotate to
SERVO_MAX = 180                        # Maximum angle a servo can rotate to
SERVO_INIT = {                         # Initial servo positions (centered)
    'x1': 90, 
    'y1': 90, 
    'x2': 90, 
    'y2': 90
}

# Arduino serial communication
ARDUINO_PORT = '/dev/cu.usbmodem11101' # Serial port where Arduino is connected
ARDUINO_BAUDRATE = 9600                # Communication speed between Python and Arduino

# %%
# CV2 and camera settings

# Initialize camera
def init_camera(index=CAMERA_INDEX, verbose=True):
    cap = cv2.VideoCapture(index)
    if not cap.isOpened():
        raise RuntimeError(f"Error: Could not open webcam {index}.")
    if verbose:
        print(f"Camera {index} opened successfully.")
    return cap


# Read current frame
def read_frame(cap):
    ret, frame = cap.read()
    if not ret:
        raise RuntimeError("Failed to capture image from webcam.")
    return frame


# Calculate frame center
def calculate_center(frame):
    height, width = frame.shape[:2]
    x_center, y_center = width / 2, height / 2
    return x_center, y_center


# Check if class is in desired classes
def valid_class(box, class_names=CLASS_NAMES, desired_classes=DESIRED_CLASSES):
    return class_names[int(box.cls)] in desired_classes


# Draw bounding box
def draw_bounding_box(frame, box, class_names=CLASS_NAMES, verbose=True):
    x1, y1, x2, y2 = map(int, box.xyxy[0])
    cv2.rectangle(frame, (x1, y1), (x2, y2), (255, 0, 255), 3)
    
    cls = int(box.cls[0])
    confidence = math.ceil((box.conf[0] * 100)) / 100
    
    org = [x1, y1]
    font = cv2.FONT_HERSHEY_SIMPLEX
    font_scale = 1
    color = (255, 0, 0)
    thickness = 2
    cv2.putText(frame, class_names[cls], org, font, font_scale, color, thickness)
    
    if verbose:
        print(f"Class: {class_names[cls]}, Confidence: {confidence}")


# Draw movement vector
def draw_movement_vector(frame, box, vector_history):
    x1, y1, x2, y2 = map(int, box.xyxy[0])
    cx, cy = int((x1 + x2) / 2), int((y1 + y2) / 2)
            
    if len(vector_history) > 0:
        px = sum(p[0] for p in list(vector_history)) / len(vector_history)
        py = sum(p[1] for p in list(vector_history)) / len(vector_history)
        dx, dy = cx - px, cy - py
        mag = math.hypot(dx, dy)

        if mag > 1e-6:
            new_mag = max(VECTOR_MIN_LENGTH, min(mag, VECTOR_MAX_LENGTH))
            scale = new_mag / mag
            end_x = int(cx + dx * scale)
            end_y = int(cy + dy * scale)
            cv2.arrowedLine(frame, (cx, cy), (end_x, end_y), (0, 0, 255), 3, tipLength=0.3)

    vector_history.append((cx, cy))

# %%
# Calculations

# Calculate balloon coordinates
def triangulation(angles: dict, d=CAMERA_DISTANCE, verbose=True):
    alpha = np.radians(angles['x1'])
    beta = np.radians(angles['x2'])
    gamma = np.radians(angles['y1'])
    delta = np.radians(angles['y2'])
    
    if (np.sin(alpha + beta)) == 0:
        raise ValueError("Invalid angles for triangulation.")
    
    n = d * np.sin(beta) / np.sin(alpha + beta)
    m = d * np.sin(alpha) / np.sin(alpha + beta)

    x1 = n * np.cos(alpha)
    y1 = n * np.sin(alpha)
    z1 = n * np.tan(gamma)
    
    x2 = d - (m * np.cos(beta))
    y2 = m * np.sin(beta)
    z2 = m * np.tan(delta)

    x = (x1 + x2) / 2
    y = (y1 + y2) / 2
    z = (z1 + z2) / 2
    
    if verbose:
        print(f"Balloon position: ({x:.2f}, {y:.2f}, {z:.2f})")
    
    return np.array([x, y, z])


# Calculate distance to camera
def get_distance(camera, balloon_position, d=CAMERA_DISTANCE, verbose=True):
    if camera == 'C1':
        camera_position = np.array([0, 0, 0])
    elif camera == 'C2':
        camera_position = np.array([d, 0, 0])
    else:
        raise ValueError("Invalid camera ID. Use 'C1' or 'C2'.")
    
    distance = np.linalg.norm(balloon_position - camera_position)
    
    if verbose:
        print(f"{camera} Distance: {distance:.2f} {DISTANCE_UNIT}")
    
    return distance

# %%
# PID controller

# Initialize PID controller
def init_pid(x_center, y_center, verbose=True):
    global prev_pan, prev_tilt
    prev_pan, prev_tilt = 0, 0
    pid_pan = PID(Kp=PID_KP, Ki=PID_KI, Kd=PID_KD, setpoint=x_center)
    pid_pan.output_limits = PID_OUTPUT_LIMITS
    pid_tilt = PID(Kp=PID_KP, Ki=PID_KI, Kd=PID_KD, setpoint=y_center)
    pid_tilt.output_limits = PID_OUTPUT_LIMITS
    if verbose:
        print("PID controller initialized.")
    return pid_pan, pid_tilt


# Calculate corrections using PID controller
def calculate_corrections(box, pid_pan, pid_tilt, verbose=True):
    global prev_pan, prev_tilt
    x1, y1, x2, y2 = box.xyxy[0]
    x_box = float((x1 + x2) / 2)
    y_box = float((y1 + y2) / 2)
    pan_raw = pid_pan(x_box)
    tilt_raw = pid_tilt(y_box)
    pan = ALPHA * pan_raw + (1 - ALPHA) * prev_pan
    tilt = ALPHA * tilt_raw + (1 - ALPHA) * prev_tilt
    prev_pan, prev_tilt = pan, tilt
    
    if verbose:
        print(f"Box: ({x_box}, {y_box})")
        print(f"Pan: {pan}, Tilt: {tilt}")
    return pan, tilt


# Update servo angle
def update_angle(servo_angle, correction):
    if correction > 10:
        correction = 10
    elif correction < -10:
        correction = -10
    return max(SERVO_MIN, min(SERVO_MAX, math.ceil(servo_angle + correction)))

# %%
# Arduino

# Initialize serial connection to arduino
def init_arduino(*, port=ARDUINO_PORT, baudrate=ARDUINO_BAUDRATE, initial_angles=SERVO_INIT, verbose=True):
    try:
        arduino = serial.Serial(port, baudrate)
        time.sleep(2)
        if verbose:
            print(f"Connected to Arduino on {port}.")
        move_servos(arduino, initial_angles)
        return arduino
    except serial.SerialException as e:
        raise RuntimeError(f"Could not connect to Arduino on {port}: {e}")


# Move servos
def move_servos(arduino, angles: dict, verbose=True):
    try:
        command = f"{angles['x1']},{angles['y1']},{angles['x2']},{angles['y2']}\n"
        arduino.write(command.encode())
        arduino.flush()
        if verbose:
            print(f"C1 → X: {angles['x1']:.1f}°, Y: {angles['y1']:.1f}°")
            print(f"C2 → X: {angles['x2']:.1f}°, Y: {angles['y2']:.1f}°")
            
    except serial.SerialException as e:
        print(f"Serial communication error: {e}")

# %%
# Print functions

# Print divider
def print_div(text):
    print("\n" + f" {text} ".center(100, '-') + "\n")


# Print available cameras
def print_cameras():
    for camera_info in enumerate_cameras():
        print(f'{camera_info.index}: {camera_info.name}')


# Print final information
def final_prints(frame_count, x_center, y_center, balloon_position, dist_c1, dist_c2, servo_angles):
    x, y, z = balloon_position
    print(f"Total frames: {frame_count}")
    print(f"Detected classes: {DESIRED_CLASSES}")
    print(f"Frame center: ({x_center}, {y_center})")
    print(f"FPS: {(1/FRAME_DELAY):.2f}")
    print(f"Final balloon position: ({x:.2f}, {y:.2f}, {z:.2f})")
    print(f"Final C1 distance: {dist_c1:.2f} {DISTANCE_UNIT}")
    print(f"Final C2 distance: {dist_c2:.2f} {DISTANCE_UNIT}")
    print(f"Servo angles: {servo_angles}\n")

# %%
# Main program
print_div("Available cameras")
print_cameras()

print_div("Initial settings")
frame_count = 0
servo_angles = SERVO_INIT
vector_history = deque(maxlen=VECTOR_HISTORY_SIZE)
arduino = init_arduino()
cap = init_camera()
frame = read_frame(cap)
x_center, y_center = calculate_center(frame)
pid_pan, pid_tilt = init_pid(x_center, y_center)

print_div("Program started")
try:
    while True:
        x1_correction, y1_correction = 0, 0
        frame = read_frame(cap)
        results = MODEL(frame, stream=True)
        for r in results:
            if not r.boxes:
                continue
            for box in r.boxes:
                if valid_class(box):
                    draw_bounding_box(frame, box)
                    draw_movement_vector(frame, box, vector_history)
                    x1_correction, y1_correction = calculate_corrections(box, pid_pan, pid_tilt)
        
        print(f"Frame number: {frame_count}")
        balloon_position = triangulation(servo_angles)
        dist_c1 = get_distance('C1', balloon_position)
        dist_c2 = get_distance('C2', balloon_position)
        print(f"Servo angles: {servo_angles}")
        
        if x1_correction != 0 or y1_correction != 0:
            y1_correction *= -1 # type: ignore
            servo_angles['x1'] = update_angle(servo_angles['x1'], x1_correction)
            servo_angles['y1'] = update_angle(servo_angles['y1'], y1_correction)
            move_servos(arduino, servo_angles)
        
        cv2.imshow("Image", frame)
        if cv2.waitKey(1) == ord('q'):
            break
        frame_count += 1
        time.sleep(FRAME_DELAY)
finally:
    print_div("Program finished")
    final_prints(frame_count, x_center, y_center, balloon_position, dist_c1, dist_c2, servo_angles)
    cap.release()
    cv2.destroyAllWindows()
    arduino.close()
# Out:
# ---------------------------------------- Available cameras -----------------------------------------
#
# 1200: USB Camera VID:1133 PID:2085
# 1201: C270 HD WEBCAM
# 1202: iPhone Leo Camera
# 1203: MacBook Air Camera
#
# ----------------------------------------- Initial settings -----------------------------------------
# 2025-09-20 12:28:37.759 Python[15529:652577] WARNING: AVCaptureDeviceTypeExternal is deprecated for Continuity Cameras. Please use AVCaptureDeviceTypeContinuityCamera and add NSCameraUseContinuityCameraDeviceType to your Info.plist.
# Connected to Arduino on /dev/cu.usbmodem11101.
# C1 → X: 90.0°, Y: 90.0°
# C2 → X: 90.0°, Y: 90.0°
# Camera 1200 opened successfully.
# PID controller initialized.
#
# ----------------------------------------- Program started ------------------------------------------
#
#
# 0: 480x640 1 bed, 153.1ms
# Speed: 1.6ms preprocess, 153.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 0
# Balloon position: (10.00, 163312393531953696.00, 2667093788113571165172990803443712.00)
# C1 Distance: 2667093788113571165172990803443712.00 cm
# C2 Distance: 2667093788113571165172990803443712.00 cm
# Servo angles: {'x1': 90, 'y1': 90, 'x2': 90, 'y2': 90}
#
# 0: 480x640 (no detections), 148.2ms
# Speed: 1.2ms preprocess, 148.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 1
# Balloon position: (10.00, 163312393531953696.00, 2667093788113571165172990803443712.00)
# C1 Distance: 2667093788113571165172990803443712.00 cm
# C2 Distance: 2667093788113571165172990803443712.00 cm
# Servo angles: {'x1': 90, 'y1': 90, 'x2': 90, 'y2': 90}
#
# 0: 480x640 1 person, 144.1ms
# Speed: 1.2ms preprocess, 144.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 2
# Balloon position: (10.00, 163312393531953696.00, 2667093788113571165172990803443712.00)
# C1 Distance: 2667093788113571165172990803443712.00 cm
# C2 Distance: 2667093788113571165172990803443712.00 cm
# Servo angles: {'x1': 90, 'y1': 90, 'x2': 90, 'y2': 90}
#
# 0: 480x640 1 person, 1 remote, 139.9ms
# Speed: 1.1ms preprocess, 139.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 3
# Balloon position: (10.00, 163312393531953696.00, 2667093788113571165172990803443712.00)
# C1 Distance: 2667093788113571165172990803443712.00 cm
# C2 Distance: 2667093788113571165172990803443712.00 cm
# Servo angles: {'x1': 90, 'y1': 90, 'x2': 90, 'y2': 90}
#
# 0: 480x640 1 person, 213.3ms
# Speed: 1.1ms preprocess, 213.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 4
# Balloon position: (10.00, 163312393531953696.00, 2667093788113571165172990803443712.00)
# C1 Distance: 2667093788113571165172990803443712.00 cm
# C2 Distance: 2667093788113571165172990803443712.00 cm
# Servo angles: {'x1': 90, 'y1': 90, 'x2': 90, 'y2': 90}
#
# 0: 480x640 1 person, 143.4ms
# Speed: 1.1ms preprocess, 143.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 5
# Balloon position: (10.00, 163312393531953696.00, 2667093788113571165172990803443712.00)
# C1 Distance: 2667093788113571165172990803443712.00 cm
# C2 Distance: 2667093788113571165172990803443712.00 cm
# Servo angles: {'x1': 90, 'y1': 90, 'x2': 90, 'y2': 90}
#
# 0: 480x640 1 person, 140.9ms
# Speed: 1.1ms preprocess, 140.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 6
# Balloon position: (10.00, 163312393531953696.00, 2667093788113571165172990803443712.00)
# C1 Distance: 2667093788113571165172990803443712.00 cm
# C2 Distance: 2667093788113571165172990803443712.00 cm
# Servo angles: {'x1': 90, 'y1': 90, 'x2': 90, 'y2': 90}
#
# 0: 480x640 1 person, 148.2ms
# Speed: 1.1ms preprocess, 148.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 7
# Balloon position: (10.00, 163312393531953696.00, 2667093788113571165172990803443712.00)
# C1 Distance: 2667093788113571165172990803443712.00 cm
# C2 Distance: 2667093788113571165172990803443712.00 cm
# Servo angles: {'x1': 90, 'y1': 90, 'x2': 90, 'y2': 90}
#
# 0: 480x640 1 person, 1 sports ball, 144.0ms
# Class: sports ball, Confidence: 0.93
# Box: (103.19646453857422, 572.7752685546875)
# Pan: 0.6000000000000001, Tilt: -0.4247950276419582
# Speed: 1.1ms preprocess, 144.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 8
# Balloon position: (10.00, 163312393531953696.00, 2667093788113571165172990803443712.00)
# C1 Distance: 2667093788113571165172990803443712.00 cm
# C2 Distance: 2667093788113571165172990803443712.00 cm
# Servo angles: {'x1': 90, 'y1': 90, 'x2': 90, 'y2': 90}
# C1 → X: 91.0°, Y: 91.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 140.2ms
# Class: sports ball, Confidence: 0.95
# Box: (270.7615051269531, 387.2138977050781)
# Pan: -0.12, Tilt: 0.26016397788643353
# Speed: 1.1ms preprocess, 140.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 9
# Balloon position: (20.00, -1145.80, -9356160759273250816.00)
# C1 Distance: 9356160759273250816.00 cm
# C2 Distance: 9356160759273250816.00 cm
# Servo angles: {'x1': 91, 'y1': 91, 'x2': 90, 'y2': 90}
# C1 → X: 91.0°, Y: 91.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 1 couch, 142.3ms
# Class: sports ball, Confidence: 0.96
# Box: (379.243408203125, 322.0888977050781)
# Pan: -0.6960000000000001, Tilt: 0.8081311823091469
# Speed: 1.2ms preprocess, 142.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 10
# Balloon position: (20.00, -1145.80, -9356160759273250816.00)
# C1 Distance: 9356160759273250816.00 cm
# C2 Distance: 9356160759273250816.00 cm
# Servo angles: {'x1': 91, 'y1': 91, 'x2': 90, 'y2': 90}
# C1 → X: 91.0°, Y: 91.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 1 couch, 141.7ms
# Class: sports ball, Confidence: 0.96
# Box: (484.98193359375, 316.40447998046875)
# Pan: -1.1568, Tilt: 1.2465049458473176
# Speed: 1.4ms preprocess, 141.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 11
# Balloon position: (20.00, -1145.80, -9356160759273250816.00)
# C1 Distance: 9356160759273250816.00 cm
# C2 Distance: 9356160759273250816.00 cm
# Servo angles: {'x1': 91, 'y1': 91, 'x2': 90, 'y2': 90}
# C1 → X: 90.0°, Y: 90.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 142.4ms
# Class: sports ball, Confidence: 0.94
# Box: (533.04296875, 320.5421142578125)
# Pan: -1.5254400000000001, Tilt: 1.0270739750697897
# Speed: 1.1ms preprocess, 142.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 12
# Balloon position: (10.00, 163312393531953696.00, 2667093788113571165172990803443712.00)
# C1 Distance: 2667093788113571165172990803443712.00 cm
# C2 Distance: 2667093788113571165172990803443712.00 cm
# Servo angles: {'x1': 90, 'y1': 90, 'x2': 90, 'y2': 90}
# C1 → X: 89.0°, Y: 89.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 1 couch, 141.6ms
# Class: sports ball, Confidence: 0.94
# Box: (583.9508666992188, 345.25408935546875)
# Pan: -1.8203520000000002, Tilt: 0.22165918005583174
# Speed: 1.3ms preprocess, 141.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 13
# Balloon position: (20.00, 1145.80, 9356160759273183232.00)
# C1 Distance: 9356160759273183232.00 cm
# C2 Distance: 9356160759273183232.00 cm
# Servo angles: {'x1': 89, 'y1': 89, 'x2': 90, 'y2': 90}
# C1 → X: 88.0°, Y: 89.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 141.6ms
# Class: sports ball, Confidence: 0.91
# Box: (641.3670043945312, 379.31390380859375)
# Pan: -2.0562816, Tilt: -0.42267265595533465
# Speed: 1.0ms preprocess, 141.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 14
# Balloon position: (20.00, 572.73, 4676655065420208128.00)
# C1 Distance: 4676655065420208128.00 cm
# C2 Distance: 4676655065420208128.00 cm
# Servo angles: {'x1': 88, 'y1': 89, 'x2': 90, 'y2': 90}
# C1 → X: 86.0°, Y: 90.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 141.7ms
# Class: sports ball, Confidence: 0.96
# Box: (705.4310302734375, 373.4103088378906)
# Pan: -2.24502528, Tilt: 0.26186187523573234
# Speed: 1.2ms preprocess, 141.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 15
# Balloon position: (20.00, 286.01, 4676655065420198912.00)
# C1 Distance: 4676655065420198912.00 cm
# C2 Distance: 4676655065420198912.00 cm
# Servo angles: {'x1': 86, 'y1': 90, 'x2': 90, 'y2': 90}
# C1 → X: 84.0°, Y: 90.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 144.3ms
# Class: sports ball, Confidence: 0.97
# Box: (756.072021484375, 366.5852355957031)
# Pan: -2.3960202240000004, Tilt: 0.809489500188586
# Speed: 1.4ms preprocess, 144.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 16
# Balloon position: (20.00, 190.29, 3116186103783274496.00)
# C1 Distance: 3116186103783274496.00 cm
# C2 Distance: 3116186103783274496.00 cm
# Servo angles: {'x1': 84, 'y1': 90, 'x2': 90, 'y2': 90}
# C1 → X: 82.0°, Y: 90.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 141.4ms
# Class: sports ball, Confidence: 0.97
# Box: (804.1329956054688, 356.5521545410156)
# Pan: -2.5168161792000006, Tilt: 1.247591600150869
# Speed: 1.1ms preprocess, 141.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 17
# Balloon position: (20.00, 142.31, 2335476035485264384.00)
# C1 Distance: 2335476035485264384.00 cm
# C2 Distance: 2335476035485264384.00 cm
# Servo angles: {'x1': 82, 'y1': 90, 'x2': 90, 'y2': 90}
# C1 → X: 80.0°, Y: 89.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 142.1ms
# Class: sports ball, Confidence: 0.97
# Box: (839.41943359375, 325.93975830078125)
# Pan: -2.6134529433600004, Tilt: 1.5980732801206954
# Speed: 1.2ms preprocess, 142.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 18
# Balloon position: (20.00, 113.43, 926190608356025472.00)
# C1 Distance: 926190608356025472.00 cm
# C2 Distance: 926190608356025472.00 cm
# Servo angles: {'x1': 80, 'y1': 89, 'x2': 90, 'y2': 90}
# C1 → X: 78.0°, Y: 88.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 143.7ms
# Class: sports ball, Confidence: 0.97
# Box: (740.6581420898438, 300.9886169433594)
# Pan: -1.4907623546880004, Tilt: 1.8784586240965564
# Speed: 1.1ms preprocess, 143.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 19
# Balloon position: (20.00, 94.09, 768324403861423616.00)
# C1 Distance: 768324403861423616.00 cm
# C2 Distance: 768324403861423616.00 cm
# Servo angles: {'x1': 78, 'y1': 88, 'x2': 90, 'y2': 90}
# C1 → X: 77.0°, Y: 87.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 143.8ms
# Class: sports ball, Confidence: 0.97
# Box: (757.2844848632812, 312.3641357421875)
# Pan: -1.7926098837504005, Tilt: 1.0333221939583626
# Speed: 1.0ms preprocess, 143.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 20
# Balloon position: (20.00, 86.63, 707383692555257472.00)
# C1 Distance: 707383692555257472.00 cm
# C2 Distance: 707383692555257472.00 cm
# Servo angles: {'x1': 77, 'y1': 87, 'x2': 90, 'y2': 90}
# C1 → X: 76.0°, Y: 86.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 178.8ms
# Class: sports ball, Confidence: 0.95
# Box: (767.2880859375, 345.6420593261719)
# Pan: -2.0340879070003206, Tilt: 0.22665775516668996
# Speed: 1.2ms preprocess, 178.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 21
# Balloon position: (20.00, 80.22, 655010234188063104.00)
# C1 Distance: 655010234188063104.00 cm
# C2 Distance: 655010234188063104.00 cm
# Servo angles: {'x1': 76, 'y1': 86, 'x2': 90, 'y2': 90}
# C1 → X: 74.0°, Y: 86.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 144.5ms
# Class: sports ball, Confidence: 0.93
# Box: (806.300537109375, 393.36370849609375)
# Pan: -2.227270325600257, Tilt: -0.4186737958666481
# Speed: 1.1ms preprocess, 144.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 22
# Balloon position: (20.00, 69.75, 569538000061566400.00)
# C1 Distance: 569538000061566400.00 cm
# C2 Distance: 569538000061566400.00 cm
# Servo angles: {'x1': 74, 'y1': 86, 'x2': 90, 'y2': 90}
# C1 → X: 72.0°, Y: 87.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 145.0ms
# Class: sports ball, Confidence: 0.94
# Box: (753.4530029296875, 431.08099365234375)
# Pan: -1.1818162604802054, Tilt: -0.9349390366933186
# Speed: 1.2ms preprocess, 145.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 23
# Balloon position: (20.00, 61.55, 502623864989980672.00)
# C1 Distance: 502623864989980672.00 cm
# C2 Distance: 502623864989980672.00 cm
# Servo angles: {'x1': 72, 'y1': 87, 'x2': 90, 'y2': 90}
# C1 → X: 71.0°, Y: 88.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 143.1ms
# Class: sports ball, Confidence: 0.91
# Box: (650.965087890625, 475.5807800292969)
# Pan: -0.34545300838416426, Tilt: -1.347951229354655
# Speed: 1.2ms preprocess, 143.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 24
# Balloon position: (20.00, 58.08, 474293629754775552.00)
# C1 Distance: 474293629754775552.00 cm
# C2 Distance: 474293629754775552.00 cm
# Servo angles: {'x1': 71, 'y1': 88, 'x2': 90, 'y2': 90}
# C1 → X: 71.0°, Y: 90.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 143.3ms
# Class: sports ball, Confidence: 0.95
# Box: (566.0902099609375, 482.5272216796875)
# Pan: 0.32363759329266867, Tilt: -1.6169326417785053
# Speed: 1.2ms preprocess, 143.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 25
# Balloon position: (20.00, 58.08, 975916381538518016.00)
# C1 Distance: 975916381538518016.00 cm
# C2 Distance: 975916381538518016.00 cm
# Servo angles: {'x1': 71, 'y1': 90, 'x2': 90, 'y2': 90}
# C1 → X: 72.0°, Y: 92.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 141.9ms
# Class: sports ball, Confidence: 0.96
# Box: (495.25860595703125, 454.47979736328125)
# Pan: 0.858910074634135, Tilt: -0.6935461134228043
# Speed: 1.2ms preprocess, 141.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 26
# Balloon position: (20.00, 61.55, 502623864989979136.00)
# C1 Distance: 502623864989979136.00 cm
# C2 Distance: 502623864989979136.00 cm
# Servo angles: {'x1': 72, 'y1': 92, 'x2': 90, 'y2': 90}
# C1 → X: 73.0°, Y: 93.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 160.6ms
# Class: sports ball, Confidence: 0.96
# Box: (423.0869140625, 408.38037109375)
# Pan: 1.287128059707308, Tilt: 0.045163109261756706
# Speed: 1.5ms preprocess, 160.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 27
# Balloon position: (20.00, 65.42, 534170770014901952.00)
# C1 Distance: 534170770014901952.00 cm
# C2 Distance: 534170770014901952.00 cm
# Servo angles: {'x1': 73, 'y1': 93, 'x2': 90, 'y2': 90}
# C1 → X: 75.0°, Y: 93.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 1 chair, 141.7ms
# Class: sports ball, Confidence: 0.96
# Box: (340.0715026855469, 373.8601379394531)
# Pan: 1.6297024477658466, Tilt: 0.6361304874094055
# Speed: 1.4ms preprocess, 141.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 28
# Balloon position: (20.00, 74.64, 609490150166933760.00)
# C1 Distance: 609490150166933760.00 cm
# C2 Distance: 609490150166933760.00 cm
# Servo angles: {'x1': 75, 'y1': 93, 'x2': 90, 'y2': 90}
# C1 → X: 77.0°, Y: 93.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 143.8ms
# Class: sports ball, Confidence: 0.96
# Box: (258.48907470703125, 357.5438232421875)
# Pan: 1.9037619582126775, Tilt: 1.1089043899275244
# Speed: 1.0ms preprocess, 143.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 29
# Balloon position: (20.00, 86.63, 707383692555255680.00)
# C1 Distance: 707383692555255680.00 cm
# C2 Distance: 707383692555255680.00 cm
# Servo angles: {'x1': 77, 'y1': 93, 'x2': 90, 'y2': 90}
# C1 → X: 79.0°, Y: 92.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 1 chair, 141.0ms
# Class: sports ball, Confidence: 0.94
# Box: (224.3562774658203, 363.0771484375)
# Pan: 2.123009566570142, Tilt: 0.876713207241411
# Speed: 1.1ms preprocess, 141.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 30
# Balloon position: (20.00, 102.89, 840169430002533888.00)
# C1 Distance: 840169430002533888.00 cm
# C2 Distance: 840169430002533888.00 cm
# Servo angles: {'x1': 79, 'y1': 92, 'x2': 90, 'y2': 90}
# C1 → X: 82.0°, Y: 92.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 1 chair, 141.6ms
# Class: sports ball, Confidence: 0.89
# Box: (246.61868286132812, 406.9017333984375)
# Pan: 1.4763437623852458, Tilt: 0.10137056579312875
# Speed: 1.0ms preprocess, 141.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 31
# Balloon position: (20.00, 142.31, 1162028060227353344.00)
# C1 Distance: 1162028060227353344.00 cm
# C2 Distance: 1162028060227353344.00 cm
# Servo angles: {'x1': 82, 'y1': 92, 'x2': 90, 'y2': 90}
# C1 → X: 84.0°, Y: 92.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 1 chair, 142.2ms
# Class: sports ball, Confidence: 0.94
# Box: (308.2402648925781, 472.4202880859375)
# Pan: 0.5810750099081965, Tilt: -0.518903547365497
# Speed: 1.1ms preprocess, 142.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 32
# Balloon position: (20.00, 190.29, 1553813631954430464.00)
# C1 Distance: 1553813631954430464.00 cm
# C2 Distance: 1553813631954430464.00 cm
# Servo angles: {'x1': 84, 'y1': 92, 'x2': 90, 'y2': 90}
# C1 → X: 85.0°, Y: 93.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 1 chair, 141.6ms
# Class: sports ball, Confidence: 0.91
# Box: (311.7369079589844, 527.4508666992188)
# Pan: 1.0648600079265573, Tilt: -1.0151228378923978
# Speed: 1.1ms preprocess, 141.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 33
# Balloon position: (20.00, 228.60, 1866669199759371264.00)
# C1 Distance: 1866669199759371264.00 cm
# C2 Distance: 1866669199759371264.00 cm
# Servo angles: {'x1': 85, 'y1': 93, 'x2': 90, 'y2': 90}
# C1 → X: 87.0°, Y: 95.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 1 chair, 142.9ms
# Class: sports ball, Confidence: 0.92
# Box: (273.23309326171875, 557.39306640625)
# Pan: 1.451888006341246, Tilt: -1.4120982703139182
# Speed: 1.1ms preprocess, 142.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 34
# Balloon position: (20.00, 381.62, 3116186103783241728.00)
# C1 Distance: 3116186103783241728.00 cm
# C2 Distance: 3116186103783241728.00 cm
# Servo angles: {'x1': 87, 'y1': 95, 'x2': 90, 'y2': 90}
# C1 → X: 89.0°, Y: 97.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 1 chair, 142.2ms
# Class: sports ball, Confidence: 0.96
# Box: (262.752197265625, 548.5737915039062)
# Pan: 1.761510405072997, Tilt: -0.5296786162511344
# Speed: 1.1ms preprocess, 142.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 35
# Balloon position: (20.00, 1145.80, 9356160759273146368.00)
# C1 Distance: 9356160759273146368.00 cm
# C2 Distance: 9356160759273146368.00 cm
# Servo angles: {'x1': 89, 'y1': 97, 'x2': 90, 'y2': 90}
# C1 → X: 91.0°, Y: 98.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 143.4ms
# Class: sports ball, Confidence: 0.95
# Box: (203.99465942382812, 501.8499755859375)
# Pan: 2.009208324058398, Tilt: 0.17625710699909253
# Speed: 1.1ms preprocess, 143.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 36
# Balloon position: (20.00, -1145.80, -9356160759273279488.00)
# C1 Distance: 9356160759273279488.00 cm
# C2 Distance: 9356160759273279488.00 cm
# Servo angles: {'x1': 91, 'y1': 98, 'x2': 90, 'y2': 90}
# C1 → X: 94.0°, Y: 98.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 1 chair, 143.6ms
# Class: sports ball, Confidence: 0.96
# Box: (182.22796630859375, 461.9591979980469)
# Pan: 2.2073666592467185, Tilt: 0.7410056855992742
# Speed: 1.1ms preprocess, 143.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 37
# Balloon position: (20.00, -286.01, -2335476035485268992.00)
# C1 Distance: 2335476035485268992.00 cm
# C2 Distance: 2335476035485268992.00 cm
# Servo angles: {'x1': 94, 'y1': 98, 'x2': 90, 'y2': 90}
# C1 → X: 97.0°, Y: 98.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 1 couch, 141.8ms
# Class: sports ball, Confidence: 0.95
# Box: (371.1724548339844, 460.5113220214844)
# Pan: 1.1658933273973748, Tilt: 0.9125591675955806
# Speed: 1.1ms preprocess, 141.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 38
# Balloon position: (20.00, -162.89, -1330072708905949952.00)
# C1 Distance: 1330072708905949952.00 cm
# C2 Distance: 1330072708905949952.00 cm
# Servo angles: {'x1': 97, 'y1': 98, 'x2': 90, 'y2': 90}
# C1 → X: 99.0°, Y: 98.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 1 chair, 143.0ms
# Class: sports ball, Confidence: 0.95
# Box: (526.6309814453125, 504.01287841796875)
# Pan: 0.3327146619178998, Tilt: 0.13004733407646452
# Speed: 1.1ms preprocess, 143.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 39
# Balloon position: (20.00, -126.28, -1031113872027579904.00)
# C1 Distance: 1031113872027579904.00 cm
# C2 Distance: 1031113872027579904.00 cm
# Servo angles: {'x1': 99, 'y1': 98, 'x2': 90, 'y2': 90}
# C1 → X: 100.0°, Y: 98.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 1 couch, 143.7ms
# Class: sports ball, Confidence: 0.95
# Box: (694.2559814453125, 540.34228515625)
# Pan: -0.33382827046568025, Tilt: -0.4959621327388285
# Speed: 1.1ms preprocess, 143.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 40
# Balloon position: (20.00, -113.43, -926190608356023040.00)
# C1 Distance: 926190608356023040.00 cm
# C2 Distance: 926190608356023040.00 cm
# Servo angles: {'x1': 100, 'y1': 98, 'x2': 90, 'y2': 90}
# C1 → X: 100.0°, Y: 99.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 143.6ms
# Class: sports ball, Confidence: 0.96
# Box: (835.0658569335938, 561.6761474609375)
# Pan: -0.8670626163725443, Tilt: -0.996769706191063
# Speed: 1.1ms preprocess, 143.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 41
# Balloon position: (20.00, -113.43, -926190608356023040.00)
# C1 Distance: 926190608356023040.00 cm
# C2 Distance: 926190608356023040.00 cm
# Servo angles: {'x1': 100, 'y1': 99, 'x2': 90, 'y2': 90}
# C1 → X: 100.0°, Y: 100.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 1 chair, 149.9ms
# Class: sports ball, Confidence: 0.96
# Box: (956.1759033203125, 555.0794067382812)
# Pan: -1.2936500930980355, Tilt: -0.3473035299828458
# Speed: 1.0ms preprocess, 149.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 42
# Balloon position: (20.00, -113.43, -926190608356023040.00)
# C1 Distance: 926190608356023040.00 cm
# C2 Distance: 926190608356023040.00 cm
# Servo angles: {'x1': 100, 'y1': 100, 'x2': 90, 'y2': 90}
# C1 → X: 99.0°, Y: 101.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 1 chair, 143.0ms
# Class: sports ball, Confidence: 0.96
# Box: (1066.5849609375, 517.8182983398438)
# Pan: -1.6349200744784285, Tilt: 0.32215717601372346
# Speed: 1.0ms preprocess, 143.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 43
# Balloon position: (20.00, -126.28, -1031113872027580032.00)
# C1 Distance: 1031113872027580032.00 cm
# C2 Distance: 1031113872027580032.00 cm
# Servo angles: {'x1': 99, 'y1': 101, 'x2': 90, 'y2': 90}
# C1 → X: 98.0°, Y: 101.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 145.1ms
# Class: sports ball, Confidence: 0.96
# Box: (1140.709716796875, 451.3333740234375)
# Pan: -1.907936059582743, Tilt: 0.8577257408109789
# Speed: 1.1ms preprocess, 145.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 44
# Balloon position: (20.00, -142.31, -1162028060227357184.00)
# C1 Distance: 1162028060227357184.00 cm
# C2 Distance: 1162028060227357184.00 cm
# Servo angles: {'x1': 98, 'y1': 101, 'x2': 90, 'y2': 90}
# C1 → X: 97.0°, Y: 101.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 1 bed, 145.0ms
# Class: sports ball, Confidence: 0.96
# Box: (1157.132080078125, 393.669921875)
# Pan: -2.1263488476661947, Tilt: 1.2861805926487833
# Speed: 1.1ms preprocess, 145.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 45
# Balloon position: (20.00, -162.89, -1330072708905949952.00)
# C1 Distance: 1330072708905949952.00 cm
# C2 Distance: 1330072708905949952.00 cm
# Servo angles: {'x1': 97, 'y1': 101, 'x2': 90, 'y2': 90}
# C1 → X: 95.0°, Y: 100.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 144.2ms
# Class: sports ball, Confidence: 0.97
# Box: (1109.77587890625, 342.3116455078125)
# Pan: -1.1010790781329558, Tilt: 1.6289444741190267
# Speed: 1.1ms preprocess, 144.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 46
# Balloon position: (20.00, -228.60, -1866669199759378176.00)
# C1 Distance: 1866669199759378176.00 cm
# C2 Distance: 1866669199759378176.00 cm
# Servo angles: {'x1': 95, 'y1': 100, 'x2': 90, 'y2': 90}
# C1 → X: 94.0°, Y: 99.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 1 chair, 1 couch, 142.5ms
# Class: sports ball, Confidence: 0.97
# Box: (1011.715576171875, 307.908935546875)
# Pan: -0.2808632625063646, Tilt: 1.9031555792952215
# Speed: 1.3ms preprocess, 142.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 47
# Balloon position: (20.00, -286.01, -2335476035485268992.00)
# C1 Distance: 2335476035485268992.00 cm
# C2 Distance: 2335476035485268992.00 cm
# Servo angles: {'x1': 94, 'y1': 99, 'x2': 90, 'y2': 90}
# C1 → X: 94.0°, Y: 98.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 1 chair, 1 couch, 146.2ms
# Class: sports ball, Confidence: 0.96
# Box: (952.9296264648438, 282.1746826171875)
# Pan: 0.37530938999490837, Tilt: 2.1225244634361773
# Speed: 1.2ms preprocess, 146.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 48
# Balloon position: (20.00, -286.01, -2335476035485268992.00)
# C1 Distance: 2335476035485268992.00 cm
# C2 Distance: 2335476035485268992.00 cm
# Servo angles: {'x1': 94, 'y1': 98, 'x2': 90, 'y2': 90}
# C1 → X: 95.0°, Y: 96.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 142.7ms
# Class: sports ball, Confidence: 0.97
# Box: (888.794921875, 272.1728820800781)
# Pan: 0.9002475119959268, Tilt: 2.298019570748942
# Speed: 1.0ms preprocess, 142.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 49
# Balloon position: (20.00, -228.60, -1866669199759377920.00)
# C1 Distance: 1866669199759377920.00 cm
# C2 Distance: 1866669199759377920.00 cm
# Servo angles: {'x1': 95, 'y1': 96, 'x2': 90, 'y2': 90}
# C1 → X: 96.0°, Y: 94.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 143.3ms
# Class: sports ball, Confidence: 0.97
# Box: (845.5430908203125, 263.35894775390625)
# Pan: 1.3201980095967416, Tilt: 2.4384156565991537
# Speed: 1.1ms preprocess, 143.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 50
# Balloon position: (20.00, -190.29, -1553813631954429184.00)
# C1 Distance: 1553813631954429184.00 cm
# C2 Distance: 1553813631954429184.00 cm
# Servo angles: {'x1': 96, 'y1': 94, 'x2': 90, 'y2': 90}
# C1 → X: 98.0°, Y: 92.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 143.7ms
# Class: sports ball, Confidence: 0.97
# Box: (800.7515869140625, 294.0089111328125)
# Pan: 1.6561584076773934, Tilt: 1.350732525279323
# Speed: 1.1ms preprocess, 143.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 51
# Balloon position: (20.00, -142.31, -1162028060227355392.00)
# C1 Distance: 1162028060227355392.00 cm
# C2 Distance: 1162028060227355392.00 cm
# Servo angles: {'x1': 98, 'y1': 92, 'x2': 90, 'y2': 90}
# C1 → X: 100.0°, Y: 91.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 143.0ms
# Class: sports ball, Confidence: 0.97
# Box: (744.3018798828125, 333.17950439453125)
# Pan: 1.924926726141915, Tilt: 0.4805860202234584
# Speed: 1.1ms preprocess, 143.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 52
# Balloon position: (20.00, -113.43, -926190608356020096.00)
# C1 Distance: 926190608356020096.00 cm
# C2 Distance: 926190608356020096.00 cm
# Servo angles: {'x1': 100, 'y1': 91, 'x2': 90, 'y2': 90}
# C1 → X: 102.0°, Y: 91.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 144.5ms
# Class: sports ball, Confidence: 0.97
# Box: (730.8405151367188, 341.35675048828125)
# Pan: 2.139941380913532, Tilt: 0.35674653575742543
# Speed: 1.1ms preprocess, 144.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 53
# Balloon position: (20.00, -94.09, -768324403861420288.00)
# C1 Distance: 768324403861420288.00 cm
# C2 Distance: 768324403861420288.00 cm
# Servo angles: {'x1': 102, 'y1': 91, 'x2': 90, 'y2': 90}
# C1 → X: 105.0°, Y: 91.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 144.0ms
# Class: sports ball, Confidence: 0.98
# Box: (723.9605712890625, 335.923828125)
# Pan: 2.2052607690205543, Tilt: 0.8853972286059404
# Speed: 1.1ms preprocess, 144.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 54
# Balloon position: (20.00, -74.64, -609490150166931840.00)
# C1 Distance: 609490150166931840.00 cm
# C2 Distance: 609490150166931840.00 cm
# Servo angles: {'x1': 105, 'y1': 91, 'x2': 90, 'y2': 90}
# C1 → X: 108.0°, Y: 91.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 144.4ms
# Class: sports ball, Confidence: 0.97
# Box: (748.6998901367188, 316.53778076171875)
# Pan: 1.1642086152164435, Tilt: 1.3083177828847523
# Speed: 1.1ms preprocess, 144.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 55
# Balloon position: (20.00, -61.55, -502623864989978624.00)
# C1 Distance: 502623864989978624.00 cm
# C2 Distance: 502623864989978624.00 cm
# Servo angles: {'x1': 108, 'y1': 91, 'x2': 90, 'y2': 90}
# C1 → X: 110.0°, Y: 90.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 145.9ms
# Class: sports ball, Confidence: 0.97
# Box: (756.2706298828125, 292.89349365234375)
# Pan: 0.33136689217315474, Tilt: 1.646654226307802
# Speed: 1.0ms preprocess, 145.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 56
# Balloon position: (20.00, -54.95, -926190608356022016.00)
# C1 Distance: 926190608356022016.00 cm
# C2 Distance: 926190608356022016.00 cm
# Servo angles: {'x1': 110, 'y1': 90, 'x2': 90, 'y2': 90}
# C1 → X: 111.0°, Y: 89.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 145.3ms
# Class: sports ball, Confidence: 0.97
# Box: (750.026123046875, 306.4241027832031)
# Pan: 0.5731913986901437, Tilt: 0.9713331028924943
# Speed: 1.0ms preprocess, 145.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 57
# Balloon position: (20.00, -52.10, -425443330519064704.00)
# C1 Distance: 425443330519064704.00 cm
# C2 Distance: 425443330519064704.00 cm
# Servo angles: {'x1': 111, 'y1': 89, 'x2': 90, 'y2': 90}
# C1 → X: 112.0°, Y: 89.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 143.8ms
# Class: sports ball, Confidence: 0.97
# Box: (701.6631469726562, 332.4095153808594)
# Pan: 1.0585531189521151, Tilt: 0.17706648231399535
# Speed: 1.1ms preprocess, 143.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 58
# Balloon position: (20.00, -49.50, -404212358230888704.00)
# C1 Distance: 404212358230888704.00 cm
# C2 Distance: 404212358230888704.00 cm
# Servo angles: {'x1': 112, 'y1': 89, 'x2': 90, 'y2': 90}
# C1 → X: 114.0°, Y: 89.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 144.4ms
# Class: sports ball, Confidence: 0.97
# Box: (672.7576904296875, 333.69183349609375)
# Pan: 1.4468424951616923, Tilt: 0.7416531858511963
# Speed: 1.1ms preprocess, 144.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 59
# Balloon position: (20.00, -44.92, -366805641507086400.00)
# C1 Distance: 366805641507086400.00 cm
# C2 Distance: 366805641507086400.00 cm
# Servo angles: {'x1': 114, 'y1': 89, 'x2': 90, 'y2': 90}
# C1 → X: 116.0°, Y: 89.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 145.7ms
# Class: sports ball, Confidence: 0.97
# Box: (689.51513671875, 331.6318359375)
# Pan: 0.5574739961293538, Tilt: 1.1933225486809573
# Speed: 1.1ms preprocess, 145.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 60
# Balloon position: (20.00, -41.01, -334840027836075712.00)
# C1 Distance: 334840027836075712.00 cm
# C2 Distance: 334840027836075712.00 cm
# Servo angles: {'x1': 116, 'y1': 89, 'x2': 90, 'y2': 90}
# C1 → X: 117.0°, Y: 88.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 144.4ms
# Class: sports ball, Confidence: 0.97
# Box: (681.7310180664062, 330.1065673828125)
# Pan: 1.045979196903483, Tilt: 1.554658038944766
# Speed: 1.0ms preprocess, 144.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 61
# Balloon position: (20.00, -39.25, -320518619225004480.00)
# C1 Distance: 320518619225004480.00 cm
# C2 Distance: 320518619225004480.00 cm
# Servo angles: {'x1': 117, 'y1': 88, 'x2': 90, 'y2': 90}
# C1 → X: 119.0°, Y: 87.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 145.5ms
# Class: sports ball, Confidence: 0.97
# Box: (639.1311645507812, 361.8876647949219)
# Pan: 1.4367833575227866, Tilt: 0.6437264311558129
# Speed: 1.1ms preprocess, 145.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 62
# Balloon position: (20.00, -36.08, -294623356959324928.00)
# C1 Distance: 294623356959324928.00 cm
# C2 Distance: 294623356959324928.00 cm
# Servo angles: {'x1': 119, 'y1': 87, 'x2': 90, 'y2': 90}
# C1 → X: 121.0°, Y: 87.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 2 sports balls, 144.2ms
# Class: sports ball, Confidence: 0.85
# Box: (634.6654052734375, 406.6341247558594)
# Pan: 1.624601199043803, Tilt: -0.08501885507534979
# Class: sports ball, Confidence: 0.28
# Box: (634.4642333984375, 406.2015380859375)
# Pan: 1.774855472260616, Tilt: -0.6680150840602799
# Speed: 1.1ms preprocess, 144.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 63
# Balloon position: (20.00, -33.29, -271797465768784448.00)
# C1 Distance: 271797465768784448.00 cm
# C2 Distance: 271797465768784448.00 cm
# Servo angles: {'x1': 121, 'y1': 87, 'x2': 90, 'y2': 90}
# C1 → X: 123.0°, Y: 88.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 143.8ms
# Class: sports ball, Confidence: 0.94
# Box: (609.8406372070312, 471.02667236328125)
# Pan: 2.019884377808493, Tilt: -1.134412067248224
# Speed: 1.1ms preprocess, 143.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 64
# Balloon position: (20.00, -30.80, -251479032956555328.00)
# C1 Distance: 251479032956555328.00 cm
# C2 Distance: 251479032956555328.00 cm
# Servo angles: {'x1': 123, 'y1': 88, 'x2': 90, 'y2': 90}
# C1 → X: 126.0°, Y: 90.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 143.5ms
# Class: sports ball, Confidence: 0.94
# Box: (652.6300048828125, 566.7357177734375)
# Pan: 1.0159075022467945, Tilt: -1.5075296537985794
# Speed: 1.1ms preprocess, 143.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 65
# Balloon position: (20.00, -27.53, -502623864989980416.00)
# C1 Distance: 502623864989980416.00 cm
# C2 Distance: 502623864989980416.00 cm
# Servo angles: {'x1': 126, 'y1': 90, 'x2': 90, 'y2': 90}
# C1 → X: 128.0°, Y: 92.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 142.6ms
# Class: sports ball, Confidence: 0.96
# Box: (732.2681274414062, 617.6666870117188)
# Pan: 0.2127260017974355, Tilt: -1.8060237230388636
# Speed: 1.1ms preprocess, 142.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 66
# Balloon position: (20.00, -25.60, -209030331534646784.00)
# C1 Distance: 209030331534646784.00 cm
# C2 Distance: 209030331534646784.00 cm
# Servo angles: {'x1': 128, 'y1': 92, 'x2': 90, 'y2': 90}
# C1 → X: 129.0°, Y: 94.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 144.7ms
# Class: sports ball, Confidence: 0.94
# Box: (821.0, 634.121337890625)
# Pan: -0.42981919856205164, Tilt: -2.044818978431091
# Speed: 1.1ms preprocess, 144.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 67
# Balloon position: (20.00, -24.70, -201674010399542816.00)
# C1 Distance: 201674010399542816.00 cm
# C2 Distance: 201674010399542816.00 cm
# Servo angles: {'x1': 129, 'y1': 94, 'x2': 90, 'y2': 90}
# C1 → X: 129.0°, Y: 97.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 145.1ms
# Class: sports ball, Confidence: 0.95
# Box: (912.1788330078125, 610.257080078125)
# Pan: -0.9438553588496414, Tilt: -1.0358551827448728
# Speed: 1.1ms preprocess, 145.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 68
# Balloon position: (20.00, -24.70, -201674010399542912.00)
# C1 Distance: 201674010399542912.00 cm
# C2 Distance: 201674010399542912.00 cm
# Servo angles: {'x1': 129, 'y1': 97, 'x2': 90, 'y2': 90}
# C1 → X: 129.0°, Y: 99.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 143.3ms
# Class: sports ball, Confidence: 0.96
# Box: (995.9957275390625, 550.2999267578125)
# Pan: -1.3550842870797133, Tilt: -0.22868414619589816
# Speed: 1.1ms preprocess, 143.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 69
# Balloon position: (20.00, -24.70, -201674010399542944.00)
# C1 Distance: 201674010399542944.00 cm
# C2 Distance: 201674010399542944.00 cm
# Servo angles: {'x1': 129, 'y1': 99, 'x2': 90, 'y2': 90}
# C1 → X: 128.0°, Y: 100.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 142.7ms
# Class: sports ball, Confidence: 0.96
# Box: (1089.521728515625, 510.83282470703125)
# Pan: -1.6840674296637708, Tilt: 0.4170526830432816
# Speed: 1.1ms preprocess, 142.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 70
# Balloon position: (20.00, -25.60, -209030331534647168.00)
# C1 Distance: 209030331534647168.00 cm
# C2 Distance: 209030331534647168.00 cm
# Servo angles: {'x1': 128, 'y1': 100, 'x2': 90, 'y2': 90}
# C1 → X: 127.0°, Y: 100.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 144.0ms
# Class: sports ball, Confidence: 0.96
# Box: (1183.893310546875, 499.8254089355469)
# Pan: -1.9472539437310168, Tilt: 0.9336421464346254
# Speed: 1.1ms preprocess, 144.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 71
# Balloon position: (20.00, -26.54, -216722866143013536.00)
# C1 Distance: 216722866143013536.00 cm
# C2 Distance: 216722866143013536.00 cm
# Servo angles: {'x1': 127, 'y1': 100, 'x2': 90, 'y2': 90}
# C1 → X: 126.0°, Y: 100.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 2 persons, 1 sports ball, 145.4ms
# Class: sports ball, Confidence: 0.91
# Box: (1229.4949951171875, 508.1012268066406)
# Pan: -2.157803154984814, Tilt: 0.29838782896000715
# Speed: 1.2ms preprocess, 145.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 72
# Balloon position: (20.00, -27.53, -224780225846254464.00)
# C1 Distance: 224780225846254464.00 cm
# C2 Distance: 224780225846254464.00 cm
# Servo angles: {'x1': 126, 'y1': 100, 'x2': 90, 'y2': 90}
# C1 → X: 124.0°, Y: 100.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 143.6ms
# Speed: 1.3ms preprocess, 143.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 73
# Balloon position: (20.00, -29.65, -242120580324867040.00)
# C1 Distance: 242120580324867040.00 cm
# C2 Distance: 242120580324867040.00 cm
# Servo angles: {'x1': 124, 'y1': 100, 'x2': 90, 'y2': 90}
#
# 0: 480x640 1 person, 1 sports ball, 144.6ms
# Class: sports ball, Confidence: 0.28
# Box: (1264.019775390625, 490.39666748046875)
# Pan: -2.326242523987851, Tilt: 0.8387102631680058
# Speed: 1.3ms preprocess, 144.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 74
# Balloon position: (20.00, -29.65, -242120580324867040.00)
# C1 Distance: 242120580324867040.00 cm
# C2 Distance: 242120580324867040.00 cm
# Servo angles: {'x1': 124, 'y1': 100, 'x2': 90, 'y2': 90}
# C1 → X: 122.0°, Y: 100.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 couch, 142.5ms
# Speed: 1.0ms preprocess, 142.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 75
# Balloon position: (20.00, -32.01, -261354462389525824.00)
# C1 Distance: 261354462389525824.00 cm
# C2 Distance: 261354462389525824.00 cm
# Servo angles: {'x1': 122, 'y1': 100, 'x2': 90, 'y2': 90}
#
# 0: 480x640 1 person, 1 sports ball, 1 apple, 144.3ms
# Class: sports ball, Confidence: 0.47
# Box: (1251.328125, 479.3328552246094)
# Pan: -2.460994019190281, Tilt: 1.270968210534405
# Speed: 1.0ms preprocess, 144.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 76
# Balloon position: (20.00, -32.01, -261354462389525824.00)
# C1 Distance: 261354462389525824.00 cm
# C2 Distance: 261354462389525824.00 cm
# Servo angles: {'x1': 122, 'y1': 100, 'x2': 90, 'y2': 90}
# C1 → X: 120.0°, Y: 99.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 1 apple, 143.4ms
# Class: sports ball, Confidence: 0.49
# Box: (1251.1925048828125, 479.853271484375)
# Pan: -2.5687952153522247, Tilt: 1.3415998130058229
# Speed: 1.0ms preprocess, 143.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 77
# Balloon position: (20.00, -34.64, -282865363103026720.00)
# C1 Distance: 282865363103026720.00 cm
# C2 Distance: 282865363103026720.00 cm
# Servo angles: {'x1': 120, 'y1': 99, 'x2': 90, 'y2': 90}
# C1 → X: 118.0°, Y: 98.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 bench, 1 sports ball, 1 apple, 145.5ms
# Class: sports ball, Confidence: 0.5
# Box: (1249.985595703125, 487.05706787109375)
# Pan: -2.65503617228178, Tilt: 0.7791584332698616
# Speed: 1.1ms preprocess, 145.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 78
# Balloon position: (20.00, -37.61, -307145940634600192.00)
# C1 Distance: 307145940634600192.00 cm
# C2 Distance: 307145940634600192.00 cm
# Servo angles: {'x1': 118, 'y1': 98, 'x2': 90, 'y2': 90}
# C1 → X: 116.0°, Y: 98.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 1 dining table, 145.3ms
# Class: sports ball, Confidence: 0.77
# Box: (1226.380126953125, 510.8420715332031)
# Pan: -2.3658952783402003, Tilt: 0.023326746615889182
# Speed: 1.0ms preprocess, 145.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 79
# Balloon position: (20.00, -41.01, -334840027836074240.00)
# C1 Distance: 334840027836074240.00 cm
# C2 Distance: 334840027836074240.00 cm
# Servo angles: {'x1': 116, 'y1': 98, 'x2': 90, 'y2': 90}
# C1 → X: 114.0°, Y: 98.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 160.7ms
# Class: sports ball, Confidence: 0.76
# Box: (1232.864990234375, 522.794677734375)
# Pan: -2.4927162226721604, Tilt: -0.5813386027072888
# Speed: 1.4ms preprocess, 160.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 80
# Balloon position: (20.00, -44.92, -366805641507084800.00)
# C1 Distance: 366805641507084800.00 cm
# C2 Distance: 366805641507084800.00 cm
# Servo angles: {'x1': 114, 'y1': 98, 'x2': 90, 'y2': 90}
# C1 → X: 112.0°, Y: 99.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 apple, 1 dining table, 142.7ms
# Speed: 1.0ms preprocess, 142.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 81
# Balloon position: (20.00, -49.50, -404212358230886976.00)
# C1 Distance: 404212358230886976.00 cm
# C2 Distance: 404212358230886976.00 cm
# Servo angles: {'x1': 112, 'y1': 99, 'x2': 90, 'y2': 90}
#
# 0: 480x640 1 person, 1 sports ball, 1 chair, 1 couch, 145.6ms
# Class: sports ball, Confidence: 0.93
# Box: (1201.6246337890625, 519.4734497070312)
# Pan: -2.5941729781377285, Tilt: -0.07544709179550274
# Speed: 1.1ms preprocess, 145.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 82
# Balloon position: (20.00, -49.50, -404212358230886976.00)
# C1 Distance: 404212358230886976.00 cm
# C2 Distance: 404212358230886976.00 cm
# Servo angles: {'x1': 112, 'y1': 99, 'x2': 90, 'y2': 90}
# C1 → X: 110.0°, Y: 100.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 1 apple, 1 chair, 1 couch, 144.2ms
# Class: sports ball, Confidence: 0.4
# Box: (1211.8330078125, 522.07568359375)
# Pan: -2.675338382510183, Tilt: -0.07441106623493413
# Speed: 1.0ms preprocess, 144.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 83
# Balloon position: (20.00, -54.95, -448697113546129856.00)
# C1 Distance: 448697113546129856.00 cm
# C2 Distance: 448697113546129856.00 cm
# Servo angles: {'x1': 110, 'y1': 100, 'x2': 90, 'y2': 90}
# C1 → X: 108.0°, Y: 101.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 1 chair, 1 couch, 143.7ms
# Class: sports ball, Confidence: 0.87
# Box: (1198.2965087890625, 510.802978515625)
# Pan: -2.740270706008147, Tilt: 0.5404711470120528
# Speed: 1.3ms preprocess, 143.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 84
# Balloon position: (20.00, -61.55, -502623864989980288.00)
# C1 Distance: 502623864989980288.00 cm
# C2 Distance: 502623864989980288.00 cm
# Servo angles: {'x1': 108, 'y1': 101, 'x2': 90, 'y2': 90}
# C1 → X: 106.0°, Y: 101.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 1 chair, 1 couch, 145.3ms
# Class: sports ball, Confidence: 0.64
# Box: (1203.919921875, 481.05889892578125)
# Pan: -2.792216564806518, Tilt: 1.0323769176096422
# Speed: 1.1ms preprocess, 145.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 85
# Balloon position: (20.00, -69.75, -569538000061566144.00)
# C1 Distance: 569538000061566144.00 cm
# C2 Distance: 569538000061566144.00 cm
# Servo angles: {'x1': 106, 'y1': 101, 'x2': 90, 'y2': 90}
# C1 → X: 104.0°, Y: 100.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 1 chair, 1 couch, 145.0ms
# Class: sports ball, Confidence: 0.96
# Box: (1180.551513671875, 468.5123291015625)
# Pan: -2.360916578952593, Tilt: 1.425901534087714
# Speed: 1.1ms preprocess, 145.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 86
# Balloon position: (20.00, -80.22, -655010234188062848.00)
# C1 Distance: 655010234188062848.00 cm
# C2 Distance: 655010234188062848.00 cm
# Servo angles: {'x1': 104, 'y1': 100, 'x2': 90, 'y2': 90}
# C1 → X: 102.0°, Y: 99.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 1 couch, 1 bed, 144.8ms
# Class: sports ball, Confidence: 0.96
# Box: (1170.533447265625, 465.814697265625)
# Pan: -2.4887332631620747, Tilt: 1.7407212272701713
# Speed: 1.1ms preprocess, 144.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 87
# Balloon position: (20.00, -94.09, -768324403861422848.00)
# C1 Distance: 768324403861422848.00 cm
# C2 Distance: 768324403861422848.00 cm
# Servo angles: {'x1': 102, 'y1': 99, 'x2': 90, 'y2': 90}
# C1 → X: 100.0°, Y: 98.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 144.5ms
# Class: sports ball, Confidence: 0.94
# Box: (1154.291015625, 481.4734191894531)
# Pan: -2.5909866105296597, Tilt: 0.792576981816137
# Speed: 1.1ms preprocess, 144.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 88
# Balloon position: (20.00, -113.43, -926190608356023040.00)
# C1 Distance: 926190608356023040.00 cm
# C2 Distance: 926190608356023040.00 cm
# Servo angles: {'x1': 100, 'y1': 98, 'x2': 90, 'y2': 90}
# C1 → X: 98.0°, Y: 98.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 143.0ms
# Class: sports ball, Confidence: 0.96
# Box: (1115.300537109375, 511.0281982421875)
# Pan: -1.4727892884237277, Tilt: 0.034061585452909604
# Speed: 1.3ms preprocess, 143.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 89
# Balloon position: (20.00, -142.31, -1162028060227356928.00)
# C1 Distance: 1162028060227356928.00 cm
# C2 Distance: 1162028060227356928.00 cm
# Servo angles: {'x1': 98, 'y1': 98, 'x2': 90, 'y2': 90}
# C1 → X: 97.0°, Y: 98.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 144.1ms
# Class: sports ball, Confidence: 0.96
# Box: (1111.527587890625, 512.2132568359375)
# Pan: -1.7782314307389824, Tilt: 0.16338802811772601
# Speed: 1.0ms preprocess, 144.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 90
# Balloon position: (20.00, -162.89, -1330072708905949952.00)
# C1 Distance: 1330072708905949952.00 cm
# C2 Distance: 1330072708905949952.00 cm
# Servo angles: {'x1': 97, 'y1': 98, 'x2': 90, 'y2': 90}
# C1 → X: 96.0°, Y: 98.0°
# C2 → X: 90.0°, Y: 90.0°
#
# ...
# C1 Distance: 3116186103783256576.00 cm
# C2 Distance: 3116186103783256576.00 cm
# Servo angles: {'x1': 93, 'y1': 95, 'x2': 90, 'y2': 90}
# C1 → X: 91.0°, Y: 94.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 1 couch, 142.6ms
# Class: sports ball, Confidence: 0.96
# Box: (1183.251953125, 544.5293579101562)
# Pan: -1.0802333683854808, Tilt: 0.22282814117586203
# Speed: 1.3ms preprocess, 142.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 105
# Balloon position: (20.00, -1145.80, -9356160759273275392.00)
# C1 Distance: 9356160759273275392.00 cm
# C2 Distance: 9356160759273275392.00 cm
# Servo angles: {'x1': 91, 'y1': 94, 'x2': 90, 'y2': 90}
# C1 → X: 90.0°, Y: 94.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 144.3ms
# Class: sports ball, Confidence: 0.97
# Box: (979.6297607421875, 586.7550048828125)
# Pan: -0.26418669470838463, Tilt: -0.42173748705931047
# Speed: 1.0ms preprocess, 144.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 106
# Balloon position: (10.00, 163312393531953696.00, 1333546894056784429664990794874880.00)
# C1 Distance: 1333546894056784429664990794874880.00 cm
# C2 Distance: 1333546894056784429664990794874880.00 cm
# Servo angles: {'x1': 90, 'y1': 94, 'x2': 90, 'y2': 90}
# C1 → X: 90.0°, Y: 95.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 1 chair, 144.2ms
# Class: sports ball, Confidence: 0.97
# Box: (840.267578125, 587.8706665039062)
# Pan: 0.3886506442332924, Tilt: -0.5483552002524352
# Speed: 1.1ms preprocess, 144.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 107
# Balloon position: (10.00, 163312393531953696.00, 1333546894056784717895366946586624.00)
# C1 Distance: 1333546894056784717895366946586624.00 cm
# C2 Distance: 1333546894056784717895366946586624.00 cm
# Servo angles: {'x1': 90, 'y1': 95, 'x2': 90, 'y2': 90}
# C1 → X: 91.0°, Y: 96.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 145.3ms
# Class: sports ball, Confidence: 0.97
# Box: (744.264892578125, 585.0359497070312)
# Pan: 0.910920515386634, Tilt: -0.29892293855820773
# Speed: 0.9ms preprocess, 145.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 108
# Balloon position: (20.00, -1145.80, -9356160759273277440.00)
# C1 Distance: 9356160759273277440.00 cm
# C2 Distance: 9356160759273277440.00 cm
# Servo angles: {'x1': 91, 'y1': 96, 'x2': 90, 'y2': 90}
# C1 → X: 92.0°, Y: 97.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 1 couch, 143.2ms
# Class: sports ball, Confidence: 0.96
# Box: (655.9681396484375, 563.2665405273438)
# Pan: 1.3287364123093073, Tilt: 0.3608616491534339
# Speed: 1.1ms preprocess, 143.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 109
# Balloon position: (20.00, -572.73, -4676655065420221440.00)
# C1 Distance: 4676655065420221440.00 cm
# C2 Distance: 4676655065420221440.00 cm
# Servo angles: {'x1': 92, 'y1': 97, 'x2': 90, 'y2': 90}
# C1 → X: 94.0°, Y: 97.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 1 couch, 142.3ms
# Class: sports ball, Confidence: 0.95
# Box: (560.4810180664062, 501.34112548828125)
# Pan: 1.662989129847446, Tilt: 0.8886893193227472
# Speed: 1.1ms preprocess, 142.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 110
# Balloon position: (20.00, -286.01, -2335476035485268992.00)
# C1 Distance: 2335476035485268992.00 cm
# C2 Distance: 2335476035485268992.00 cm
# Servo angles: {'x1': 94, 'y1': 97, 'x2': 90, 'y2': 90}
# C1 → X: 96.0°, Y: 97.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 1 couch, 143.1ms
# Class: sports ball, Confidence: 0.96
# Box: (485.9587707519531, 425.5986633300781)
# Pan: 1.930391303877957, Tilt: 1.310951455458198
# Speed: 1.1ms preprocess, 143.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 111
# Balloon position: (20.00, -190.29, -1553813631954429696.00)
# C1 Distance: 1553813631954429696.00 cm
# C2 Distance: 1553813631954429696.00 cm
# Servo angles: {'x1': 96, 'y1': 97, 'x2': 90, 'y2': 90}
# C1 → X: 98.0°, Y: 96.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 1 couch, 142.4ms
# Class: sports ball, Confidence: 0.96
# Box: (514.9935302734375, 335.64739990234375)
# Pan: 0.9443130431023656, Tilt: 1.6487611643665585
# Speed: 1.1ms preprocess, 142.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 112
# Balloon position: (20.00, -142.31, -1162028060227356672.00)
# C1 Distance: 1162028060227356672.00 cm
# C2 Distance: 1162028060227356672.00 cm
# Servo angles: {'x1': 98, 'y1': 96, 'x2': 90, 'y2': 90}
# C1 → X: 99.0°, Y: 95.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 1 couch, 144.5ms
# Class: sports ball, Confidence: 0.96
# Box: (603.5841064453125, 252.8927764892578)
# Pan: 0.15545043448189244, Tilt: 1.919008931493247
# Speed: 1.1ms preprocess, 144.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 113
# Balloon position: (20.00, -126.28, -1031113872027579648.00)
# C1 Distance: 1031113872027579648.00 cm
# C2 Distance: 1031113872027579648.00 cm
# Servo angles: {'x1': 99, 'y1': 95, 'x2': 90, 'y2': 90}
# C1 → X: 100.0°, Y: 94.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 1 couch, 142.2ms
# Class: sports ball, Confidence: 0.97
# Box: (722.6666259765625, 218.1573028564453)
# Pan: -0.47563965241448614, Tilt: 2.135207145194598
# Speed: 1.0ms preprocess, 142.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 114
# Balloon position: (20.00, -113.43, -926190608356022656.00)
# C1 Distance: 926190608356022656.00 cm
# C2 Distance: 926190608356022656.00 cm
# Servo angles: {'x1': 100, 'y1': 94, 'x2': 90, 'y2': 90}
# C1 → X: 100.0°, Y: 92.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 1 chair, 142.3ms
# Class: sports ball, Confidence: 0.97
# Box: (866.1861572265625, 254.81011962890625)
# Pan: -0.9805117219315891, Tilt: 1.1081657161556784
# Speed: 1.0ms preprocess, 142.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 115
# Balloon position: (20.00, -113.43, -926190608356021760.00)
# C1 Distance: 926190608356021760.00 cm
# C2 Distance: 926190608356021760.00 cm
# Servo angles: {'x1': 100, 'y1': 92, 'x2': 90, 'y2': 90}
# C1 → X: 100.0°, Y: 91.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 142.3ms
# Class: sports ball, Confidence: 0.96
# Box: (953.320068359375, 335.9749755859375)
# Pan: -1.3844093775452713, Tilt: 0.2865325729245427
# Speed: 1.1ms preprocess, 142.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 116
# Balloon position: (20.00, -113.43, -926190608356020096.00)
# C1 Distance: 926190608356020096.00 cm
# C2 Distance: 926190608356020096.00 cm
# Servo angles: {'x1': 100, 'y1': 91, 'x2': 90, 'y2': 90}
# C1 → X: 99.0°, Y: 91.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 142.6ms
# Class: sports ball, Confidence: 0.96
# Box: (1057.0042724609375, 413.1339111328125)
# Pan: -1.707527502036217, Tilt: -0.3707739416603659
# Speed: 1.0ms preprocess, 142.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 117
# Balloon position: (20.00, -126.28, -1031113872027576704.00)
# C1 Distance: 1031113872027576704.00 cm
# C2 Distance: 1031113872027576704.00 cm
# Servo angles: {'x1': 99, 'y1': 91, 'x2': 90, 'y2': 90}
# C1 → X: 98.0°, Y: 92.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 144.2ms
# Class: sports ball, Confidence: 0.95
# Box: (1136.224609375, 495.6168518066406)
# Pan: -1.9660220016289738, Tilt: -0.8966191533282928
# Speed: 1.1ms preprocess, 144.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 118
# Balloon position: (20.00, -142.31, -1162028060227355392.00)
# C1 Distance: 1162028060227355392.00 cm
# C2 Distance: 1162028060227355392.00 cm
# Servo angles: {'x1': 98, 'y1': 92, 'x2': 90, 'y2': 90}
# C1 → X: 97.0°, Y: 93.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 142.8ms
# Class: sports ball, Confidence: 0.96
# Box: (1145.055908203125, 568.8770141601562)
# Pan: -2.172817601303179, Tilt: -1.3172953226626345
# Speed: 1.1ms preprocess, 142.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 119
# Balloon position: (20.00, -162.89, -1330072708905948928.00)
# C1 Distance: 1330072708905948928.00 cm
# C2 Distance: 1330072708905948928.00 cm
# Servo angles: {'x1': 97, 'y1': 93, 'x2': 90, 'y2': 90}
# C1 → X: 95.0°, Y: 95.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 143.0ms
# Class: sports ball, Confidence: 0.94
# Box: (1054.430419921875, 628.0765380859375)
# Pan: -1.1382540810425432, Tilt: -1.6538362581301078
# Speed: 1.3ms preprocess, 143.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 120
# Balloon position: (20.00, -228.60, -1866669199759377664.00)
# C1 Distance: 1866669199759377664.00 cm
# C2 Distance: 1866669199759377664.00 cm
# Servo angles: {'x1': 95, 'y1': 95, 'x2': 90, 'y2': 90}
# C1 → X: 94.0°, Y: 97.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 1 chair, 144.3ms
# Class: sports ball, Confidence: 0.96
# Box: (896.523681640625, 637.6765747070312)
# Pan: -0.31060326483403455, Tilt: -1.9230690065040865
# Speed: 1.0ms preprocess, 144.3ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 121
# Balloon position: (20.00, -286.01, -2335476035485268992.00)
# C1 Distance: 2335476035485268992.00 cm
# C2 Distance: 2335476035485268992.00 cm
# Servo angles: {'x1': 94, 'y1': 97, 'x2': 90, 'y2': 90}
# C1 → X: 94.0°, Y: 99.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 144.1ms
# Class: sports ball, Confidence: 0.96
# Box: (738.623779296875, 595.5621337890625)
# Pan: 0.35151738813277245, Tilt: -0.9384552052032693
# Speed: 1.1ms preprocess, 144.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 122
# Balloon position: (20.00, -286.01, -2335476035485268992.00)
# C1 Distance: 2335476035485268992.00 cm
# C2 Distance: 2335476035485268992.00 cm
# Servo angles: {'x1': 94, 'y1': 99, 'x2': 90, 'y2': 90}
# C1 → X: 95.0°, Y: 100.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 146.0ms
# Class: sports ball, Confidence: 0.96
# Box: (590.494384765625, 538.7368774414062)
# Pan: 0.881213910506218, Tilt: -0.1507641641626154
# Speed: 1.0ms preprocess, 146.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 123
# Balloon position: (20.00, -228.60, -1866669199759378176.00)
# C1 Distance: 1866669199759378176.00 cm
# C2 Distance: 1866669199759378176.00 cm
# Servo angles: {'x1': 95, 'y1': 100, 'x2': 90, 'y2': 90}
# C1 → X: 96.0°, Y: 101.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 1 bed, 144.9ms
# Class: sports ball, Confidence: 0.95
# Box: (429.2969970703125, 488.6290283203125)
# Pan: 1.3049711284049745, Tilt: 0.47938866866990776
# Speed: 1.0ms preprocess, 144.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 124
# Balloon position: (20.00, -190.29, -1553813631954429952.00)
# C1 Distance: 1553813631954429952.00 cm
# C2 Distance: 1553813631954429952.00 cm
# Servo angles: {'x1': 96, 'y1': 101, 'x2': 90, 'y2': 90}
# C1 → X: 98.0°, Y: 101.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 144.1ms
# Class: sports ball, Confidence: 0.96
# Box: (232.4525146484375, 429.7520446777344)
# Pan: 1.6439769027239797, Tilt: 0.9835109349359263
# Speed: 1.3ms preprocess, 144.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 125
# Balloon position: (20.00, -142.31, -1162028060227357184.00)
# C1 Distance: 1162028060227357184.00 cm
# C2 Distance: 1162028060227357184.00 cm
# Servo angles: {'x1': 98, 'y1': 101, 'x2': 90, 'y2': 90}
# C1 → X: 100.0°, Y: 101.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 sports ball, 1 bed, 144.1ms
# Class: sports ball, Confidence: 0.32
# Box: (45.08432388305664, 351.04443359375)
# Pan: 1.915181522179184, Tilt: 1.3868087479487412
# Speed: 1.1ms preprocess, 144.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 126
# Balloon position: (20.00, -113.43, -926190608356023168.00)
# C1 Distance: 926190608356023168.00 cm
# C2 Distance: 926190608356023168.00 cm
# Servo angles: {'x1': 100, 'y1': 101, 'x2': 90, 'y2': 90}
# C1 → X: 102.0°, Y: 100.0°
# C2 → X: 90.0°, Y: 90.0°
#
# 0: 480x640 1 person, 1 couch, 144.7ms
# Speed: 1.0ms preprocess, 144.7ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 127
# Balloon position: (20.00, -94.09, -768324403861422848.00)
# C1 Distance: 768324403861422848.00 cm
# C2 Distance: 768324403861422848.00 cm
# Servo angles: {'x1': 102, 'y1': 100, 'x2': 90, 'y2': 90}
#
# 0: 480x640 1 person, 1 couch, 145.2ms
# Speed: 1.1ms preprocess, 145.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 128
# Balloon position: (20.00, -94.09, -768324403861422848.00)
# C1 Distance: 768324403861422848.00 cm
# C2 Distance: 768324403861422848.00 cm
# Servo angles: {'x1': 102, 'y1': 100, 'x2': 90, 'y2': 90}
#
# 0: 480x640 1 person, 1 couch, 143.5ms
# Speed: 1.0ms preprocess, 143.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 129
# Balloon position: (20.00, -94.09, -768324403861422848.00)
# C1 Distance: 768324403861422848.00 cm
# C2 Distance: 768324403861422848.00 cm
# Servo angles: {'x1': 102, 'y1': 100, 'x2': 90, 'y2': 90}
#
# 0: 480x640 1 person, 1 bed, 143.0ms
# Speed: 1.0ms preprocess, 143.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 130
# Balloon position: (20.00, -94.09, -768324403861422848.00)
# C1 Distance: 768324403861422848.00 cm
# C2 Distance: 768324403861422848.00 cm
# Servo angles: {'x1': 102, 'y1': 100, 'x2': 90, 'y2': 90}
#
# 0: 480x640 1 person, 1 couch, 141.1ms
# Speed: 1.0ms preprocess, 141.1ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 131
# Balloon position: (20.00, -94.09, -768324403861422848.00)
# C1 Distance: 768324403861422848.00 cm
# C2 Distance: 768324403861422848.00 cm
# Servo angles: {'x1': 102, 'y1': 100, 'x2': 90, 'y2': 90}
#
# 0: 480x640 1 person, 1 bed, 144.4ms
# Speed: 1.0ms preprocess, 144.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 132
# Balloon position: (20.00, -94.09, -768324403861422848.00)
# C1 Distance: 768324403861422848.00 cm
# C2 Distance: 768324403861422848.00 cm
# Servo angles: {'x1': 102, 'y1': 100, 'x2': 90, 'y2': 90}
#
# 0: 480x640 1 person, 143.6ms
# Speed: 1.1ms preprocess, 143.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 133
# Balloon position: (20.00, -94.09, -768324403861422848.00)
# C1 Distance: 768324403861422848.00 cm
# C2 Distance: 768324403861422848.00 cm
# Servo angles: {'x1': 102, 'y1': 100, 'x2': 90, 'y2': 90}
#
# 0: 480x640 1 person, 144.4ms
# Speed: 1.1ms preprocess, 144.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 134
# Balloon position: (20.00, -94.09, -768324403861422848.00)
# C1 Distance: 768324403861422848.00 cm
# C2 Distance: 768324403861422848.00 cm
# Servo angles: {'x1': 102, 'y1': 100, 'x2': 90, 'y2': 90}
#
# 0: 480x640 1 person, 141.9ms
# Speed: 1.4ms preprocess, 141.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Frame number: 135
# Balloon position: (20.00, -94.09, -768324403861422848.00)
# C1 Distance: 768324403861422848.00 cm
# C2 Distance: 768324403861422848.00 cm
# Servo angles: {'x1': 102, 'y1': 100, 'x2': 90, 'y2': 90}
#
# ----------------------------------------- Program finished -----------------------------------------
#
# Total frames: 135
# Detected classes: ['sports ball']
# Frame center: (640.0, 480.0)
# FPS: 100.00
# Final balloon position: (20.00, -94.09, -768324403861422848.00)
# Final C1 distance: 768324403861422848.00 cm
# Final C2 distance: 768324403861422848.00 cm
# Servo angles: {'x1': 102, 'y1': 100, 'x2': 90, 'y2': 90}
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
